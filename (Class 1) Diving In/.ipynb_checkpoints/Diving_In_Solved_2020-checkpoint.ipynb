# %% [markdown]
# # Welcome to Projects in Programming & Data Science!

# %% [markdown]
# ---

# %% [markdown]
# # Laptop Setup
#
# ### NYU Classes
#
# Make sure you are able to access our course page on NYU Classes. This is where I will be posting all of our course content (notebooks, datasets, et. cetera). This is also where all of your assignments will be posted, graded, and returned.
#
# ### Colab
#
# In order to standardize the way we all use Jupyter Notebook (described below) we are going to use Google's Colab (https://colab.research.google.com/notebooks/welcome.ipynb)
#
# Think of using Colab as renting a computer via your web browser (I recommend Chrome) that you can use. This is important because that means that in order to save your work, you need to download it from Colab onto your computer (machine) and re-upload it next time you'd like to work with it.
#
# For instance, if I want to open today's class notebook in Colab, I:
#
# <br>
#
# 1. **Will go to https://colab.research.google.com/notebooks/welcome.ipynb**
#
# <div>
#     <img src="attachment:Screen%20Shot%202019-10-23%20at%201.51.42%20PM.png" width=600  />
# </div>
#
# 2. **Will click "file" > "upload notebook"**
#
# <div>
#     <img src="attachment:Screen%20Shot%202019-10-23%20at%201.54.00%20PM.png" width=600  />
# </div>
#
# 3. **Note that a Jupyter Notebook will always have a .ipynb extension. In Colab I can click "Upload" then "Choose File" and upload the notebook (that I have downloaded from NYU Classes) to Colab.**
#
# <div>
#     <img src="attachment:Screen%20Shot%202019-10-23%20at%201.54.49%20PM.png" width=600  />
# </div>
#
# 4. **Once I click "Open" ...**
#
# <div>
#     <img src="attachment:Screen%20Shot%202019-10-23%20at%201.55.06%20PM.png" width=600  />
# </div>
#
# 5. **Colab should open the notebook, and voila!**
#
# <div>
#     <img src="attachment:Screen%20Shot%202019-10-23%20at%201.55.27%20PM.png" width=600  />
# </div>

# %% [markdown]
# ---

# %% [markdown]
# Today we're going to jump right in to the mix and leverage the CitiBike API to populate a sqlite database at regular intervals. Consider this your warm-up for the semester!

# %%
import sqlite3

# %% [markdown]
# [SQLite](https://www.sqlite.org/index.html) is a library that allows us to create, populate, and call upon a SQL Database. It's also serverless, meaning we don't need to access a separate server where we're storing our data – instead, we can directly access our databse. We can even store that database as a file on our local machine and call upon it.

# %%
con = sqlite3.connect('citibikeData2020.db') # this is how we are going to create our database, 
                                         # calling it 'citibikeData.db'

                                         # note that if the db doesn't exist, this will create it; Otherwise, it will connect

# "con" stands for "connection" – this is telling SQLite what database to use

# %% [markdown]
# Now, let's check out the API we'll be working with: http://gbfs.citibikenyc.com/gbfs/gbfs.json

# %% [markdown]
# ---

# %% [markdown]
# First, we'll request the json from the CitiBike API URL and just print it out to get a quick glimpse

# %%
import json 
import urllib.request # https://docs.python.org/3/library/urllib.request.html

with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_status.json") as url:
    data = json.loads(url.read().decode())
    print(data)

# %% [markdown]
# As you can see, the json is a dictionary of lists and other dictionaries containing information about CitiBike stations across New York City.

# %%
for key,value in data.items():
    #print("key: {0} | value: {1}".format(key, value))
# Out:
#   File "<ipython-input-6-2500c30d98ba>", line 2
#     #print("key: {0} | value: {1}".format(key, value))
#                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
values_list = list(data.values())

# %%
#values_list

# %%
clean_data = values_list[0]['stations']

# %%
import pandas as pd # we'll use pandas just to visualize our data, NOT to query it

df_stations = pd.DataFrame(clean_data) # create a new dataframe called 'df_stations' 
df_stations.head() # check the first five station entries
# Out:
#    num_bikes_available  is_installed  ... valet  eightd_active_station_services
# 0                    0             0  ...   NaN                             NaN
# 1                   31             1  ...   NaN                             NaN
# 2                   23             1  ...   NaN                             NaN
# 3                   57             1  ...   NaN                             NaN
# 4                   15             1  ...   NaN                             NaN
#
# [5 rows x 15 columns]

# %%
#clean_data[0]

# %%
#clean_data[0]['station_id']

# %%
for entry in clean_data:
    #print(entry['station_id'])
# Out:
#   File "<ipython-input-10-be9833a46aa7>", line 2
#     #print(entry['station_id'])
#                                ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# So, we have our data from the CitiBike feed, and it looks pretty good! Now we need to create a table within our database (the one we named citibikeData.db). We do that using the 'CREATE TABLE IF NOT EXISTS' statement seen below.
#
# In that statement, the 'IF NOT EXISTS' makes clear that we are going to create the table called 'StationsData' only once. That way, if we run that cell again, it's not going to overwrite the work we've previously done.
#
# Note that at this point we aren't adding any data to our table. All we're doing is telling SQLite that we want to create a new table, and providing it with a) the column names and b) the data type those columns should be expecting.

# %%
sql = "CREATE TABLE IF NOT EXISTS StationsData (station_id int, num_ebikes_available int, num_bikes_available int, is_installed int, last_reported int, num_docks_disabled int, is_renting int, eightd_has_available_keys varchar(250), num_docks_available int, num_bikes_disabled int, legacy_id int, station_status varchar(250), is_returning int);" 

con.execute(sql)
con.commit()

# %% [markdown]
# Now that we have our database and our table, we want to insert our data.
#
# Below, we create a "query template" where we "INSERT OR IGNORE INTO" our table (StationsData) the values associated with each of our columns.
#
# We define those values by parsing through the CitiBike json we got earlier, and for each "row" of that json, we create a new row in our SQLite table.

# %%
""" 

query_template = """INSERT OR IGNORE INTO StationsData(station_id, num_ebikes_available, num_bikes_available, \
is_installed, last_reported, num_docks_disabled, is_renting, eightd_has_available_keys, \
num_docks_available, num_bikes_disabled, legacy_id, station_status, is_returning) \
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

for entry in clean_data: # for every station entry in the json 
    station_id = int(entry['station_id']) # find and set station_id
    num_ebikes_available = int(entry['num_ebikes_available'])
    num_bikes_available = int(entry['num_bikes_available'])
    is_installed = int(entry['is_installed'])
    last_reported = int(entry['last_reported'])
    num_docks_disabled = int(entry['num_docks_disabled'])
    is_renting = int(entry['is_renting'])
    eightd_has_available_keys = str(entry['eightd_has_available_keys'])
    num_docks_available = int(entry['num_docks_available'])
    num_bikes_disabled = int(entry['num_bikes_disabled'])
    legacy_id = int(entry['legacy_id'])
    station_status = str(entry['station_status'])
    is_returning = int(entry['is_returning'])
                           
    print("Inserting Station:", station_id, num_ebikes_available, num_bikes_available, is_installed, last_reported, num_docks_disabled, is_renting, eightd_has_available_keys, num_docks_available, num_bikes_disabled, legacy_id, station_status, is_returning) 
    
    query_parameters = (station_id, num_ebikes_available, num_bikes_available, is_installed, last_reported, num_docks_disabled, is_renting, eightd_has_available_keys, num_docks_available, num_bikes_disabled, legacy_id, station_status, is_returning) 
    
    con.execute(query_template, query_parameters)
    
con.commit()

"""
# Out:
#   File "<ipython-input-11-c63c84959792>", line 3
#     query_template = """INSERT OR IGNORE INTO StationsData(station_id, num_ebikes_available, num_bikes_available, \
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# Now, we can use [pd.read_sql](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_sql.html) to check that we are properly connected to our database, and the StationsData table within that database:

# %%
check = pd.read_sql("SELECT * FROM StationsData LIMIT 5", con=con)
check
# Out:
#    station_id  num_ebikes_available  ...  station_status  is_returning
# 0          72                     0  ...  out_of_service             0
# 1          79                     1  ...          active             1
# 2          82                     0  ...          active             1
# 3          83                     1  ...          active             1
# 4         116                     0  ...          active             1
#
# [5 rows x 13 columns]

# %% [markdown]
# Looks good! Last but not least, let's set things up so that our database automatically updates every 15 seconds.

# %%
import time 
import json 
import urllib.request
from datetime import datetime

while True:

    with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_status.json") as url:
        data = json.loads(url.read().decode())
        print(data)

    clean_data = values_list[0]['stations']

    query_template = """INSERT OR IGNORE INTO StationsData(station_id, num_ebikes_available, num_bikes_available, \
is_installed, last_reported, num_docks_disabled, is_renting, eightd_has_available_keys, \
num_docks_available, num_bikes_disabled, legacy_id, station_status, is_returning) \
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

    for entry in clean_data: # for every station entry in the json 
        station_id = int(entry['station_id']) # find and set station_id
        num_ebikes_available = int(entry['num_ebikes_available'])
        num_bikes_available = int(entry['num_bikes_available'])
        is_installed = int(entry['is_installed'])
        last_reported = int(entry['last_reported'])
        num_docks_disabled = int(entry['num_docks_disabled'])
        is_renting = int(entry['is_renting'])
        eightd_has_available_keys = str(entry['eightd_has_available_keys'])
        num_docks_available = int(entry['num_docks_available'])
        num_bikes_disabled = int(entry['num_bikes_disabled'])
        legacy_id = int(entry['legacy_id'])
        station_status = str(entry['station_status'])
        is_returning = int(entry['is_returning'])
                              
        print("Inserting Station:", station_id, num_ebikes_available, num_bikes_available, is_installed, last_reported, num_docks_disabled, is_renting, eightd_has_available_keys, num_docks_available, num_bikes_disabled, legacy_id, station_status, is_returning) 
        
        query_parameters = (station_id, num_ebikes_available, num_bikes_available, is_installed, last_reported, num_docks_disabled, is_renting, eightd_has_available_keys, num_docks_available, num_bikes_disabled, legacy_id, station_status, is_returning) 
        
        con.execute(query_template, query_parameters)
        
    con.commit()
        
    time.sleep(15)
# Out:
# {'data': {'stations': [{'legacy_id': '72', 'is_installed': 0, 'num_docks_disabled': 0, 'num_bikes_available': 0, 'num_ebikes_available': 0, 'is_renting': 0, 'eightd_has_available_keys': False, 'station_id': '72', 'is_returning': 0, 'num_bikes_disabled': 0, 'last_reported': 86400, 'station_status': 'out_of_service', 'num_docks_available': 0}, {'legacy_id': '79', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 31, 'num_ebikes_available': 1, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '79', 'is_returning': 1, 'num_bikes_disabled': 2, 'last_reported': 1598968712, 'station_status': 'active', 'num_docks_available': 0}, {'legacy_id': '82', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 23, 'num_ebikes_available': 0, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '82', 'is_returning': 1, 'num_bikes_disabled': 0, 'last_reported': 1598969781, 'station_status': 'active', 'num_docks_available': 4}, {'legacy_id': '83', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 57, 'num_ebikes_available': 1, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '83', 'is_returning': 1, 'num_bikes_disabled': 0, 'last_reported': 1598969176, 'station_status': 'active', 'num_docks_available': 5}, {'legacy_id': '116', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 15, 'num_ebikes_available': 0, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '116', 'is_returning': 1, 'num_bikes_disabled': 1, 'last_reported': 1598969023, 'station_status': 'active', 'num_docks_available': 34}, {'legacy_id': '119', 'is_installed': 0, 'num_docks_disabled': 0, 'num_bikes_available': 0, 'num_ebikes_available': 0, 'is_renting': 0, 'eightd_has_available_keys': False, 'station_id': '119', 'is_returning': 0, 'num_bikes_disabled': 0, 'last_reported': 86400, 'station_status': 'out_of_service', 'num_docks_available': 0}, {'legacy_id': '120', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 11, 'num_ebikes_available': 0, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '120', 'is_returning': 1, 'num_bikes_disabled': 0, 'last_reported': 1598969449, 'station_status': 'active', 'num_docks_available': 8}, {'legacy_id': '127', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 13, 'num_ebikes_available': 0, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '127', 'is_returning': 1, 'num_bikes_disabled': 0, 'last_reported': 1598969848, 'station_status': 'active', 'num_docks_available': 18}, {'legacy_id': '128', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 17, 'num_ebikes_available': 0, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '128', 'is_returning': 1, 'num_bikes_disabled': 2, 'last_reported': 1598969693, 'station_status': 'active', 'num_docks_available': 11}, {'legacy_id': '143', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 20, 'num_ebikes_available': 0, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '143', 'is_returning': 1, 'num_bikes_disabled': 2, 'last_reported': 1598969163, 'station_status': 'active', 'num_docks_available': 2}, {'legacy_id': '144', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 56, 'num_ebikes_available': 0, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '144', 'is_returning': 1, 'num_bikes_disabled': 0, 'last_reported': 1598969510, 'station_status': 'active', 'num_docks_available': 2}, {'legacy_id': '146', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 25, 'num_ebikes_available': 0, 'is_renting': 1, 'eightd_has_available_keys': False, 'station_id': '146', 'is_returning': 1, 'num_bikes_disabled': 5, 'last_reported': 1598969675, 'station_status': 'active', 'num_docks_available': 9}, {'legacy_id': '150', 'is_installed': 1, 'num_docks_disabled': 0, 'num_bikes_available': 17, 'num_ebikes_available': 0, 'is_ren ...
# Inserting Station: 72 0 0 0 86400 0 0 False 0 0 72 out_of_service 0
# Inserting Station: 79 1 31 1 1598968712 0 1 False 0 2 79 active 1
# Inserting Station: 82 0 23 1 1598969781 0 1 False 4 0 82 active 1
# Inserting Station: 83 1 57 1 1598969176 0 1 False 5 0 83 active 1
# Inserting Station: 116 0 15 1 1598969023 0 1 False 34 1 116 active 1
# Inserting Station: 119 0 0 0 86400 0 0 False 0 0 119 out_of_service 0
# Inserting Station: 120 0 11 1 1598969449 0 1 False 8 0 120 active 1
# Inserting Station: 127 0 12 1 1598969411 0 1 False 19 0 127 active 1
# Inserting Station: 128 0 17 1 1598969693 0 1 False 11 2 128 active 1
# Inserting Station: 143 0 20 1 1598969163 0 1 False 2 2 143 active 1
# Inserting Station: 144 0 56 1 1598969510 0 1 False 2 0 144 active 1
# Inserting Station: 146 0 25 1 1598969675 0 1 False 9 5 146 active 1
# Inserting Station: 150 0 17 1 1598969696 0 1 False 37 1 150 active 1
# Inserting Station: 151 1 30 1 1598969362 0 1 True 1 2 151 active 1
# Inserting Station: 157 0 0 1 1598967640 0 1 False 22 1 157 active 1
# Inserting Station: 161 0 14 1 1598969783 0 1 False 19 2 161 active 1
# Inserting Station: 164 0 10 1 1598969628 0 1 False 36 1 164 active 1
# Inserting Station: 167 1 16 1 1598969792 0 1 False 29 0 167 active 1
# Inserting Station: 168 0 0 0 86400 0 0 False 0 0 168 out_of_service 0
# Inserting Station: 173 0 6 1 1598969570 70 1 False 0 3 173 active 1
# Inserting Station: 174 0 23 1 1598969689 0 1 False 10 2 174 active 1
# Inserting Station: 195 0 0 0 86400 0 0 False 0 0 195 out_of_service 0
# Inserting Station: 212 0 52 1 1598969160 0 1 False 2 0 212 active 1
# Inserting Station: 216 0 13 1 1598969133 0 1 False 9 1 216 active 1
# Inserting Station: 217 0 26 1 1598968939 0 1 False 9 2 217 active 1
# Inserting Station: 223 1 11 1 1598968937 0 1 False 20 2 223 active 1
# Inserting Station: 224 1 5 1 1598969520 0 1 True 24 1 224 active 1
# Inserting Station: 228 2 11 1 1598969244 0 1 False 43 1 228 active 1
# Inserting Station: 229 0 16 1 1598969782 0 1 False 7 0 229 active 1
# Inserting Station: 236 0 21 1 1598969816 0 1 False 24 2 236 active 1
# Inserting Station: 237 0 20 1 1598969753 0 1 False 18 1 237 active 1
# Inserting Station: 238 0 16 1 1598969671 0 1 False 14 1 238 active 1
# Inserting Station: 239 0 19 1 1598969386 0 1 False 9 3 239 active 1
# Inserting Station: 241 0 15 1 1598968267 0 1 False 7 1 241 active 1
# Inserting Station: 242 0 45 1 1598969581 0 1 False 1 0 242 active 1
# Inserting Station: 244 0 1 1 1598969331 0 1 False 29 1 244 active 1
# Inserting Station: 245 0 19 1 1598968310 0 1 True 1 3 245 active 1
# Inserting Station: 247 0 24 1 1598968918 0 1 False 31 0 247 active 1
# Inserting Station: 248 0 81 1 1598969287 0 1 False 18 0 248 active 1
# Inserting Station: 249 0 16 1 1598969352 0 1 False 10 1 249 active 1
# Inserting Station: 250 1 20 1 1598969635 0 1 False 19 1 250 active 1
# Inserting Station: 251 0 15 1 1598969577 0 1 False 12 0 251 active 1
# Inserting Station: 252 1 15 1 1598969681 0 1 False 16 2 252 active 1
# Inserting Station: 254 0 13 1 1598969477 0 1 False 33 1 254 active 1
# Inserting Station: 257 3 30 1 1598969378 0 1 False 7 2 257 active 1
# Inserting Station: 258 1 9 1 1598969056 0 1 False 14 0 258 active 1
# Inserting Station: 259 0 11 1 1598969447 0 1 False 27 1 259 active 1
# Inserting Station: 260 0 24 1 1598968650 0 1 False 9 0 260 active 1
# Inserting Station: 261 1 24 1 1598969782 0 1 False 3 0 261 active 1
# Inserting Station: 262 0 5 1 1598968193 0 1 False 18 1 262 active 1
# Inserting Station: 264 1 10 1 1598969636 0 1 False 15 2 264 active 1
# Inserting Station: 265 0 17 1 1598969431 0 1 False 18 0 265 active 1
# Inserting Station: 267 0 9 1 1598969781 0 1 False 67 2 267 active 1
# Inserting Station: 268 2 27 1 1598969362 0 1 False 0 0 268 active 1
# Inserting Station: 270 0 9 1 1598967971 0 1 False 14 0 270 active 1
# Inserting Station: 274 0 21 1 1598968914 0 1 False 7 3 274 active 1
# Inserting Station: 275 0 4 1 1598968875 0 1 False 14 1 275 active 1
# Inserting Station: 276 0 17 1 1598968945 0 1 False 3 5 276 active 1
# Inserting Station: 278 1 17 1 1598967235 0 1 False 2 0 278 active 1
# Inserting Station: 280 0 0 1 1598938985 0 0 False 59 0 280 active 0
# Inserting Station: 281 3 35 1 1598969385 0 1 False 27 4 281 active 1
# Inserting Station: 282 0 18 1 1598968754 0 1 False 8 1 282 active 1
# Inserting Station: 284 2 20 1 1598969649 0 1 False 23 0 284 active 1
# Inserting Station: 285 0 21 1 1598969743 0 1 True 31 1 285 active 1
# Inserting Station: 289 0 6 1 1598967743 0 1 False 13 0 289 active 1
# Inserting Station: 291 0 1 1 1598969791 0 1 False 13 6 291 active 1
# Inserting Station: 293 3 7 1 1598969746 0 1 False 47 1 293 active 1
# Inserting Station: 295 0 14 1 1598969522 0 1 False 10 0 295 active 1
# Inserting Station: 297 2 38 1 1598969592 0 1 False 40 3 297 active 1
# Inserting Station: 298 2 21 1 1598969091 0 1 False 14 0 298 active 1
# Inserting Station: 301 0 40 1 1598969807 0 1 False 17 1 301 active 1
# Inserting Station: 302 0 15 1 1598968600 0 1 False 7 1 302 active 1
# Inserting Station: 303 2 61 1 1598969708 0 1 False 6 0 303 active 1
# Inserting Station: 304 6 24 1 1598969799 26 1 True 0 1 304 active 1
# Inserting Station: 305 0 11 1 1598969728 0 1 False 22 0 305 active 1
# Inserting Station: 307 0 11 1 1598969302 0 1 False 19 0 307 active 1
# Inserting Station: 308 0 25 1 1598968834 0 1 False 0 2 308 active 1
# Inserting Station: 309 2 40 1 1598969692 0 1 False 0 1 309 active 1
# Inserting Station: 310 0 22 1 1598969393 0 1 False 11 3 310 active 1
# Inserting Station: 311 0 20 1 1598969628 0 1 False 7 4 311 active 1
# Inserting Station: 366 0 29 1 1598968261 0 1 False 4 0 366 active 1
# Inserting Station: 367 0 21 1 1598969579 0 1 False 22 0 367 active 1
# Inserting Station: 368 0 23 1 1598969666 0 1 False 15 1 368 active 1
# Inserting Station: 369 0 12 1 1598969635 0 1 False 45 3 369 active 1
# Inserting Station: 372 1 3 1 1598967081 0 1 False 23 1 372 active 1
# Inserting Station: 373 0 11 1 1598969110 0 1 False 8 0 373 active 1
# Inserting Station: 376 0 39 1 1598969818 0 1 False 3 1 376 active 1
# Inserting Station: 377 2 48 1 1598968230 0 1 False 0 0 377 active 1
# Inserting Station: 379 2 2 1 1598969761 0 1 False 40 0 379 active 1
# Inserting Station: 380 1 21 1 1598969532 0 1 False 20 1 380 active 1
# Inserting Station: 383 0 5 1 1598969125 0 1 False 34 0 383 active 1
# Inserting Station: 385 0 1 1 1598969725 0 1 False 26 2 385 active 1
# Inserting Station: 386 1 76 1 1598969259 0 1 False 4 2 386 active 1
# Inserting Station: 387 0 29 1 1598968928 0 1 True 9 1 387 active 1
# Inserting Station: 388 1 20 1 1598969121 0 1 False 12 3 388 active 1
# Inserting Station: 389 0 0 0 86400 0 0 False 0 0 389 out_of_service 0
# Inserting Station: 390 0 25 1 1598969038 0 1 False 4 2 390 active 1
# Inserting Station: 391 0 11 1 1598968971 0 1 False 20 0 391 active 1
# Inserting Station: 392 0 32 1 1598969374 0 1 False 0 3 392 active 1
# Inserting Station: 393 0 18 1 1598969334 0 1 False 18 1 393 active 1
# Inserting Station: 394 0 22 1 1598969607 0 1 False 12 0 394 active 1
# Inserting Station: 396 0 4 1 1598969559 0 1 False 21 0 396 active 1
# Inserting Station: 397 0 2 1 1598968748 0 1 False 25 0 397 active 1
# Inserting Station: 398 0 17 1 1598969339 0 1 False 13 1 398 active 1
# Inserting Station: 399 0 8 1 1598968217 0 1 False 31 0 399 active 1
# Inserting Station: 400 0 9 1 1598968477 0 1 False 5 1 400 active 1
# Inserting Station: 401 0 15 1 1598968782 0 1 False 26 1 401 active 1
# Inserting Station: 402 1 17 1 1598969706 0 1 False 22 0 402 active 1
# Inserting Station: 403 0 22 1 1598968970 0 1 False 8 1 403 active 1
# Inserting Station: 405 0 29 1 1598968768 0 1 False 21 1 405 active 1
# Inserting Station: 406 0 18 0 1598969420 0 0 False 0 2 406 out_of_service 0
# Inserting Station: 408 0 8 1 1598968903 0 1 False 12 3 408 active 1
# Inserting Station: 410 0 19 1 1598969710 0 1 False 25 1 410 active 1
# Inserting Station: 411 0 11 1 1598969809 0 1 False 18 2 411 active 1
# Inserting Station: 412 0 27 1 1598966770 0 1 False 0 2 412 active 1
# Inserting Station: 415 0 30 1 1598969160 0 1 False 15 1 415 active 1
# Inserting Station: 416 0 2 1 1598968320 0 1 False 29 0 416 active 1
# Inserting Station: 417 0 15 1 1598966948 0 1 False 10 0 417 active 1
# Inserting Station: 418 0 19 1 1598969661 0 1 False 4 0 418 active 1
# Inserting Station: 419 0 16 1 1598968953 0 1 False 7 0 419 active 1
# Inserting Station: 420 0 2 1 1598967968 0 1 False 21 0 420 active 1
# Inserting Station: 421 0 13 1 1598969452 0 1 False 6 0 421 active 1
# Inserting Station: 422 0 28 1 1598969709 0 1 False 49 1 422 active 1
# Inserting Station: 423 0 0 1 1598969563 0 1 False 27 0 423 active 1
# Inserting Station: 426 0 22 1 1598969783 30 1 True 0 1 426 active 1
# Inserting Station: 427 0 40 1 1598969663 0 1 False 6 1 427 active 1
# Inserting Station: 432 0 15 1 1598969256 0 1 False 16 0 432 active 1
# Inserting Station: 434 1 31 1 1598969282 0 1 False 27 2 434 active 1
# Inserting Station: 435 5 40 1 1598969818 0 1 False 8 2 435 active 1
# Inserting Station: 436 0 5 1 1598968533 0 1 False 22 0 436 active 1
# Inserting Station: 437 0 9 1 1598967901 0 1 False 15 0 437 active 1
# Inserting Station: 438 0 25 1 1598969418 0 1 False 21 1 438 active 1
# Inserting Station: 439 0 21 1 1598969418 0 1 False 18 0 439 active 1
# Inserting Station: 440 0 22 1 1598969656 0 1 False 9 1 440 active 1
# Inserting Station: 442 3 13 1 1598969688 0 1 False 38 0 442 active 1
# Inserting Station: 443 0 11 1 1598968395 1 1 False 11 0 443 active 1
# Inserting Station: 445 0 27 1 1598969178 0 1 False 52 1 445 active 1
# Inserting Station: 446 1 30 1 1598969799 0 1 False 49 0 446 active 1
# Inserting Station: 447 1 6 1 1598969625 0 1 False 24 1 447 active 1
# Inserting Station: 448 0 9 1 1598969679 0 1 False 18 0 448 active 1
# Inserting Station: 450 3 19 1 1598969805 0 1 False 38 10 450 active 1
# Inserting Station: 453 0 25 1 1598969794 0 1 False 40 1 453 active 1
# Inserting Station: 454 0 0 1 1598969563 0 1 False 34 1 454 active 1
# Inserting Station: 455 0 14 1 1598969476 0 1 False 43 2 455 active 1
# Inserting Station: 456 7 25 1 1598969780 30 1 False 0 0 456 active 1
# Inserting Station: 458 0 23 1 1598969818 0 1 False 7 1 458 active 1
# Inserting Station: 459 0 28 1 1598969802 0 1 True 21 0 459 active 1
# Inserting Station: 460 1 6 1 1598969733 0 1 False 16 3 460 active 1
# Inserting Station: 461 0 0 0 1597420774 19 0 False 0 0 461 out_of_service 0
# Inserting Station: 462 1 18 1 1598969740 0 1 False 59 0 462 active 1
# Inserting Station: 464 0 6 1 1598969411 0 1 False 47 0 464 active 1
# Inserting Station: 465 0 17 1 1598968879 0 1 False 20 2 465 active 1
# Inserting Station: 466 0 7 1 1598969312 8 1 False 19 1 466 active 1
# Inserting Station: 467 0 11 1 1598968311 0 1 False 23 0 467 active 1
# Inserting Station: 468 0 1 1 1598969731 0 1 False 63 1 468 active 1
# Inserting Station: 469 0 6 1 1598969296 0 0 False 48 3 469 active 0
# Inserting Station: 470 0 29 1 1598969029 0 1 False 41 2 470 active 1
# Inserting Station: 471 0 0 0 86400 0 0 False 0 0 471 out_of_service 0
# Inserting Station: 472 0 42 1 1598969395 0 1 False 11 2 472 active 1
# Inserting Station: 473 0 30 1 1598969327 0 1 False 18 2 473 active 1
# Inserting Station: 474 4 28 1 1598969597 0 1 False 26 2 474 active 1
# Inserting Station: 476 1 40 1 1598969791 0 1 False 19 6 476 active 1
# Inserting Station: 477 7 12 1 1598969533 0 1 False 53 6 477 active 1
# Inserting Station: 478 0 3 1 1598969805 0 1 False 34 0 478 active 1
# Inserting Station: 479 0 1 1 1598969189 0 1 False 28 2 479 active 1
# Inserting Station: 480 0 0 1 1598969752 0 1 False 28 1 480 active 1
# Inserting Station: 481 0 15 1 1598969806 0 1 False 10 0 481 active 1
# Inserting Station: 482 1 58 1 1598969803 0 1 False 19 2 482 active 1
# Inserting Station: 483 0 0 1 1598938901 0 0 False 32 2 483 active 0
# Inserting Station: 484 7 37 1 1598969690 0 1 False 8 1 484 active 1
# Inserting Station: 485 4 24 1 1598969414 0 1 False 14 2 485 active 1
# Inserting Station: 486 1 19 1 1598969175 0 1 False 21 1 486 active 1
# Inserting Station: 487 0 17 1 1598969781 0 1 False 18 0 487 active 1
# Inserting Station: 489 0 29 1 1598969815 0 1 False 18 2 489 active 1
# Inserting Station: 490 11 15 1 1598969666 0 1 False 47 4 490 active 1
# Inserting Station: 491 0 0 0 86400 0 0 False 0 0 491 out_of_service 0
# Inserting Station: 492 2 6 1 1598969671 0 1 False 60 2 492 active 1
# Inserting Station: 493 5 27 1 1598969424 0 1 False 5 2 493 active 1
# Inserting Station: 494 0 2 1 1598969460 0 1 False 62 2 494 active 1
# Inserting Station: 495 0 2 1 1598969469 0 1 False 36 1 495 active 1
# Inserting Station: 496 3 40 1 1598969681 0 1 False 24 1 496 active 1
# Inserting Station: 497 0 39 1 1598969722 0 1 True 27 0 497 active 1
# Inserting Station: 499 0 2 1 1598969796 0 1 True 32 2 499 active 1
# Inserting Station: 500 0 24 1 1598969549 0 1 False 26 2 500 active 1
# Inserting Station: 501 0 1 1 1598969745 0 1 False 75 3 501 active 1
# Inserting Station: 502 0 7 1 1598969691 0 1 False 29 0 502 active 1
# Inserting Station: 503 2 20 1 1598969693 0 1 False 9 2 503 active 1
# Inserting Station: 504 0 25 1 1598969745 0 1 False 27 2 504 active 1
# Inserting Station: 505 0 0 1 1598969742 0 1 False 50 2 505 active 1
# Inserting Station: 507 0 0 0 86400 0 0 False 0 0 507 out_of_service 0
# Inserting Station: 508 0 6 1 1598969659 1 1 False 15 3 508 active 1
# Inserting Station: 509 0 7 1 1598969790 0 1 False 53 1 509 active 1
# Inserting Station: 513 0 1 1 1598969292 0 1 False 27 1 513 active 1
# Inserting Station: 514 0 19 1 1598969633 0 1 False 33 0 514 active 1
# Inserting Station: 515 0 17 1 1598969744 0 1 False 61 1 515 active 1
# Inserting Station: 516 0 13 1 1598969705 0 1 False 16 2 516 active 1
# Inserting Station: 517 4 18 1 1598969776 0 1 False 51 0 517 active 1
# Inserting Station: 518 0 5 1 1598969517 0 1 False 31 3 518 active 1
# Inserting Station: 519 6 24 1 1598969698 46 1 False 0 3 519 active 1
# Inserting Station: 522 2 27 1 1598969811 0 1 False 22 2 522 active 1
# Inserting Station: 525 2 21 1 1598969587 0 1 False 34 1 525 active 1
# Inserting Station: 526 1 19 1 1598969817 0 1 False 21 0 526 active 1
# Inserting Station: 528 2 24 1 1598969741 0 1 False 12 3 528 active 1
# Inserting Station: 529 0 3 1 1598969459 0 1 False 38 0 529 active 1
# Inserting Station: 530 0 0 1 1598969230 0 1 False 24 0 530 active 1
# Inserting Station: 531 0 37 1 1598969760 0 1 False 0 2 531 active 1
# Inserting Station: 532 0 17 1 1598969550 0 1 False 24 2 532 active 1
# Inserting Station: 533 4 29 1 1598969700 0 1 False 1 3 533 active 1
# Inserting Station: 534 3 18 1 1598967118 0 1 False 12 1 534 active 1
# Inserting Station: 536 1 27 1 1598969546 0 1 False 1 0 536 active 1
# Inserting Station: 539 1 18 1 1598969632 0 1 False 13 0 539 active 1
# Inserting Station: 540 0 40 1 1598969793 0 1 False 3 3 540 active 1
# Inserting Station: 545 1 13 1 1598969372 0 1 False 12 2 545 active 1
# Inserting Station: 546 0 21 1 1598968953 0 1 False 24 0 546 active 1
# Inserting Station: 2000 1 23 1 1598969695 0 1 False 7 0 2000 active 1
# Inserting Station: 2002 0 23 1 1598967648 0 1 False 4 0 2002 active 1
# Inserting Station: 2003 1 22 1 1598969711 0 1 False 30 2 2003 active 1
# Inserting Station: 2005 0 7 1 1598969160 0 1 False 4 1 2005 active 1
# Inserting Station: 2006 1 9 1 1598969807 0 1 True 38 2 2006 active 1
# Inserting Station: 2008 0 6 1 1598969791 0 1 False 17 1 2008 active 1
# Inserting Station: 2009 0 26 1 1598969693 1 1 False 8 0 2009 active 1
# Inserting Station: 2010 0 20 1 1598969551 0 1 False 16 3 2010 active 1
# Inserting Station: 2012 2 18 1 1598969582 18 1 False 0 3 2012 active 1
# Inserting Station: 2017 0 30 1 1598969518 0 1 False 9 0 2017 active 1
# Inserting Station: 2021 0 0 1 1598969147 0 1 False 63 2 2021 active 1
# Inserting Station: 2022 1 3 1 1598969772 0 1 False 30 0 2022 active 1
# Inserting Station: 3016 0 46 1 1598969453 0 1 False 7 1 3016 active 1
# Inserting Station: 3041 0 2 1 1598966618 0 1 False 22 0 3041 active 1
# Inserting Station: 3042 1 14 1 1598966871 0 1 False 5 0 3042 active 1
# Inserting Station: 3043 0 4 1 1598968249 0 1 False 15 0 3043 active 1
# Inserting Station: 3044 0 1 1 1598965854 0 1 False 26 0 3044 active 1
# Inserting Station: 3046 0 8 1 1598969190 0 1 False 11 0 3046 active 1
# Inserting Station: 3047 0 14 1 1598966494 0 1 False 4 3 3047 active 1
# Inserting Station: 3048 0 5 1 1598969105 0 1 False 14 0 3048 active 1
# Inserting Station: 3049 0 10 1 1598969305 0 1 False 8 0 3049 active 1
# Inserting Station: 3050 0 8 1 1598967724 0 1 False 13 0 3050 active 1
# Inserting Station: 3052 0 1 1 1598967560 0 1 False 21 1 3052 active 1
# Inserting Station: 3053 1 12 1 1598969382 0 1 False 10 1 3053 active 1
# Inserting Station: 3054 0 9 1 1598969713 0 1 False 10 0 3054 active 1
# Inserting Station: 3055 0 6 1 1598968364 0 1 False 17 0 3055 active 1
# Inserting Station: 3056 0 19 1 1598969707 0 1 False 2 2 3056 active 1
# Inserting Station: 3107 0 37 1 1598969768 0 1 False 2 0 3107 active 1
# Inserting Station: 3108 0 44 1 1598969345 0 1 False 6 1 3108 active 1
# Inserting Station: 3109 0 25 1 1598969355 0 1 False 6 0 3109 active 1
# Inserting Station: 3110 1 25 1 1598969595 0 1 False 2 1 3110 active 1
# Inserting Station: 3112 1 32 1 1598969131 0 1 False 0 1 3112 active 1
# Inserting Station: 3113 0 26 1 1598969010 0 1 False 0 1 3113 active 1
# Inserting Station: 3115 0 43 1 1598969767 0 1 False 6 1 3115 active 1
# Inserting Station: 3116 0 32 1 1598969724 0 1 False 3 0 3116 active 1
# Inserting Station: 3117 0 17 1 1598969548 0 1 False 8 2 3117 active 1
# Inserting Station: 3118 0 0 0 86400 0 0 False 0 0 3118 out_of_service 0
# Inserting Station: 3119 1 19 1 1598966090 0 1 False 25 1 3119 active 1
# Inserting Station: 3121 0 14 1 1598967255 0 1 False 13 0 3121 active 1
# Inserting Station: 3122 0 4 1 1598969505 0 1 False 72 3 3122 active 1
# Inserting Station: 3123 1 32 1 1598966006 0 1 False 15 0 3123 active 1
# Inserting Station: 3124 0 2 1 1598968364 0 1 False 40 1 3124 active 1
# Inserting Station: 3125 0 8 1 1598968968 0 1 False 15 0 3125 active 1
# Inserting Station: 3126 0 15 1 1598969042 0 1 False 19 0 3126 active 1
# Inserting Station: 3127 0 0 1 1598969087 0 1 False 35 0 3127 active 1
# Inserting Station: 3128 2 10 1 1598969025 0 1 False 17 0 3128 active 1
# Inserting Station: 3129 0 8 1 1598969474 0 1 False 22 1 3129 active 1
# Inserting Station: 3130 0 8 1 1598969055 0 1 False 22 0 3130 active 1
# Inserting Station: 3131 0 0 1 1598967390 0 1 False 30 1 3131 active 1
# Inserting Station: 3132 1 18 1 1598969590 0 1 False 15 2 3132 active 1
# Inserting Station: 3134 1 8 1 1598969723 0 1 False 43 0 3134 active 1
# Inserting Station: 3135 0 3 1 1598969669 0 1 False 38 0 3135 active 1
# Inserting Station: 3136 0 6 1 1598969069 0 1 False 41 0 3136 active 1
# Inserting Station: 3137 1 11 1 1598969676 0 1 True 20 0 3137 active 1
# Inserting Station: 3139 1 6 1 1598969338 0 1 False 37 0 3139 active 1
# Inserting Station: 3140 0 1 1 1598969785 0 1 False 51 3 3140 active 1
# Inserting Station: 3141 4 5 1 1598969672 33 1 False 19 1 3141 active 1
# Inserting Station: 3142 0 0 1 1598969190 0 1 False 41 0 3142 active 1
# Inserting Station: 3143 5 46 1 1598968550 0 0 False 0 1 3143 active 0
# Inserting Station: 3144 0 1 1 1598969707 0 1 False 45 0 3144 active 1
# Inserting Station: 3145 0 3 1 1598969514 0 1 False 41 1 3145 active 1
# Inserting Station: 3146 0 2 1 1598969227 0 1 False 45 0 3146 active 1
# Inserting Station: 3147 1 2 1 1598969805 0 1 False 37 0 3147 active 1
# Inserting Station: 3148 1 7 1 1598969556 0 1 False 21 3 3148 active 1
# Inserting Station: 3150 0 0 1 1598967960 0 1 False 45 2 3150 active 1
# Inserting Station: 3363 0 11 1 1598969543 0 1 False 22 0 3363 active 1
# Inserting Station: 3364 1 24 1 1598966709 0 1 False 2 1 3364 active 1
# Inserting Station: 3365 1 4 1 1598969770 0 1 False 23 0 3365 active 1
# Inserting Station: 3366 0 4 1 1598968984 0 1 False 26 1 3366 active 1
# Inserting Station: 3367 4 34 1 1598969447 39 1 True 0 0 3367 active 1
# Inserting Station: 3368 0 22 1 1598968390 0 1 False 8 0 3368 active 1
# Inserting Station: 3369 0 1 1 1598969044 0 1 False 28 0 3369 active 1
# Inserting Station: 3370 0 2 1 1598968329 0 1 False 22 1 3370 active 1
# Inserting Station: 3372 0 3 1 1598969121 0 1 False 33 3 3372 active 1
# Inserting Station: 3373 0 25 1 1598969684 0 1 False 1 1 3373 active 1
# Inserting Station: 3374 1 26 1 1598969555 0 1 True 10 0 3374 active 1
# Inserting Station: 3375 0 3 1 1598969059 0 1 False 30 2 3375 active 1
# Inserting Station: 3376 1 2 1 1598969719 0 1 False 37 0 3376 active 1
# Inserting Station: 3377 0 19 1 1598969302 0 1 False 5 1 3377 active 1
# Inserting Station: 3378 0 8 1 1598969588 0 1 False 19 1 3378 active 1
# Inserting Station: 3379 0 13 1 1598969453 0 1 False 22 0 3379 active 1
# Inserting Station: 3381 0 20 1 1598967129 0 1 False 0 1 3381 active 1
# Inserting Station: 3382 0 0 0 1597683895 0 0 False 15 0 3382 out_of_service 0
# Inserting Station: 3383 0 4 1 1598969325 0 1 False 21 0 3383 active 1
# Inserting Station: 3384 0 23 1 1598968618 0 1 False 1 1 3384 active 1
# Inserting Station: 3386 1 21 1 1598969328 0 1 False 6 0 3386 active 1
# Inserting Station: 3387 0 7 1 1598969621 0 1 False 18 0 3387 active 1
# Inserting Station: 3388 0 24 1 1598965883 0 1 False 1 0 3388 active 1
# Inserting Station: 3389 0 0 0 86400 0 0 False 0 0 3389 out_of_service 0
# Inserting Station: 3390 0 19 1 1598968454 0 1 False 5 0 3390 active 1
# Inserting Station: 3391 0 14 1 1598968024 0 1 False 11 0 3391 active 1
# Inserting Station: 3392 0 18 1 1598967642 0 1 False 0 1 3392 active 1
# Inserting Station: 3393 1 15 1 1598969613 0 1 False 4 0 3393 active 1
# Inserting Station: 3394 1 21 1 1598969085 0 1 False 0 0 3394 active 1
# Inserting Station: 3395 1 16 1 1598967070 0 1 False 3 0 3395 active 1
# Inserting Station: 3396 0 18 1 1598967631 0 1 False 5 2 3396 active 1
# Inserting Station: 3397 0 20 1 1598969661 0 1 False 5 0 3397 active 1
# Inserting Station: 3398 0 14 1 1598968954 0 1 False 8 1 3398 active 1
# Inserting Station: 3399 1 23 1 1598968181 0 1 False 1 0 3399 active 1
# Inserting Station: 3400 0 8 1 1598969060 0 1 False 16 0 3400 active 1
# Inserting Station: 3402 0 21 1 1598969816 0 1 False 2 0 3402 active 1
# Inserting Station: 3403 0 28 1 1598968554 0 1 False 3 0 3403 active 1
# Inserting Station: 3404 0 23 1 1598968307 0 1 False 4 0 3404 active 1
# Inserting Station: 3405 0 17 1 1598968416 0 1 False 5 1 3405 active 1
# Inserting Station: 3980 0 5 1 1598967665 0 1 False 15 0 3980 active 1
# Inserting Station: 3981 1 3 1 1598969318 0 1 False 21 0 3981 active 1
# Inserting Station: 3982 0 10 1 1598949691 0 1 False 11 0 3982 active 1
# Inserting Station: 3983 2 4 1 1598969723 0 1 False 19 0 3983 active 1
# Inserting Station: 3984 0 3 1 1598969269 0 1 False 20 0 3984 active 1
# Inserting Station: 3985 3 6 1 1598966669 0 1 False 16 0 3985 active 1
# Inserting Station: 3986 5 27 1 1598967818 0 1 False 7 1 3986 active 1
# Inserting Station: 3987 1 14 1 1598965888 0 1 False 9 0 3987 active 1
# Inserting Station: 3988 0 18 1 1598948642 0 1 False 1 0 3988 active 1
# Inserting Station: 3989 0 11 1 1598968409 0 1 False 11 0 3989 active 1
# Inserting Station: 3992 0 40 1 1598969653 0 1 False 6 1 3992 active 1
# Inserting Station: 3994 0 15 1 1598967325 0 1 False 14 1 3994 active 1
# Inserting Station: 3995 1 6 1 1598969646 0 1 False 14 1 3995 active 1
# Inserting Station: 3996 2 24 1 1598963904 0 1 False 0 0 3996 active 1
# Inserting Station: 3997 1 11 1 1598967645 0 1 False 7 2 3997 active 1
# Inserting Station: 3998 2 10 1 1598968304 0 1 False 18 1 3998 active 1
# Inserting Station: 3999 0 8 1 1598969696 0 1 False 15 0 3999 active 1
# Inserting Station: 4000 0 20 1 1598959604 0 1 False 2 0 4000 active 1
# Inserting Station: 4001 0 15 1 1598964106 0 1 False 9 0 4001 active 1
# Inserting Station: 4002 0 17 1 1598968969 0 1 False 6 1 4002 active 1
# Inserting Station: 4004 0 11 1 1598969515 0 1 False 9 1 4004 active 1
# Inserting Station: 4005 0 0 1 1598949748 0 1 False 24 0 4005 active 1
# Inserting Station: 4006 0 4 1 1598968536 0 1 False 21 0 4006 active 1
# Inserting Station: 4007 1 4 1 1598969105 0 1 False 25 1 4007 active 1
# Inserting Station: 4008 0 0 0 86400 0 0 False 0 0 4008 out_of_service 0
# Inserting Station: 4009 1 11 1 1598969761 0 1 False 24 0 4009 active 1
# Inserting Station: 4010 1 1 1 1598969513 0 1 False 23 0 4010 active 1
# Inserting Station: 4011 0 2 1 1598964098 0 1 False 23 0 4011 active 1
# Inserting Station: 4012 1 7 1 1598969801 0 1 False 16 0 4012 active 1
# Inserting Station: 4013 0 0 1 1598965197 0 1 False 23 1 4013 active 1
# Inserting Station: 4014 3 14 1 1598968854 0 1 False 8 0 4014 active 1
# Inserting Station: 4015 0 12 1 1598968741 0 1 False 19 0 4015 active 1
# Inserting Station: 4016 0 3 1 1598969040 0 1 False 19 0 4016 active 1
# Inserting Station: 4017 0 0 1 1598969798 4 1 False 0 18 4017 active 1
# Inserting Station: 4018 2 10 1 1598969299 0 1 False 11 0 4018 active 1
# Inserting Station: 4019 0 16 1 1598964483 0 1 False 1 0 4019 active 1
# Inserting Station: 4020 0 12 1 1598969463 0 1 False 10 0 4020 active 1
# Inserting Station: 4021 0 13 1 1598949665 0 1 False 8 0 4021 active 1
# Inserting Station: 4022 0 0 0 86400 0 0 False 0 0 4022 out_of_service 0
# Inserting Station: 4023 0 18 1 1598968823 0 1 False 5 1 4023 active 1
# Inserting Station: 4024 0 8 1 1598965214 0 1 False 25 0 4024 active 1
# Inserting Station: 4025 0 0 1 1598968008 0 1 False 20 0 4025 active 1
# Inserting Station: 4027 0 1 1 1598968755 0 1 False 22 0 4027 active 1
# Inserting Station: 4028 1 12 1 1598958965 0 1 False 7 0 4028 active 1
# Inserting Station: 4029 0 4 1 1598969425 0 1 False 18 1 4029 active 1
# Inserting Station: 4030 0 0 0 86400 0 0 False 0 0 4030 out_of_service 0
# Inserting Station: 4031 0 0 1 1598964327 0 1 False 19 0 4031 active 1
# Inserting Station: 4032 2 9 1 1598969358 0 1 False 10 0 4032 active 1
# Inserting Station: 4034 2 4 1 1598965474 0 1 False 23 0 4034 active 1
# Inserting Station: 4035 0 1 1 1598968458 0 1 False 19 0 4035 active 1
# Inserting Station: 4036 0 34 1 1598968623 0 1 False 2 0 4036 active 1
# Inserting Station: 4037 0 31 1 1598967430 0 1 False 8 0 4037 active 1
# Inserting Station: 4038 0 25 1 1598968063 0 1 False 3 1 4038 active 1
# Inserting Station: 4040 2 22 1 1598968595 0 0 False 27 2 4040 active 0
# Inserting Station: 4041 0 11 1 1598968689 0 1 False 6 1 4041 active 1
# Inserting Station: 4043 1 7 1 1598969427 0 1 False 17 0 4043 active 1
# Inserting Station: 4044 2 16 1 1598969749 0 1 False 28 5 4044 active 1
# Inserting Station: 4045 0 18 1 1598969815 0 1 False 20 1 4045 active 1
# Inserting Station: 4047 0 4 1 1598965824 0 1 False 20 3 4047 active 1
# Inserting Station: 4048 2 14 1 1598968925 0 1 False 5 1 4048 active 1
# Inserting Station: 4050 0 0 0 86400 0 0 False 0 0 4050 out_of_service 0
# Inserting Station: 4051 0 2 1 1598968162 0 1 False 23 1 4051 active 1
# Inserting Station: 4052 1 27 1 1598969263 0 1 False 0 0 4052 active 1
# Inserting Station: 4053 0 3 1 1598949686 0 1 False 16 0 4053 active 1
# Inserting Station: 4054 2 16 1 1598966856 0 1 False 3 0 4054 active 1
# Inserting Station: 4055 5 10 1 1598969732 0 1 False 17 0 4055 active 1
# Inserting Station: 4056 0 5 1 1598965774 0 1 False 17 2 4056 active 1
# Inserting Station: 4057 0 1 1 1598969271 0 1 False 22 0 4057 active 1
# Inserting Station: 4058 5 27 1 1598969757 0 1 False 14 0 4058 active 1
# Inserting Station: 4059 13 29 0 1598968996 0 0 False 1 1 4059 out_of_service 0
# Inserting Station: 4060 0 5 1 1598969669 0 1 False 18 0 4060 active 1
# Inserting Station: 4061 0 6 1 1598969653 1 1 False 17 0 4061 active 1
# Inserting Station: 4062 3 8 1 1598968765 0 1 False 15 0 4062 active 1
# Inserting Station: 4063 0 13 1 1598969778 0 1 False 11 0 4063 active 1
# Inserting Station: 4064 0 1 1 1598949690 0 1 False 22 0 4064 active 1
# Inserting Station: 4065 1 15 1 1598969784 0 1 False 20 0 4065 active 1
# Inserting Station: 4066 0 1 1 1598949801 0 1 False 22 0 4066 active 1
# Inserting Station: 4067 1 4 1 1598949825 0 1 False 19 0 4067 active 1
# Inserting Station: 4068 3 7 1 1598968815 0 1 False 23 0 4068 active 1
# Inserting Station: 4069 0 0 1 1598949643 0 1 False 23 1 4069 active 1
# Inserting Station: 4070 1 14 1 1598969637 0 1 False 9 1 4070 active 1
# Inserting Station: 4071 0 6 1 1598969607 0 1 False 15 1 4071 active 1
# Inserting Station: 4072 4 13 1 1598969812 0 1 False 27 0 4072 active 1
# Inserting Station: 4073 3 15 1 1598969811 0 1 False 20 0 4073 active 1
# Inserting Station: 4074 0 0 1 1598949755 0 1 False 22 1 4074 active 1
# Inserting Station: 4075 0 1 1 1598969370 0 1 True 35 1 4075 active 1
# Inserting Station: 4076 2 26 1 1598967754 0 1 False 3 0 4076 active 1
# Inserting Station: 4079 1 2 1 1598969450 0 1 False 19 0 4079 active 1
# Inserting Station: 4080 0 0 0 86400 0 0 False 0 0 4080 out_of_service 0
# Inserting Station: 4081 1 10 1 1598965740 0 1 False 11 0 4081 active 1
# Inserting Station: 4082 1 16 1 1598967821 0 1 False 13 1 4082 active 1
# Inserting Station: 4083 0 0 0 86400 0 0 False 0 0 4083 out_of_service 0
# Inserting Station: 4084 1 5 1 1598963121 0 1 False 17 0 4084 active 1
# Inserting Station: 4085 5 14 1 1598966100 0 1 False 11 0 4085 active 1
# Inserting Station: 4086 0 2 1 1598949744 0 1 False 19 0 4086 active 1
# Inserting Station: 4087 2 18 1 1598968908 0 1 False 4 0 4087 active 1
# Inserting Station: 4088 0 1 1 1598963191 0 1 False 19 0 4088 active 1
# Inserting Station: 4090 2 3 1 1598969233 0 1 False 18 0 4090 active 1
# Inserting Station: 4091 0 0 0 1598969453 1 0 False 0 20 4091 out_of_service 0
# Inserting Station: 4092 0 0 0 1598562341 0 0 False 3 0 4092 out_of_service 0
# Inserting Station: 4093 0 0 0 86400 0 0 False 0 0 4093 out_of_service 0
# Inserting Station: 4094 0 0 0 86400 0 0 False 0 0 4094 out_of_service 0
# Inserting Station: 4095 0 0 0 86400 0 0 False 0 0 4095 out_of_service 0
# Inserting Station: 4096 3 10 1 1598966748 0 1 False 20 0 4096 active 1
# Inserting Station: 4098 0 3 1 1598949713 0 1 False 16 1 4098 active 1
# Inserting Station: 4099 1 17 1 1598968866 0 1 False 3 1 4099 active 1
# Inserting Station: 4101 1 2 0 1598949761 0 0 False 17 0 4101 out_of_service 0
# Inserting Station: 4102 0 0 0 86400 0 0 False 0 0 4102 out_of_service 0
# Inserting Station: 4103 0 17 1 1598967578 0 1 False 2 0 4103 active 1
# Inserting Station: 4104 0 0 1 1598949708 0 1 False 20 0 4104 active 1
# Inserting Station: 4105 0 0 0 86400 0 0 False 0 0 4105 out_of_service 0
# Inserting Station: 4106 2 18 1 1598964563 0 1 False 1 0 4106 active 1
# Inserting Station: 4107 0 0 0 86400 0 0 False 0 0 4107 out_of_service 0
# Inserting Station: 4108 0 0 0 86400 0 0 False 0 0 4108 out_of_service 0
# Inserting Station: 4109 8 13 1 1598962635 0 1 False 6 2 4109 active 1
# Inserting Station: 4110 0 6 1 1598969280 0 1 False 24 0 4110 active 1
# Inserting Station: 4112 0 0 0 86400 0 0 False 0 0 4112 out_of_service 0
# Inserting Station: 4113 0 0 0 86400 0 0 False 0 0 4113 out_of_service 0
# Inserting Station: 4114 0 0 0 86400 0 0 False 0 0 4114 out_of_service 0
# Inserting Station: 4115 0 0 0 86400 0 0 False 0 0 4115 out_of_service 0
# Inserting Station: 4116 0 6 1 1598949751 0 1 False 13 0 4116 active 1
# Inserting Station: 4122 0 0 1 1598969760 0 1 True 49 4 4122 active 1
# Inserting Station: 4123 0 1 1 1598968345 0 1 False 57 0 4123 active 1
# Inserting Station: 4124 0 2 1 1598969604 0 1 False 44 2 4124 active 1
# Inserting Station: 4125 0 0 0 1598559083 0 0 False 3 0 4125 out_of_service 0
# Inserting Station: 4126 0 0 0 86400 0 0 False 0 0 4126 out_of_service 0
# Inserting Station: 4127 0 0 0 86400 0 0 False 0 0 4127 out_of_service 0
# Inserting Station: 4128 0 0 0 86400 0 0 False 0 0 4128 out_of_service 0
# Inserting Station: 4130 0 0 0 1598889239 0 0 False 3 0 4130 out_of_service 0
# Inserting Station: 4131 0 0 0 86400 0 0 False 0 0 4131 out_of_service 0
# Inserting Station: 4132 0 0 0 86400 0 0 False 0 0 4132 out_of_service 0
# Inserting Station: 4133 0 0 0 86400 0 0 False 0 0 4133 out_of_service 0
# Inserting Station: 4134 0 0 0 86400 0 0 False 0 0 4134 out_of_service 0
# Inserting Station: 4135 0 0 0 86400 0 0 False 0 0 4135 out_of_service 0
# Inserting Station: 4137 0 0 0 86400 0 0 False 0 0 4137 out_of_service 0
# Inserting Station: 4139 0 0 0 86400 0 0 False 0 0 4139 out_of_service 0
# Inserting Station: 4140 0 0 0 86400 0 0 False 0 0 4140 out_of_service 0
# Inserting Station: 4141 0 0 0 86400 0 0 False 0 0 4141 out_of_service 0
# Inserting Station: 4144 0 0 0 86400 0 0 False 0 0 4144 out_of_service 0
# Inserting Station: 4147 0 0 0 86400 0 0 False 0 0 4147 out_of_service 0
# Inserting Station: 4148 0 0 0 86400 0 0 False 0 0 4148 out_of_service 0
# Inserting Station: 4150 0 0 0 86400 0 0 False 0 0 4150 out_of_service 0
# Inserting Station: 4151 0 0 0 86400 0 0 False 0 0 4151 out_of_service 0
# Inserting Station: 4153 0 0 0 86400 0 0 False 0 0 4153 out_of_service 0
# Inserting Station: 4155 0 0 0 86400 0 0 False 0 0 4155 out_of_service 0
# Inserting Station: 4165 0 0 0 86400 0 0 False 0 0 4165 out_of_service 0
# Inserting Station: 4166 0 0 0 86400 0 0 False 0 0 4166 out_of_service 0
# Inserting Station: 4167 0 0 0 86400 0 0 False 0 0 4167 out_of_service 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-0b44c0d93a27> in <module>()
#      37     con.commit()
#      38
# ---> 39     time.sleep(15)
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %% [markdown]
# I hope this has helped you find your programming legs! Next week we'll get back to descriptive analytics using Python and Pandas. For now, take time to refresh yourself on the content covered in "Introduction to Programming".
#
# If you need a referesher on your SQL skills, check out the "Supplementary Info" directory in the class repo.
