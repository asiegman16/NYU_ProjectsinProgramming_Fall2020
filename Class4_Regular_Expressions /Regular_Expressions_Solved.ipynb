# %% [markdown]
# # Regular Expressions

# %% [markdown]
# ---

# %% [markdown]
# Regular expressions (regex's) are like pattern matchers – they allow us to match certain texts within a larger block of text. But, unlike a Command+F search, regular expressions allow you to be flexible.
#
# To best understand, let's delve right into an example.
#
# The code below from Panos Ipeirotis is written in Python to replicate the behavior of grep, a UNIX utility. Grep (Global Search with Regular Expression and Printing Matching Lines) searches the named input files for lines containing a match to the given pattern.
#
# By default, grep prints the matching lines.

# %%
import re # https://docs.python.org/3/library/re.html

def printMatches(text, regex_expression):
    BACKGROUND_YELLOW = '\x1b[43m'
    COLOR_RESET  = "\x1b[0m"
    regex= re.compile(regex_expression)
    matches = regex.finditer(text)
    for m in matches:
        highlighted  = text[:m.start()] # the string before the regex match
        highlighted += BACKGROUND_YELLOW + text[m.start():m.end()] + COLOR_RESET 
        highlighted += text[m.end():] # the string after the regex match
        print(highlighted)
        print('\n')

def grep(regex_expression, file_name):
    f = open(file_name, "r")
    content = f.read()
    f.close()
    for line in content.split("\n"):
        printMatches(line, regex_expression)

# %% [markdown]
# ---

# %% [markdown]
# For today's class, we'll be taking a look at  the ["Capital Project Tracker" from NYC Open Data.](https://data.cityofnewyork.us/Recreation/Capital-Project-Tracker/qiwj-i2jk)
#
# One of the first things you may want to do is search for a literal – simply match the exact text in the document in question. For instance, if we want to find any mention of the word, "Highway"...
#
# _Note that we have uploaded our "ParkProjects.txt" file directly into our Colab instance so that we can search it._

# %%
grep('Highway', './ParkProjects.txt')
# Out:
# Summary This project will reconstruct the east and west Ocean Parkway Malls from Avenue O to Kings Highway with new asphalt pavement, pipe handrails, trees, benches, signage, greenway markings and curbs; expanded tree pits and restored granite block pavers and a mile marker. This project will also reconstruct the handball and basketball courts, paving, fencing, gates and landscaping and construct a new ADA-accessible drinking fountain in Colonel David Marcus Playground.
#
#
# name Between Avenue P and Kings Highway
#
#
# name Plimpton Avenue between West 170th Street and Edward L Grant Highway.
#
#
# name Nostrand Avenue between Kings Highway and Avenue P, Brooklyn
#
#
# name Edward L. Grant Highway and Plimpton Avenue
#
#
# name Kings Highway, Avenue H, East 49th Street

# %% [markdown]
# That's all fine and well, but the goal here is to leverage the power and flexibility of regular expressions. That's where atoms come into play.
#
# The simplest regular expressions are a sequence of "atoms".

# %% [markdown]
# ## The dot (.) atom
#
# Matches any single character other than \n (newline)

# %%
grep('Avenue . and', './ParkProjects.txt')
# Out:
# name East 71st Street between Avenue N and Avenue T
#
#
# name Between Avenue P and Kings Highway
#
#
# name Szold Place, Avenue D and East 10th Street
#
#
# name Avenue L and East 4th Street
#
#
# name Avenue U and East 33rd Street
#
#
# name McDonald Avenue between Avenue S and Avenue T
#
#
# name Ocean Parkway between Avenue R and Avenue X
#
#
# name Avenue V and West 13th Street
#
#
# name East 9th Street between Avenue A and Avenue B
#
#
# name East 6th Street between Avenue B and Avenue C

# %%
grep('Avenue . and Avenue .', './ParkProjects.txt')
# Out:
# name East 71st Street between Avenue N and Avenue T
#
#
# name McDonald Avenue between Avenue S and Avenue T
#
#
# name Ocean Parkway between Avenue R and Avenue X
#
#
# name East 9th Street between Avenue A and Avenue B
#
#
# name East 6th Street between Avenue B and Avenue C

# %% [markdown]
# ## The bracket expression
#
# Defines a set of characters of which only one needs to be matched

# %%
grep('Avenue [FG]', './ParkProjects.txt')
# Out:
# name McDonald Avenue and Avenue F
#
#
# Title Yellowstone Park 68th Avenue Fencing Reconstruction
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Yellowstone Park 68th Avenue Fencing Reconstruction Rendering_20190516_Q.jpg

# %%
grep('[Pp]layground', './ParkProjects.txt')
# Out:
# Title Abraham Lincoln Playground Reconstruction
#
#
# Summary This project will reconstruct Abraham Lincoln Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Abraham Lincoln Playground Reconstruction Schematic_20171127_M.jpg
#
#
# Title Abraham Lincoln Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station in Abraham Lincoln Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Abraham Lincoln Playground Comfort Station Reconstruction Rendering_20170821_A.jpg
#
#
# Title Agnes Haywood Playground Reconstruction
#
#
# Summary This project will reconstruct Agnes Haywood Playground.
#
#
# Title Al Stabile Playground Reconstruction
#
#
# Summary This project will reconstruct Al Stabile Playground.
#
#
# Title Albemarle Playground Synthetic Turf Field and Basketball Court Reconstruction
#
#
# Summary This project will reconstruct the synthetic turf field, basketball court, and drainage systems in Albemarle Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Albemarle Playground Synthetic Turf Field and Basketball Court Reconstruction Schematic_20190207_B.jpg
#
#
# Summary This project will reconstruct parks, playgrounds and site work at various sites in the Bronx.
#
#
# Summary This project will construct new fitness equipment at Alley Pond Park and Alley Athletic Playground, reconstruct the seating area at One Room Schoolhouse Park, and construct a new meditation garden at Kissena Corridor Park.
#
#
# Title Almeda Playground Reconstruction
#
#
# Summary This project will reconstruct Almeda Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Almeda Playground Reconstruction Schematic_20170821_Q.jpg
#
#
# Title Morton Playground Reconstruction
#
#
# Summary This project will reconstruct Morton Playground, including the basketball courts, play equipment, safety surface, water and drainage systems, park lighting, and landscaping.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Morton Playground Reconstruction Schematic_20190919_X.jpg
#
#
# Title Arrochar Playground Pavement Reconstruction
#
#
# Summary This project will reconstruct the pavement at Arrochar Playground.
#
#
# Title Arrochar Playground and Grandview Playground Comfort Station Reconstruction
#
#
# Title Arrochar Playground and Grandview Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort stations at Arrochar Playground and Grandview Playground.
#
#
# Summary This project will reconstruct the comfort stations at Arrochar Playground and Grandview Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Arrochar Playground and Grandview Playground Comfort Station Reconstruction Schematic_20171218_A.jpg
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Arrochar Playground and Grandview Playground Comfort Station Reconstruction Schematic_20171218_A.jpg
#
#
# Title Arrochar Playground Reconstruction
#
#
# Summary This project will reconstruct the playground and multi-use area at Arrochar Playground adjacent to PS 39.
#
#
# Summary This project will reconstruct the playground and multi-use area at Arrochar Playground adjacent to PS 39.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Arrochar Playground Reconstruction Schematic_20160411_R.jpg
#
#
# Title Dekovats Playground Safety Surfacing Reconstruction
#
#
# Summary This project will reconstruct the safety surfacing at Dekovats Playground.
#
#
# Title Asser Levy Park Playground & Path Reconstruction
#
#
# Summary This project will reconstruct the playground and adjacent paths in Asser Levy Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Asser Levy Park Playground & Path Reconstruction Schematic_20170321_B.jpg
#
#
# Title Asser Levy Playground Expansion
#
#
# Summary This project will expand Asser Levy Playground into the roadbed of Asser Levy Place and construct a new artificial turf field and exercise track, new adult fitness equipment, benches, tables, drinking fountains, park lighting and trees.
#
#
# Title Astoria Health Playground Reconstruction
#
#
# Summary This project will reconstruct Astoria Health Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Astoria Health Playground Reconstruction Schematic_20170321_Q.jpg
#
#
# Title Astoria Heights and Bowne Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort stations at Astoria Heights Playground and Bowne Playground.
#
#
# Summary This project will reconstruct the comfort stations at Astoria Heights Playground and Bowne Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Astoria Heights Playground Comfort Station Reconstruction Rendering_20170327_A.jpg
#
#
# Title Astoria Heights-JHS10 Playground Reconstruction
#
#
# Summary This project will reconstruct Astoria Heights Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Astoria Heights-JHS10 Playground Reconstruction Schematic_20160411_Q.jpg
#
#
# Summary This project will construct portions of the Queens East River and North Shore Greenway in Queensbridge Park, Rainey Park, Hallets Cove Playground, Astoria Park and Ralph Demarco Park.
#
#
# Title Astoria Park Charybdis Playground Reconstruction and Spray Shower Construction
#
#
# Summary This project will reconstruct Charybdis Playground and construct a spray shower in Astoria Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Astoria Park Charybdis Playground Reconstruction and Spray Shower Construction Schematic_20180409_Q.jpg
#
#
# Title Astoria Park Charybdis Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at Charybdis Playground in Astoria Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Astoria Park Charybdis Playground Comfort Station Reconstruction Schematic_20180409_Q.jpg
#
#
# Title Arrow Recreation Center Playground Reconstruction
#
#
# Summary This project will reconstruct the playground at Arrow Recreation Center.
#
#
# Title Athens Square Playground Plaza Reconstruction
#
#
# Summary This project will reconstruct the plaza and adjacent seating area in Athens Square Playground.  The cheek walls on either side of the two ramps will be reconstructed and a new ramp will be constructed between the seating area and the plaza.  New handrails will be installed, 2 1/2 foot fencing will be placed around plant beds, plant material will be replaced as needed, and a trench drain will be installed near the spray shower to keep water from flowing onto the safety surface.
#
#
# Title Audubon Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at Audubon Playground and make it ADA accessible.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Audubon Playground Comfort Station Reconstruction Schematic_20170821_M.jpg
#
#
# Title Audubon Playground Reconstruction
#
#
# Summary This project will reconstruct Audubon Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Audubon Playground Play Area Reconstruction_20190207_M.jpg
#
#
# Title Levy Playground, McDonald Park and DeMatti Playground Comfort Station Reconstruction
#
#
# Title Levy Playground, McDonald Park and DeMatti Playground Comfort Station Reconstruction
#
#
# Title Austin J. McDonald Park Playground and Multi-Use Area Reconstruction
#
#
# Summary This project will reconstruct the playground and multi-use area at McDonald Playground.
#
#
# Summary This project will reconstruct the playground and multi-use area at McDonald Playground.
#
#
# Title Babi Yar Triangle Playground Reconstruction
#
#
# Summary This project will reconstruct the playground and seating area at Babi Yar Triangle.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Babi Yar Triangle Playground Reconstruction Schematic_20180409_B.jpg
#
#
# Summary This project will reconstruct tennis, basketball and handball courts in Baisley Pond Park; basketball courts and an entry ramp at Police Officer Nicholas Demutiis Playground; and basketball and handball courts at Harvard Playground in Queens.
#
#
# Summary This project will reconstruct tennis, basketball and handball courts in Baisley Pond Park; basketball courts and an entry ramp at Police Officer Nicholas Demutiis Playground; and basketball and handball courts at Harvard Playground in Queens.
#
#
# Title Banneker Playground Comfort Station Roof Reconstruction
#
#
# Summary This project will reconstruct the roof at the comfort station in Banneker Playground.
#
#
# Title Banneker Playground and Tilden Playground Comfort Station Reconstruction
#
#
# Title Banneker Playground and Tilden Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort stations at Banneker Playground and Tilden Playground.
#
#
# Summary This project will reconstruct the comfort stations at Banneker Playground and Tilden Playground.
#
#
# Title Bartlett Playground Reconstruction
#
#
# Summary This project will reconstruct Bartlett Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bartlett Playground Reconstruction Schematic_20190207_B.jpg
#
#
# Title Baruch Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at Baruch Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Baruch Playground Comfort Station Reconstruction Rendering_20180409_A.jpg
#
#
# Title Bay Terrace Playground Reconstruction
#
#
# Summary This project will reconstruct the lower entrance, handball court, basketball court, and multipurpose play area at Bay Terrace Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bay Terrace Playground Reconstruction Schematic_20190207_Q.jpg
#
#
# Title Bayside Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station in Bayside Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bayside Playground Comfort Station Reconstruction Rendering_20190207_A.jpg
#
#
# Title Laurelton Playground and Bayswater Park Skate Elements and Seating Areas Construction
#
#
# Summary This project will provide skate park elements and related site amenities at Laurelton Playground and Bayswater Park.
#
#
# Summary This project will reconstruct the playground, sports courts and fields and construct a new comfort station at Bayswater Park.
#
#
# Title Linden Park Handball Court and Bayview Playground Baseball Field Reconstruction
#
#
# Title Beach 59th Street Playground Reconstruction
#
#
# Summary This project will reconstruct Beach 59th Street Playground with new play equipment, safety surface, pavements, fencing, spray shower, benches and game tables.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Beach 59th Street Playground Reconstruction Schematic_20190207_Q.jpg
#
#
# Title Beach 9th Street Playground Basketball Courts Reconstruction
#
#
# Summary This project will reconstruct the basketball courts at Beach 9th Street Playground.
#
#
# Title Beach Channel (P.S. 183) Playground Reconstruction
#
#
# Summary This project will reconstruct Beach Channel (P.S. 183) playground located south of Beach Channel Drive between Beach 79th & Beach 80th Street.
#
#
# Title Bellerose Playground Reading Garden Construction
#
#
# Summary This project will construct a reading garden at Bellerose Playground.
#
#
# Summary This project will construct an ADA-accessible dog run and reconstruct the basketball court, playground, and sitting areas at Bellevue South Park.
#
#
# Title Benson Playground Asphalt Field and Handball Court Reconstruction
#
#
# Summary This project will reconstruct the handball court and asphalt field at Benson Playground.
#
#
# Title Bensonhurst Park Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, adjacent path system and sitting areas at the north end of Bensonhurst Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bensonhurst Park Playground Reconstruction Schematic_20180409_B.jpg
#
#
# Title Bergen Beach Playground Reconstruction
#
#
# Summary This project will reconstruct Bergen Beach Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bergen Beach Playground Reconstruction Schematic_20170321_B.jpg
#
#
# Title Gateway Estates Phase 1 Playground and Comfort Station Construction
#
#
# Summary This project will construct a playground and comfort station at Gateway Estates.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Gateway Estates Playground and Comfort Station Construction Schematic_20160411_B.jpg
#
#
# Title Gateway Estates Phase 1 Playground and Comfort Station Construction - Electrical
#
#
# Summary This project will construct electrical service to a playground and comfort station at Gateway Estates.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Gateway Estates Playground and Comfort Station Construction Schematic_20160411_B.jpg
#
#
# Title Gateway Estates Phase 1 Playground and Comfort Station Construction - HVAC
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Gateway Estates Playground and Comfort Station Construction Schematic_20160411_B.jpg
#
#
# Title Gateway Estates Phase 1 Playground and Comfort Station Construction - Plumbing
#
#
# Summary This project will construct plumbing systems for a playground and comfort station at Gateway Estates.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Gateway Estates Playground and Comfort Station Construction Schematic_20160411_B.jpg
#
#
# Summary This project will construct a comfort station at Imagination Playground in Betsy Head Park.
#
#
# Title Betsy Head Playground Reconstruction
#
#
# Summary This project will create an Imagination Playground that will include a water, sand and block play area in Betsy Head.
#
#
# Title Big Bush Park Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, spray shower, handball courts, sitting area, fencing and pavements in Big Bush Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Big Bush Park Playground Reconstruction Schematic_20160411_Q.jpg
#
#
# Title Bildersee Playground Reconstruction Phase 1
#
#
# Summary This project will construct a new synthetic turf field and reconstruct the basketball courts at Bildersee Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bildersee Playground Reconstruction Phase 1 Schematic_20180409_B.jpg
#
#
# Title Bildersee Playground Reconstruction Phase 2
#
#
# Summary This project will construct a new play area, basketball courts and seating areas at Bildersee Playground.
#
#
# Title Bill 'Bojangles' Robinson Playground Reconstruction
#
#
# Summary This project will reconstruct Bill 'Bojangles' Robinson Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bill Bojangles Playground Reconstruction Schematic_20180628_M.jpg
#
#
# Title Bill Brown Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station in Bill Brown Playground.
#
#
# Title Black Rock Playground Reconstruction
#
#
# Summary This project will reconstruct Black Rock Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Black Rock Playground Reconstruction Schematic_20170321_X.jpg
#
#
# Title Bland Playground Reconstruction
#
#
# Summary This project will reconstruct Bland Playground.
#
#
# Title Bleecker Playground and Comfort Station Reconstruction
#
#
# Summary This project will reconstruct Bleecker Playground, including the comfort station.
#
#
# Title Bloomingdale Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station in Bloomingdale Playground, bringing it into compliance with ADA accessibility standards.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bloomingdale Playground Comfort Station Reconstruction Schematic_20170821_M.jpg
#
#
# Title Bloomingdale Playground Play Area Reconstruction
#
#
# Summary This project will reconstruct basketball courts, paths, benches, spray shower, planting, play equipment and adult fitness equipment at Bloomingdale Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bloomingdale Playground Play Area Reconstruction Schematic_20170821_M.jpg
#
#
# Summary This project will construct adult fitness equipment and reconstruct the basketball court and handball court wall at Booker T. Washington Playground, reconstruct the playground at Chelsea Park, and construct adult fitness equipment and reconstruct the basketball half-court at Columbus Park.
#
#
# Summary This project will construct adult fitness equipment and reconstruct the basketball court and handball court wall at Booker T. Washington Playground, reconstruct the playground at Chelsea Park, and construct adult fitness equipment and reconstruct the basketball half-court at Columbus Park.
#
#
# Title Booker T. Washington Playground Synthetic Turf Reconstruction
#
#
# Summary This project will reconstruct the synthetic turf field, basketball backstops, and chain link fencing at Booker T. Washington Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Booker T. Washington Playground Synthetic Turf Reconstruction Schematic_20190207_M.jpg
#
#
# Title Bowne Park Playground Reconstruction
#
#
# Summary This project will reconstruct the playground and basketball court in Bowne Park.
#
#
# Title Bowne Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, asphalt field, seating area and swings at Bowne Playground.
#
#
# Summary This project will reconstruct the playground, asphalt field, seating area and swings at Bowne Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bowne Playground Reconstruction Schematic_20160411_Q.jpg
#
#
# Title Briarwood Playground and Phil 'Scooter' Rizzuto Park Playground Reconstruction
#
#
# Title Briarwood Playground and Phil 'Scooter' Rizzuto Park Playground Reconstruction
#
#
# Summary This project will reconstruct the playgrounds at Briarwood Playground and Phil 'Scooter' Rizzuto Park.
#
#
# Summary This project will reconstruct the playgrounds at Briarwood Playground and Phil 'Scooter' Rizzuto Park.
#
#
# Title Bridge Playground Reconstruction
#
#
# Summary This project will reconstruct Bridge Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Bridge Playground Reconstruction Schematic_20190207_X.jpg
#
#
# Title Dyker Beach Park Paths and Brizzi Playground Reconstruction
#
#
# Summary This project will reconstruct Brizzi Playground and the paths adjacent to Ben Vitale Fields in Dyker Beach Park.
#
#
# Title Bronx Park Brady Playground Adult Fitness Equipment Construction
#
#
# Title Waring Playground Reconstruction
#
#
# Summary This project will reconstruct the basketball courts and the playground at Waring Playground in Bronx Park.
#
#
# Summary This project will reconstruct the basketball courts and the playground at Waring Playground in Bronx Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Waring Playground Reconstruction Rendering_20180409_X.jpg
#
#
# Title Parque de los Ninos Playground and Seating Area Reconstruction
#
#
# Summary This project will reconstruct the playground and seating area at Parque de los Ninos.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Parque de los Ninos Playground and Seating Area Reconstruction Rendering_20170403_X.jpg
#
#
# Title Bushwick Playground Pool Reconstruction
#
#
# Summary This project will reconstruct the concrete pool deck at Bushwick Playground.
#
#
# Title Marlboro Playground and Cadman Plaza Park Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort stations at Marlboro Playground and Cadman Plaza East Comfort Station, in the borough of Brooklyn
#
#
# Title Brooklyn War Memorial Restroom and Eleanor Roosevelt Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct Brooklyn War Memorial Restroom and Eleanor Roosevelt Playground Comfort Station.
#
#
# Title Callahan-Kelly Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, spray shower, perimeter sidewalks and walls, basketball courts, adult fitness equipment and sitting areas in Callahan-Kelly Playground. In addition, this project will construct a new skate park and park entrances.
#
#
# Summary This project will reconstruct the playground, spray shower, perimeter sidewalks and walls, basketball courts, adult fitness equipment and sitting areas in Callahan-Kelly Playground. In addition, this project will construct a new skate park and park entrances.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Callahan Kelly Playground Reconstruction Schematic_20171218_B.jpg
#
#
# Title Nautilus, Walter Ward, and Cambria Playgrounds Basketball and Handball Courts Reconstruction
#
#
# Summary This project will reconstruct basketball and handball courts at Nautilus Playground and Cambria Playground, and the basketball courts at Walter Ward Playground.
#
#
# Summary This project will reconstruct basketball and handball courts at Nautilus Playground and Cambria Playground, and the basketball courts at Walter Ward Playground.
#
#
# Summary This project will reconstruct basketball and handball courts at Nautilus Playground and Cambria Playground, and the basketball courts at Walter Ward Playground.
#
#
# Summary This project will install adult fitness equipment at Cambria Playground, Haggerty Park, and Montbellier Park.
#
#
# Title Canarsie Park Playground Construction
#
#
# Summary This project will construct a playground in Canarsie Park.
#
#
# Title Carl Schurz Park Playground Reconstruction
#
#
# Summary This project will reconstruct the children's playground in Carl Schurz Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Carl Schurz Park Playground Reconstruction Schematic_20180409_M.jpg
#
#
# Title Carlton Park Landscape and Ida Court Playground Reconstruction
#
#
# Summary This project will reconstruct the play areas, paths, fencing, landscape and park amenities at Carlton Park and Ida Court Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Carlton Park Landscape and Ida Court Playground Reconstruction Schematic_20180409_R.jpg
#
#
# Title Hunts Point, Playground 52, Carmansville, MLK, and Sol Lain Playgrounds Comfort Station Reconstruction
#
#
# Title Hunts Point, Playground 52, Carmansville, MLK, and Sol Lain Playgrounds Comfort Station Reconstruction
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Hunts Point, Playground 52, Carmansville, MLK, and Sol Lain Playgrounds Comfort Station Reconstruction Schematic_20171218_A.jpg
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Hunts Point, Playground 52, Carmansville, MLK, and Sol Lain Playgrounds Comfort Station Reconstruction Schematic_20171218_A.jpg
#
#
# Title Carmansville Playground Reconstruction
#
#
# Summary This project will reconstruct Carmansville Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Carmansville Playground Schematic_20160426_M.jpg
#
#
# Title Castlewood Playground Multipurpose Play Area Reconstruction
#
#
# Summary This project will reconstruct the multipurpose play area at Castlewood Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Castlewood Playground Multipurpose Play Area Reconstruction Schematic_20190516_Q.jpg
#
#
# Title Cedar Playground Basketball Court and Playground Reconstruction
#
#
# Title Cedar Playground Basketball Court and Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, basketball courts and adjacent landscape in Cedar Playground.
#
#
# Summary This project will reconstruct the playground, basketball courts and adjacent landscape in Cedar Playground.
#
#
# Title Cedar Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station in Cedar Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Cedar Playground Comfort Station Reconstruction Rendering_20170403_A.jpg
#
#
# Title Challenge Playground Reconstruction
#
#
# Summary This project will reconstruct the play equipment, fencing, and spray shower area at Challenge Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Challenge Playground Reconstruction Schematic_20190207_Q.jpg
#
#
# Title Chester Playground Reconstruction
#
#
# Summary This project will reconstruct Chester Playground.
#
#
# Title Christopher J. Igneri Playground Reconstruction
#
#
# Summary This project will reconstruct the playground and basketball court at Christopher J. Igneri Playground.
#
#
# Summary This project will reconstruct the playground and basketball court at Christopher J. Igneri Playground.
#
#
# Summary This project will construct green infrastructure to capture storm water at Classon Playground, Colonel David Marcus Playground, Oracle Playground, and Willoughby Playground.
#
#
# Summary This project will construct green infrastructure to capture storm water at Classon Playground, Colonel David Marcus Playground, Oracle Playground, and Willoughby Playground.
#
#
# Summary This project will construct green infrastructure to capture storm water at Classon Playground, Colonel David Marcus Playground, Oracle Playground, and Willoughby Playground.
#
#
# Summary This project will construct green infrastructure to capture storm water at Classon Playground, Colonel David Marcus Playground, Oracle Playground, and Willoughby Playground.
#
#
# Title Clawson Playground Reconstruction Phase I
#
#
# Summary This project will reconstruct the area of Clawson Playground behind PS 50 with new play equipment, safety surfacing, benches and plantings.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Clawson Playground Reconstruction Phase I Schematic_20180409_R.jpg
#
#
# Summary This project will develop a playground including play equipment, basketball and sport court area, spray shower, benches, lighting and plantings at Co-op City Park Waterfront.
#
#
# Title Ocean Parkway Malls and Colonel David Marcus Playground Reconstruction
#
#
# Summary This project will reconstruct the east and west Ocean Parkway Malls from Avenue O to Kings Highway with new asphalt pavement, pipe handrails, trees, benches, signage, greenway markings and curbs; expanded tree pits and restored granite block pavers and a mile marker. This project will also reconstruct the handball and basketball courts, paving, fencing, gates and landscaping and construct a new ADA-accessible drinking fountain in Colonel David Marcus Playground.
#
#
# Title Jackie Robinson Playground and Colonel David Marcus Southeast Playground Reconstruction
#
#
# Title Jackie Robinson Playground and Colonel David Marcus Southeast Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, sitting area and multi-purpose play area at Jackie Robinson Playground and the playground at Colonel David Marcus Playground.
#
#
# Summary This project will reconstruct the playground, sitting area and multi-purpose play area at Jackie Robinson Playground and the playground at Colonel David Marcus Playground.
#
#
# Summary This project will reconstruct the playground, sitting area and multi-purpose play area at Jackie Robinson Playground and the playground at Colonel David Marcus Playground.
#
#
# Summary This project will reconstruct the playground, sitting area and multi-purpose play area at Jackie Robinson Playground and the playground at Colonel David Marcus Playground.
#
#
# Title Colonel David Marcus Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station in Colonel David Marcus Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Colonel David Marcus Playground Comfort Station Reconstruction Rendering_20170327_A.jpg
#
#
# Title Colucci Playground Adult Fitness Equipment Construction
#
#
# Summary This project will construct an adult fitness area in Colucci Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Colucci Playground Adult Fitness Equipment Construction Schematic_20170821_X.jpg
#
#
# Title Commodore Barry Park Playground Reconstruction
#
#
# Summary This project will reconstruct the playground at Commodore Barry Park.
#
#
# Title Conch Playground Reconstruction
#
#
# Summary This project will reconstruct Conch (PS.105) Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Conch Playground Reconstruction Schematic_20160411_Q.jpg
#
#
# Title Conference House Park Lenape Playground Reconstruction
#
#
# Summary This project will reconstruct Lenape Playground.
#
#
# Title Corona Golf Playground Pavement Reconstruction
#
#
# Summary This project will reconstruct pavements at Corona Golf Playground.
#
#
# Title Junction and Corona Golf Playground Play Equipment Installation (QG-615M)
#
#
# Summary This project will install special needs play equipment for Fort Totten and Crocheron Park and a safety surface for Corona Golf and Junction Playground.
#
#
# Title Corona Golf Playground Sidewalks Reconstruction
#
#
# Summary This project will reconstruct the sidewalks at Corona Golf Playground.
#
#
# Title Seravalli Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at Seravalli Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Seravalli Playground Comfort Station Reconstruction Schematic_20180409_A.jpg
#
#
# Title Courtney Callender Playground Handball Court Pavement Reconstruction
#
#
# Summary This project will reconstruct the pavement, backstop, drainage system, and benches at the handball court in Courtney Callender Playground.
#
#
# Title Crispus Attucks Playground Handball and Basketball Court Reconstruction
#
#
# Summary This project will reconstruct the handball and basketball courts in Crispus Attucks Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Crispus Attucks Playground Handball and Basketball Court Reconstruction Schematic_20170321_B.jpg
#
#
# Summary This project will reconstruct the comfort station at Playground of the Stars in Crotona Park.
#
#
# Summary This project will construct green infrastructure to capture stormwater at Crotona Parkway Malls, Whalen Grove, Parkside Playground, Loreto Playground, and Haviland Playground.
#
#
# Summary This project will construct green infrastructure to capture stormwater at Crotona Parkway Malls, Whalen Grove, Parkside Playground, Loreto Playground, and Haviland Playground.
#
#
# Summary This project will construct green infrastructure to capture stormwater at Crotona Parkway Malls, Whalen Grove, Parkside Playground, Loreto Playground, and Haviland Playground.
#
#
# Title Crowley Playground Reconstruction
#
#
# Summary This project will reconstruct Crowley Playground.
#
#
# Summary This project will reconstruct Frank O'Connor Playground, Crowley Playground, and Real Good Playground.
#
#
# Summary This project will reconstruct Frank O'Connor Playground, Crowley Playground, and Real Good Playground.
#
#
# Summary This project will reconstruct Frank O'Connor Playground, Crowley Playground, and Real Good Playground.
#
#
# Title Cunningham Park Lower Playground Tot Lot Reconstruction
#
#
# Summary This project will reconstruct the Lower Playground (Redwood Playground) in Cunningham Park.
#
#
# Summary This project will reconstruct the Lower Playground (Redwood Playground) in Cunningham Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Cunningham Park Lower Playground Tot Lot Reconstruction Schematic_20180409_Q.jpg
#
#
# Title Cunningham Park Redwood Playground Pathways Reconstruction
#
#
# Summary This project will reconstruct the pathways at Redwood Playground in Cunningham Park.
#
#
# Title Cunningham Park 210th Street Playground Reconstruction
#
#
# Summary This project will reconstruct 210th Street Playground at Cunningham Park.
#
#
# Title Cypress Hills Playground Synthetic Turf Field Construction
#
#
# Summary This project will construct a new synthetic turf multi-purpose athletic field to replace an existing natural turf field at Cypress Hills Playground. The work will include a new perimeter recreation path, reconstructed dugouts, drinking fountains and misting stations.
#
#
# Title Daniel O'Connell Playground Reconstruction
#
#
# Summary This project will reconstruct the playground at Daniel O'Connell Playground.
#
#
# Summary This project will reconstruct the playground at Daniel O'Connell Playground.
#
#
# Title O'Connell Playground Recreation Building Reconstruction
#
#
# Summary This project will reconstruct the recreation building in Daniel M. O'Connell Playground.
#
#
# Summary This project will reconstruct DeMatti Park, with a new playground, spray shower, adult fitness area, lawn, bocce courts, and performance space.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/DeMatti Playground Reconstruction Schematic_20160411_R.jpg
#
#
# Title DeSalvio Playground Reconstruction
#
#
# Summary This project will reconstruct DeSalvio Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/DeSalvio Playground Adult Use and Children's Play Area Reconstruction Schematic_20170321_M.jpg
#
#
# Title William Gunn Playground Reconstruction
#
#
# Title Di Gilio Playground Reconstruction
#
#
# Summary This project will reconstruct Di Gilio Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Di Gilio Playground Reconstruction Schematic_20160411_B.jpg
#
#
# Title Ditmars Playground Reconstruction
#
#
# Summary This project will reconstruct the play equipment, safety surface, spray shower, benches, and security lighting at Ditmars Playground.
#
#
# Title Dome Playground Basketball and Handball Courts Reconstruction
#
#
# Summary This project will reconstruct the basketball & handball courts located in Dome Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Dome Playground Sport Court Reconstruction Schematic_20180409_B.jpg
#
#
# Title Dome Playground Play Area and Lawn Reconstruction
#
#
# Summary This project will reconstruct the play area and lawn at Dome Playground.
#
#
# Title Dongan Playground Reconstruction
#
#
# Summary This project will reconstruct the play area and sidewalks at Dongan Playground.
#
#
# Title Downing Playground Reconstruction
#
#
# Title Drew Playground Park Security Lighting Construction
#
#
# Summary This project will construct new park security lighting in Drew Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Drew Playground Park Security Lighting Construction Schematic_20190207_X.jpg
#
#
# Title Dry Dock Playground Reconstruction
#
#
# Summary This project will reconstruct the play equipment and security lighting at Dry Dock Playground.
#
#
# Title Schmul Park and Dugan Playground Ballfield Reconstruction
#
#
# Summary This project will reconstruct the ballfields in Dugan Playground and Schmul Park.
#
#
# Title Dugan Playground Reconstruction
#
#
# Summary This project will reconstruct the play equipment, swings, spray shower, and seating area at Dugan Playground.
#
#
# Title Dunningham Triangle and Playground Ninety Basketball Court and Spray Shower Reconstruction
#
#
# Summary This project will reconstruct Dunningham Triangle and the basketball court and spray shower at Playground Ninety.
#
#
# Title Dutch Kills Playground and Court Area Reconstruction
#
#
# Summary This project will reconstruct the playground and court area in Dutch Kills Playground.
#
#
# Summary This project will reconstruct the playground and court area in Dutch Kills Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Dutch Kills Playground and Court Area Reconstruction Schematic_20170821_Q.jpg
#
#
# Title Dutch Kills Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at Dutch Kills Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Dutch Kills Playground Comfort Station Reconstruction Rendering_20170327_A.jpg
#
#
# Summary This project will reconstruct the multipurpose play areas at Dyker Playground in Dyker Beach Park, Patrick O'Rourke Playground and Wilson Playground.
#
#
# Summary This project will reconstruct the multipurpose play areas at Dyker Playground in Dyker Beach Park, Patrick O'Rourke Playground and Wilson Playground.
#
#
# Summary This project will reconstruct the multipurpose play areas at Dyker Playground in Dyker Beach Park, Patrick O'Rourke Playground and Wilson Playground.
#
#
# Title Prescott Playground Reconstruction
#
#
# Summary This project will reconstruct Prescott Playground, including fencing, retaining walls, play equipment, and pavements.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Prescott Playground Reconstruction Schematic_20190207_R.jpg
#
#
# Summary This project will construct green infrastructure to capture storm water at East Elmhurst Playground, Electric Playground, Horace Harding Playground, London Planetree Playground, and Joseph P. Addabbo Memorial Park.
#
#
# Summary This project will construct green infrastructure to capture storm water at East Elmhurst Playground, Electric Playground, Horace Harding Playground, London Planetree Playground, and Joseph P. Addabbo Memorial Park.
#
#
# Summary This project will construct green infrastructure to capture storm water at East Elmhurst Playground, Electric Playground, Horace Harding Playground, London Planetree Playground, and Joseph P. Addabbo Memorial Park.
#
#
# Summary This project will construct green infrastructure to capture storm water at East Elmhurst Playground, Electric Playground, Horace Harding Playground, London Planetree Playground, and Joseph P. Addabbo Memorial Park.
#
#
# Title East Elmhurst Playground Reconstruction
#
#
# Summary This project will reconstruct the playground and handball courts at PS 127 (East Elmhurst) Playground.
#
#
# Summary This project will reconstruct the playground and handball courts at PS 127 (East Elmhurst) Playground.
#
#
# Title Edenwald Playground Basketball Courts and Mini Pool Reconstruction
#
#
# Summary This project will reconstruct the basketball courts, demolish the existing above-ground mini-pool and construct a new in-ground mini-pool at Edenwald Playground.
#
#
# Title Ehrenreich-Austin Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at Ehrenreich-Austin Playground.
#
#
# Title Ehrenreich-Austin Playground Comfort Station Plumbing System Reconstruction
#
#
# Summary This project will reconstruct the comfort station plumbing system at Ehrenreich-Austin Playground.
#
#
# Title Ehrenreich-Austin Playground Comfort Station Electrical System Reconstruction
#
#
# Summary This project will reconstruct the comfort station electrical system at Ehrenreich-Austin Playground.
#
#
# Title Austin, Giovanelli, and Utopia Playgrounds Reconstruction
#
#
# Summary This project will reconstruct the play areas at Ehrenreich-Austin Playground, Utopia Playground, and Giovannelli Playground.
#
#
# Summary This project will reconstruct the play areas at Ehrenreich-Austin Playground, Utopia Playground, and Giovannelli Playground.
#
#
# Summary This project will reconstruct the play areas at Ehrenreich-Austin Playground, Utopia Playground, and Giovannelli Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Austin, Giovanelli, and Utopia Playgrounds Reconstruction Schematic_20170821_Q.jpg
#
#
# Title Ennis Playground Reconstruction
#
#
# Summary This project will reconstruct Ennis Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Ennis Park Playground Reconstruction Schematic_20170321_B.jpg
#
#
# Title Epiphany Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, spray shower, seating, handball and basketball courts, perimeter fence, and security lighting at Epiphany Playground.
#
#
# Summary This project will reconstruct the playground, spray shower, seating, handball and basketball courts, perimeter fence, and security lighting at Epiphany Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Epiphany Playground Reconstruction Schematic_20180604_B.jpg
#
#
# Summary This project will reconstruct the playground at Equity Park.
#
#
# Title Evergreen Park Playground and Spray Shower Reconstruction
#
#
# Title Evergreen Park Playground Reconstruction
#
#
# Summary This project will install new play equipment, pavement, fencing, drainage, site furniture, and lighting at the playground in Evergreen Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Evergreen Park Playground Reconstruction Schematic_20170821_Q.jpg
#
#
# Summary This project will demolish the existing playground and construct a basketball court at Faber Park.
#
#
# name Corona Avenue and 111th Street, next to Playground for All Children
#
#
# Title World's Fair Playground Asphalt Field Reconstruction
#
#
# Summary This project will reconstruct the asphalt field at World's Fair Playground in Flushing Meadows Corona Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/World's Fair Playground Asphalt Field Reconstruction Schematic_20180409_Q.jpg
#
#
# Title Flushing Meadows Corona Park Mauro Playground Reconstruction
#
#
# Summary This project will reconstruct Mauro Playground in Flushing Meadows Corona Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Flushing Meadows Corona Park Mauro Playground Reconstruction Schematic_20180409_Q.jpg
#
#
# name South shoreline of Meadow Lake, and north of Jurassic Playground
#
#
# Title Flushing Meadows Corona Park Lawrence Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at Lawrence Playground in Flushing Meadows Corona Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Flushing Meadows Corona Park Lawrence Playground Comfort Station Reconstruction Schematic_20170821_Q.jpg
#
#
# Title Flushing Meadows Corona Park Lawrence Playground Reconstruction
#
#
# Summary This project will reconstruct Lawrence Playground in Flushing Meadows Corona Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Flushing Meadows Corona Park Lawrence Playground Reconstruction Schematic_20170821_Q.jpg
#
#
# Title Forest Park Sobelsohn Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at Sobelsohn Playground in Forest Park.
#
#
# Title Forest Park Sobelsohn Playground Comfort Station Plumbing System Reconstruction
#
#
# Summary This project will reconstruct the comfort station plumbing system at Sobelsohn Playground in Forest Park.
#
#
# Title Forest Park Sobelsohn Playground Comfort Station Electrical System Reconstruction
#
#
# Summary This project will reconstruct the comfort station electrical system at Sobelsohn Playground in Forest Park.
#
#
# Title Mary Whalen Playground Reconstruction
#
#
# Summary This project will reconstruct Mary Whalen Playground.
#
#
# Title Joe Devoy Playground Reconstruction
#
#
# Summary This project will reconstruct Joe Devoy Playground in Forest Park.
#
#
# name South of Willoughby Avenue and north of the playground, and Myrtle Avenue Landscape north of Willoughby Avenue.
#
#
# Title Anne Loftus Playground Spray Shower Reconstruction
#
#
# Summary This project will reconstruct the spray shower plaza, children's climber play equipment, and safety surfacing at Anne Loftus Playground in Fort Tryon Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Anne Loftus Playground Spray Shower Reconstruction Schematic_20190516_M.jpg
#
#
# Title Jacob Javits Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, basketball court, drainage and water supply systems and surrounding landscape, and construct new adult fitness equipment at Jacob Javits Playground in Fort Tryon Park.
#
#
# Summary This project will reconstruct the playground, basketball court, drainage and water supply systems and surrounding landscape, and construct new adult fitness equipment at Jacob Javits Playground in Fort Tryon Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Jacob Javits Playground Reconstruction Schematic_20170321_M.jpg
#
#
# Title Fort Washington Park Courts Reconstruction and Playground Construction
#
#
# Summary This project will construct a new playground between West 162nd & 164th Streets and reconstruct the fields, courts, and greenway between West 155th & West 168th Streets.
#
#
# Title Fox Playground Comfort Station Construction
#
#
# Summary This project will construct a comfort station in Fox Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Fox Playground Comfort Station Construction Rendering_20190207_A.jpg
#
#
# Title South Beach Playland Playground Curbs and Fencing Reconstruction
#
#
# Summary This project will reconstruct Hurricane Sandy-damaged curbs, fences and safety surface at South Beach Playland Playground.
#
#
# Title Frederick B. Judge Playground Basketball Courts Reconstruction
#
#
# Summary This project will reconstruct the basketball courts at Frederick B. Judge Playground.
#
#
# Title Frederick B. Judge Playground Reconstruction
#
#
# Summary This project will reconstruct the playground at Frederick B. Judge Playground.
#
#
# Summary This project will reconstruct the playground at Frederick B. Judge Playground.
#
#
# Title Harlem Lane Playground and Frederick Johnson Playground Sports Courts Reconstruction
#
#
# Title Harlem Lane Playground and Frederick Johnson Playground Sports Courts Reconstruction
#
#
# Summary This project will reconstruct Harlem Lane Playground, and it will demolish the existing comfort station and construct a new basketball court and synthetic turf field at Frederick Johnson Playground.
#
#
# Summary This project will reconstruct Harlem Lane Playground, and it will demolish the existing comfort station and construct a new basketball court and synthetic turf field at Frederick Johnson Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Harlem Lane Playground and Frederick Johnson Playground Sports Courts Reconstruction Schematic_20181002_M.jpg
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Harlem Lane Playground and Frederick Johnson Playground Sports Courts Reconstruction Schematic_20181002_M.jpg
#
#
# Title Frederick Johnson Playground Comfort Station Construction
#
#
# Summary This project will construct a new comfort station at Frederick Johnson Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Frederick Johnson Playground Comfort Station Construction Schematic_20181002_M.jpg
#
#
# Title Frederick Johnson Playground Play Area Reconstruction
#
#
# Summary This project will reconstruct the play area at Frederick Johnson Playground.
#
#
# ...
#
#
# Title St. Catherine's Playground Safety Surface Reconstruction
#
#
# Title St. Gregory's Playground Reconstruction
#
#
# Summary This project will reconstruct St. Gregory's Playground.
#
#
# Title St. Mary's Playground Reconstruction
#
#
# Summary This project will construct new play equipment, benches, and pavements at St. Mary's Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/St. Mary's Playground Reconstruction Schematic_20180409_B.jpg
#
#
# Title St. Mary's Playground Multi-Purpose Area Reconstruction
#
#
# Summary This project will reconstruct the existing multipurpose play area at St. Mary's Playground to include a skate park, basketball courts, multi-use synthetic turf field, adult fitness equipment and color seal coat walking track.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/St. Mary's Playground Multi-Purpose Area Reconstruction Schematic_20180409_B.jpg
#
#
# Title St. Mary's Park Playground West Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at St. Mary's Park Playground West.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/St. Mary's Park Playground West Comfort Station Reconstruction Schematic_20190207_X.jpg
#
#
# Title St. Mary's Park Playground West Reconstruction
#
#
# Summary This project will reconstruct the basketball and tennis courts, and install play equipment, seating areas, planting beds and trees at St. Mary's Park Playground West.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/St. Mary's Playground Reconstruction Rendering_20160411_X.jpg
#
#
# Title St. Michael's Playground Synthetic Turf Field Reconstruction
#
#
# Summary This project will reconstruct the synthetic turf field at St. Michael's Playground.
#
#
# Title St. Nicholas Playground North Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station at St. Nicholas Playground North.
#
#
# Title Stapleton Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, multi-use fields, basketball and handball courts, and water features at Stapleton Playground.
#
#
# Summary This project will reconstruct the playground, multi-use fields, basketball and handball courts, and water features at Stapleton Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Stapleton Playground Reconstruction Schematic_20170821_R.jpg
#
#
# Title Starr Playground Multi-Purpose Play Area and Handball Courts Reconstruction
#
#
# Summary This project will reconstruct the multi-purpose play area and handball courts in Starr Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Starr Playground Multi-Purpose Play Area and Handball Courts Reconstruction Schematic_20190207_Q.jpg
#
#
# Title Starr Playground Play Area and Spray Shower Reconstruction
#
#
# Summary This project will reconstruct the playground and spray shower at Starr Playground.
#
#
# Summary This project will reconstruct the playground and spray shower at Starr Playground.
#
#
# Title Stockton Playground Reconstruction
#
#
# Summary This project will reconstruct Stockton Playground with new play equipment, a spray shower, a synthetic turf field and painted track, lighting, fencing, pavement, plantings, and site furnishings.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Stockton Playground Reconstruction Schematic_20160411_B.jpg
#
#
# Title Stroud Playground Reconstruction
#
#
# Summary This project will reconstruct Stroud Playground, including the multi-use area, landscaping, play equipment, safety surface, spray shower, seating areas, basketball court and handball court.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Stroud Playground Reconstruction Schematic_20170327_B.jpg
#
#
# Title Sumner Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station in Sumner Playground.
#
#
# Title Sumner Playground Reconstruction
#
#
# Summary This project will reconstruct Sumner Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Sumner Playground Ballfield and Athletic Court Reconstruction Schematic_20160411_B.jpg
#
#
# Title Sunners Playground Reconstruction
#
#
# Summary This project will reconstruct Sunners Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Sunners Playground Reconstruction Schematic_20190919_B.jpg
#
#
# Title Sunset Park Playground Play Equipment and Safety Surfacing Reconstruction
#
#
# Summary This project will install a Mobius Climber play equipment unit and reconstruct the surrounding safety surface in Sunset Park Playground.
#
#
# Title Sunset Park Playground Reconstruction
#
#
# Summary This project will reconstruct the playground in Sunset Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Sunset Park Playground Reconstruction Schematic_20160411_B.jpg
#
#
# Title Surf Playground Reconstruction
#
#
# Summary This project will install new pavement, fencing and play equipment at Surf Playground.
#
#
# Title Surf Playground Reconstruction
#
#
# Summary This project will reconstruct the asphalt multi-purpose play area and sport courts at Surf Playground with new basketball courts, seating area, synthetic turf and plantings.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Surf Playground Reconstruction Schematic_20190207_B.jpg
#
#
# Title Taaffe Playground Reconstruction
#
#
# Summary This project will install new pavement, fencing and play equipment at Taaffe Playground.
#
#
# Title Ten Eyck Playground Reconstruction
#
#
# Summary This project will reconstruct Ten Eyck Playground with new play equipment, a spray shower, a synthetic turf field and painted track, a basketball court, lighting, fencing, pavement, plantings, and site furnishings.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Ten Eyck Playground Reconstruction Schematic_20160411_B.jpg
#
#
# Summary This project will reconstruct the comfort station near the playground in the Battery.
#
#
# Title Battery Park Playground Reconstruction
#
#
# Summary This project will reconstruct and expand the playground at The Battery.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Battery Park Playground Reconstruction Schematic_20170821_M.jpg
#
#
# Title Grandview Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, courts, and multi-use fields in Grandview Playground.
#
#
# Summary This project will reconstruct the playground, courts, and multi-use fields in Grandview Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Grandview Playground Reconstruction Schematic_20160411_R.jpg
#
#
# Title Thomas Greene Playground Reconstruction
#
#
# Summary This project will install new play equipment and fencing at Thomas Greene Playground.
#
#
# Title Thomas Greene Playground Pool Reconstruction
#
#
# Summary This project will reconstruct the concrete pool deck at Thomas Greene Playground.
#
#
# Summary This project will construct a skate park in the northeast corner of the existing playground in Thomas Jefferson Park.
#
#
# Title Thomas Jefferson Park Playground Reconstruction
#
#
# Summary This project will reconstruct Thomas Jefferson Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Thomas Jefferson Park Playground Reconstruction Schematic_20190207_M.jpg
#
#
# Title Tilden Playground Shirley Chisholm Community Center Construction
#
#
# Summary This project will construct a new community center in Tilden Playground.
#
#
# Title Tompkins Square Playground Reconstruction
#
#
# Summary This project will reconstruct two playgrounds in Tompkins Square Park with new play equipment, safety surfacing, spray showers, seating, and fencing.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Tompkins Square Playground Reconstruction Schematic_20170321_M.jpg
#
#
# Title Triborough Bridge Playground C Reconstruction
#
#
# Summary This project will construct a dog run and reconstruct a basketball court at Triborough Bridge Playground C.
#
#
# Title Van Alst Playground Reconstruction
#
#
# Summary This project will reconstruct Van Alst Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Van Alst Playground Reconstruction Schematic_20160411_Q.jpg
#
#
# Title Classic Playground Fitness Equipment Installation
#
#
# Summary This project will install fitness equipment at Classic Playground in Van Cortlandt Park.
#
#
# Title Van Cortlandt Park Playground Construction
#
#
# Summary This project will construct a playground in Van Cortlandt Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Van Cortlandt Park Playground Construction Schematic_20170327_X.jpg
#
#
# Title Woodlawn Playground Spray Shower Reconstruction
#
#
# Summary This project will reconstruct the spray shower at Woodlawn Playground in Van Cortlandt Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Woodlawn Playground Spray Shower Reconstruction Schematic_20190207_X.jpg
#
#
# Title Woodlawn Playground Comfort Station Reconstruction
#
#
# Summary This project will reconstruct the comfort station in Woodlawn Playground in Van Cortlandt Park.
#
#
# Title Woodlawn Playground Reconstruction
#
#
# Summary This project will reconstruct the playground, including new steel play equipment, swings, safety surfacing, fencing, landscaping, benches, and park security lighting, at Woodlawn Playground in Van Cortlandt Park
#
#
# Summary This project will reconstruct the playground, including new steel play equipment, swings, safety surfacing, fencing, landscaping, benches, and park security lighting, at Woodlawn Playground in Van Cortlandt Park
#
#
# Title Van Nest Playground Reconstruction
#
#
# Summary This project will reconstruct the playground at Van Nest Park, including new play equipment, a spray shower, sitting area and planting borders.
#
#
# Title Albano Playground Reconstruction
#
#
# Summary This project will reconstruct the play equipment, safety surfacing, handball courts, and asphalt multi-purpose play area and construct a new spray shower at Albano Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Albano Playground Handball Court Multi-use Reconstruction Schematic_20180409_M.jpg
#
#
# Title Wagner Playground Synthetic Turf Reconstruction
#
#
# Summary This project will reconstruct the combination soccer and baseball synthetic turf field and adjacent fencing, drinking fountains, and seating areas at Wagner Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Wagner Playground Synthetic Turf Reconstruction Schematic_20180409_M.jpg
#
#
# Title Wakefield Playground Reconstruction
#
#
# Summary This project will reconstruct Wakefield Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Wakefield Playground Reconstruction Schematic_20170821_X.jpg
#
#
# Summary This project will reconstruct the playground at Walton Park.
#
#
# Title Washington Hall Playground Basketball Courts Reconstruction
#
#
# Summary This project will reconstruct the basketball courts at Washington Hall Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Washington Hall Playground Basketball Courts Reconstruction Rendering_20190516_B.jpg
#
#
# Title Washington's Walk Fort Four Playground Comfort Station Construction
#
#
# Summary This project will construct a comfort station in Fort Four Playground at Washington's Walk.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Washington's Walk Fort Four Playground Comfort Station Construction Rendering_20190207_A.jpg
#
#
# Title Washington's Walk Strong Street Playground Reconstruction
#
#
# Summary This project will reconstruct Strong Street Playground in Washington's Walk.
#
#
# Title Weeksville Playground Reconstruction
#
#
# Summary This project will reconstruct Weeksville Playground with new play equipment, seating and planting beds.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Weeksville Playground Reconstruction Schematic_20170821_B.jpg
#
#
# Title West Playground Comfort Station Construction
#
#
# Summary This project will construct a comfort station in West Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/West Playground Comfort Station Construction Rendering_20170327_A.jpg
#
#
# Title Westerleigh Park Playground Construction
#
#
# Title White Park Playground Reconstruction
#
#
# Summary This project will reconstruct the playground in White Park.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/White Park Playground Reconstruction Schematic_20190919_R.jpg
#
#
# Title White Playground Reconstruction
#
#
# Summary This project will reconstruct White Playground.
#
#
# Title William Sheridan Playground Reconstruction
#
#
# Summary This project will reconstruct William Sheridan Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/William Sheridan Playground Reconstruction Schematic_20190919_B.jpg
#
#
# Title Willis Playground Comfort Station Roof Reconstruction
#
#
# Summary This project will reconstruct the roof at the comfort station in Willis Playground.
#
#
# Title Willis Playground Reconstruction
#
#
# Summary This project will reconstruct the play area at Willis Playground.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Willis Playground Reconstruction Schematic_20190207_X.jpg
#
#
# Title Wolfe's Pond Park Playground Reconstruction (Hurricane Sandy)
#
#
# Summary This project will reconstruct the Sandy-damaged playground and adjacent pathways at Wolfe's Pond Park, including new asphalt pavement, safety surfacing, fencing, benches, and curbs.
#
#
# Title Zimmerman Playground Comfort Station Roof Reconstruction
#
#
# Summary This project will reconstruct the roof at the comfort station in Zimmerman Playground.
#
#
# Title Zimmerman Playground Reconstruction
#
#
# Summary This project will reconstruct the handball courts, play equipment, swing set, and seating area at the southern portion of Zimmerman Playground.
#
#
# Title Sunnyside Gardens Park Playground Construction
#
#
# Summary This project will construct a playground at Sunnyside Gardens Park.
#
#
# Title PS 192 Playground Reconstruction Phase 2
#
#
# Title PS 38 Playground Reconstruction
#
#
# Summary This project will reconstruct the playground at PS 38 in Queens.
#
#
# Title PS 192 Playground Reconstruction
#
#
# Summary This project will construct a new playground at Brooklyn PS 192 and open the playground for the surrounding community to use outside of school hours.
#
#
# Summary This project will construct a new playground at Brooklyn PS 192 and open the playground for the surrounding community to use outside of school hours.
#
#
# Title Intermediate School 228 Playground Reconstruction
#
#
# Summary This project will construct a playground and multi-use recreation area at Intermediate School 228.
#
#
# Attachment http://media.nycgovparks.org/images/common_images/capital-project-tracker/Intermediate School 228 Playground Reconstruction Schematic_20180409_B.jpg
#
#
# Title PS 321 Playground Reconstruction
#
#
# Summary This project will reconstruct the playground at P.S. 321.
#
#
# Title Concerned Citizens of Grove Street Community Garden Playground Construction
#
#
# Summary This project will construct a playground at Grove Street Community Garden
#
#
# Summary This project will construct a new park, including a comfort station, playground and multi-purpose synthetic turf field at Gateway Estates.
#
#
# Summary This project will plant new trees in parks and playgrounds in Brooklyn and Staten Island.

# %% [markdown]
# You can also incorporate ranges into your brackets. For instance, we want the word "East" followed by any three numbers:

# %%
grep('East [0-9][0-9][0-9]', './ParkProjects.txt')
# Out:
# name 850 East 138th Street
#
#
# name Melrose Avenue between East 162nd Street and East 163rd Street
#
#
# name Melrose Avenue between East 162nd Street and East 163rd Street
#
#
# name East 135 Street between Madison & 5 Avenue
#
#
# name St. Mary's Street, St. Ann's Avenue, East 149 Street, Jackson Avenue
#
#
# name Fifth Avenue and East 135th Street
#
#
# name Fifth Avenue and East 135th Street
#
#
# name Barnes Avenue between East 215th Street and East 216th Street
#
#
# name Barnes Avenue between East 215th Street and East 216th Street
#
#
# name FDR Drive, East 106 to East 107 Streets
#
#
# name FDR Drive, East 106 to East 107 Streets
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name Jerome Avenue, McClellan Street, River Avenue, East 164 Street
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name FDR Drive, East 90 to East 125 Streets
#
#
# name FDR Drive, East 90 to East 125 Streets
#
#
# name East 163 Street & Teller Avenue
#
#
# name East 163 Street, Cauldwell Avenue & East 161 Street
#
#
# name East 163 Street, Cauldwell Avenue & East 161 Street
#
#
# name East 166 Street & Morris Avenue
#
#
# name Jerome Avenue, East 193 Street, Creston Avenue, East 191 Street
#
#
# name Jerome Avenue, East 193 Street, Creston Avenue, East 191 Street
#
#
# name St. Mary's Street, St. Ann's Avenue, East 149 Street, Jackson Avenue
#
#
# name St. Mary's Street, St. Ann's Avenue, East 149 Street, Jackson Avenue
#
#
# name Seaview Avenue between Paerdegat Basin and East 93 Street, East 102 Street and Fresh Creek Basin
#
#
# name Bronx River at East 182nd Street
#
#
# name Bronx River near East 180th Street
#
#
# name East 180th Street, Southern Boulevard and Bronx Park East
#
#
# name Bronx Boulevard between East 227th and East 228th Streets
#
#
# name Bronx Boulevard between East 227th and East 228th Streets
#
#
# Summary This project will reconstruct the paths, landscape and staircase at East 233rd Street in Bronx River Park.
#
#
# name East 233rd Street and the Bronx River
#
#
# name Madison Avenue, East 120 Street to East 124 Street
#
#
# name Madison Avenue, East 120 Street to East 124 Street
#
#
# name Madison Avenue, East 120th to East 124th Streets
#
#
# name Madison Avenue, East 120th to East 124th Streets
#
#
# name Clay Avenue, Mount Eden Parkway, Morris Avenue, Teller Avenue. East 170th Street
#
#
# name Fulton Avenue and East 173rd Street
#
#
# name Fulton Avenue bewteen East 172nd Street and East 173rd Street
#
#
# name Fulton Avenue bewteen East 172nd Street and East 173rd Street
#
#
# name Between Southern Boulevard & Crotona Parkway from East 175 Street to Garden Street
#
#
# name Fulton Avenue between East 169th Street and East 170th Street
#
#
# name Fulton Avenue between East 169th Street and East 170th Street
#
#
# name Avenues J & K, East 100 to East 101 Streets
#
#
# name Avenues J & K, East 100 to East 101 Streets
#
#
# name East River between East 114th Street and East 117th Street
#
#
# name East River between East 114th Street and East 117th Street
#
#
# name Schieffelin Avenue between East 225th and East 229th Streets
#
#
# name Schieffelin Avenue between East 225th and East 229th Streets
#
#
# name East 167th Street between Third and Fulton Avenues
#
#
# name East 156th Street between Fox Street and Southern Boulevard
#
#
# name Walton Avenue, Grand Concourse, East 158th Street, East 151st Street
#
#
# name Walton Avenue, Grand Concourse, East 158th Street, East 151st Street
#
#
# name Brook Avenue between East 140th Street and East 141st Street
#
#
# name Brook Avenue between East 140th Street and East 141st Street
#
#
# name Grand Concourse between East 144th Street and East 149th Street
#
#
# name Grand Concourse between East 144th Street and East 149th Street
#
#
# name Grant Avenue between East 169th Street and East 170th Street
#
#
# name Grant Avenue between East 169th Street and East 170th Street
#
#
# name Northwest Corner of the intersection of Grant Avenue and East 169th Street
#
#
# name East 158th Street between Eagle Avenue and Cauldwell Avenue
#
#
# name East 128th Street, Third Avenue Bridge, Harlem River Drive
#
#
# name Harlem River Drive, East 128th Street, Third Avenue Bridge
#
#
# name Watson Avenue between Havemeyer Avenue and East 177th Street
#
#
# name East 177 Street, Westchester Avenue, Virginia Avenue
#
#
# name South of East 115th Street between Third Avenue and Lexington Avenue
#
#
# name Grand Concourse between East 161st and East 164th Streets
#
#
# name Grand Concourse between East 161st and East 164th Streets
#
#
# name Longfellow Avenue, Lowell Street, East 165th Street
#
#
# name Melrose Avenue between East 160 Street and East 159 Street
#
#
# name Melrose Avenue between East 160 Street and East 159 Street
#
#
# name Harlem River, Jerome, River Avenues, Ruppert Place, East 157 Street
#
#
# name Jerome Avenue, East 193 Street, Creston Avenue, East 191 Street
#
#
# name Jerome Avenue, East 193 Street, Creston Avenue, East 191 Street
#
#
# name Mapes Avenue and Prospect Avenue between East 180th Street and East 181st Street
#
#
# name Mapes Avenue and Prospect Avenue between East 180th Street and East 181st Street
#
#
# name Madison Avenue at East 122nd Street
#
#
# name Madison Avenue, East 124th Street, Mount Morris Park West, West 120th Street
#
#
# name West side of Creston Avenue between East Burnside Avenue East 179th Streets
#
#
# name East 177th Street between Noble Avenue and Bronx River Parkway
#
#
# name East 145th Street, Morris and Bronx Avenues.
#
#
# name East River at East 107th Street
#
#
# name East 102 Street & FDR Drive
#
#
# name East 174th Street between Bronx River Avenue and Manor Avenue
#
#
# name East 174th Street between Bronx River Avenue and Manor Avenue.
#
#
# name East 133rd Street, St. Anns Place, East 134th Street, Cypress Avenue
#
#
# name East 133rd Street, St. Anns Place, East 134th Street, Cypress Avenue
#
#
# name Grand Concourse between East Kingsbridge Road and East 192nd Street
#
#
# name 3rd Avenue between East 108th and East 109th Streets
#
#
# name 3rd Avenue between East 108th and East 109th Streets
#
#
# name East 108th Street at 2nd Avenue
#
#
# name East 176th Street between Clinton Avenue and Prospect Avenue
#
#
# name East 181st Street and Oak Tree Place between Quarry Road and Hughes Avenue
#
#
# name West of Brown Place between East 135th and East 136th Streets
#
#
# name West of Brown Place between East 135th and East 136th Streets
#
#
# name Southern Boulevard between East 173rd Street and East 174th Street
#
#
# name Southern Boulevard between East 173rd Street and East 174th Street
#
#
# name East 233rd Street between Baychester Avenue and Seton Avenue
#
#
# name Creston Avenue and East 193rd Street
#
#
# name Jerome Avenue and East 193rd Street
#
#
# name Jerome Avenue between East 190th Street and East 193rd Street
#
#
# name Jerome Avenue between East 190th Street and East 193rd Street
#
#
# name St. Ann's Avenue and East 147th Street
#
#
# name St. Anns Avenue between East 143rd Street and East 149th Street
#
#
# name St. Anns Avenue between East 143rd Street and East 149th Street
#
#
# name St. Anns Avenue between East 145th and East 146th Streets
#
#
# name St. Anns Avenue between East 145th and East 146th Streets
#
#
# name St. Anns Avenue between East 145th and East 147th Streets.
#
#
# name St. Anns Avenue between East 145th and East 147th Streets.
#
#
# name St. Anns Avenue between East 146th Street and East 148th Street
#
#
# name St. Anns Avenue between East 146th Street and East 148th Street
#
#
# name East 114th Street and FDR Drive
#
#
# name East 114th Street between Pleasant Avenue and 1st Avenue
#
#
# name First Avenue between East 111th Street and East 114th Street
#
#
# name First Avenue between East 111th Street and East 114th Street
#
#
# name Between Van Cortlandt Park East and Major Deegan Expressway at East 242nd Street.
#
#
# name East 233rd Street between Jerome Avenue and Van Cortlandt Park East
#
#
# name Van Cortlandt Park East between Oneida Avenue and East 238th Street
#
#
# name Second Avenue between East 120th Street and East 121st Street
#
#
# name Second Avenue between East 120th Street and East 121st Street
#
#
# name Carpenter Avenue between East 239th Street and East 240th Street
#
#
# name Carpenter Avenue between East 239th Street and East 240th Street
#
#
# name East 181st Street and Walton Avenue
#
#
# name Along the western bank of the Bronx River between East Tremont Avenue and East 180th Street
#
#
# name Perry Avenue and East 205th Street
#
#
# name Lexington Avenue between East 105th Street and East 106th Street
#
#
# name Lexington Avenue between East 105th Street and East 106th Street
#
#
# name East 141st Street between Alexander Avenue and Willis Avenue
#
#
# name Melrose Avenue between East 159th and East 160th Streets
#
#
# name Melrose Avenue between East 159th and East 160th Streets
#
#
# name 103 East 122nd Street
#
#
# name Lexington Avenue between East 100th and East 101 Streets
#
#
# name Lexington Avenue between East 100th and East 101 Streets
#
#
# name Pleasant Avenue between East 118 & East 119 Streets
#
#
# name Pleasant Avenue between East 118 & East 119 Streets
#
#
# Summary This project will construct a stormwater greenstreet on Crotona Parkway between East 178th Street and East Tremont Avenue.
#
#
# name East 178th Street and East Tremont Avenue

# %%
grep('East [0-9][0-9][^0-9]', './ParkProjects.txt')
# Out:
# name East 54 Street between 1 Avenue and 2 Avenue
#
#
# name Montgomery Street to East 12 Street, FDR Drive
#
#
# name East End Avenue to East River, East 84 to East 90 Streets
#
#
# name East End Avenue to East River, East 84 to East 90 Streets
#
#
# name FDR Drive, East 90 to East 125 Streets
#
#
# name FDR Drive between East 60th Street and East 62nd Street
#
#
# name FDR Drive between East 60th Street and East 62nd Street
#
#
# name FDR, East River, East 59 & East 63 Streets
#
#
# name FDR, East River, East 59 & East 63 Streets
#
#
# name FDR Drive, East 90 to East 125 Streets
#
#
# name Asser Levy Place between East 23rd Street and East 25th Street
#
#
# name Asser Levy Place between East 23rd Street and East 25th Street
#
#
# name Asser Levy Place between East 23rd Street and East 25th Street
#
#
# name Asser Levy Place between East 23rd Street and East 25th Street
#
#
# name Asser Levy Place between East 23rd Street and East 25th Street
#
#
# name Asser Levy Place between East 23rd Street and East 25th Street
#
#
# name East 54 Street between 1 Avenue and 2 Avenue
#
#
# name S/S Seaview Avenue Opposite East 99 Street
#
#
# name 1st Avenue, Mount Carmel Place, East 26th Street, East 28th Street
#
#
# name 1st Avenue, Mount Carmel Place, East 26th Street, East 28th Street
#
#
# name East 71st Street between Avenue N and Avenue T
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name Seaview Avenue between Paerdegat Basin and East 93 Street, East 102 Street and Fresh Creek Basin
#
#
# name Flatlands Avenue between East 81st Street and East 82nd Street
#
#
# name Flatlands Avenue between East 81st Street and East 82nd Street
#
#
# name Flatlands Avenue between East 81st Street and East 82nd Street
#
#
# name Flatlands Avenue between East 81st Street and East 82nd Street
#
#
# name Bedford Avenue, Avenue X, Avenue Y, East 24th Street
#
#
# name Cross Bay Boulevard, East 16 to East 18 Roads, Channel Road
#
#
# name Cross Bay Boulevard, East 16 to East 18 Roads, Channel Road
#
#
# name East 16th Road, Cross Bay Boulevard, Channel Road
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name Seaview Avenue and East 80th Street.
#
#
# name East End Avenue from Gracie Square to East 86th Street
#
#
# name Fifth Avenue and East 64th Street
#
#
# name Located at Fifth Avenue and East 64th Street in Central Park, Borough of Manhattan
#
#
# name East 54 Street between 1 Avenue and 2 Avenue
#
#
# name East 10 Street & Szold Place, Avenue D
#
#
# name East 47th Street between First Avenue and Second Avenue
#
#
# name Szold Place, Avenue D and East 10th Street
#
#
# name East River between East 36th and East 38th Streets
#
#
# name East River between East 36th and East 38th Streets
#
#
# Summary This project will construct a masonry ramp to provide ADA access to John Finley Walk at East 82nd Street.
#
#
# Title East River Esplanade Reconstruction, East 68th-70th Streets
#
#
# Summary This project will reconstruct the East River Esplanade from East 68th Street to East 70th Street.
#
#
# Summary This project will reconstruct the East River Esplanade from East 68th Street to East 70th Street.
#
#
# name between the East River and FDR Drive, East 68th Street to East 70th Street
#
#
# name between the East River and FDR Drive, East 68th Street to East 70th Street
#
#
# Title East River Esplanade East 74th Street Reconstruction
#
#
# Summary This project will reconstruct the East River Esplanade at East 74th Street.
#
#
# name East River Esplanade Reconstruction at East 74th Street.
#
#
# name East 54 Street between 1 Avenue and 2 Avenue
#
#
# name 1940 East 36th Street, Brooklyn
#
#
# name Williams Court, East 14th Street, Homecrest Avenue, Shore Parkway
#
#
# name East 59th Street between 1st Avenue and 2nd Avenue.
#
#
# name East 58th Street and East 59th Street near Avenue L
#
#
# name East 58th Street and East 59th Street near Avenue L
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name East 76-East 78 Streets, Cherokee Place
#
#
# name FDR Drive between East 76th Street and East 78th Street
#
#
# name FDR Drive between East 76th Street and East 78th Street
#
#
# name East 12th Street between Avenue A & Avenue B
#
#
# name Avenue S between East 14th Street and East 15th Street
#
#
# name Avenue S between East 14th Street and East 15th Street
#
#
# name Moore Place and East 16th Street
#
#
# name Avenue L, East 17th Street, East 18th Street
#
#
# name Avenue L, East 17th Street, East 18th Street
#
#
# name Strickland Avenue, East 60th Street and Mill Avenue, Brooklyn
#
#
# name East 23rd Street, 5th Avenue, East 26th Street, Madison Avenue
#
#
# name East 23rd Street, 5th Avenue, East 26th Street, Madison Avenue
#
#
# name Avenue U and East 33rd Street
#
#
# name Avenue U, Stuart Street, Fillmore Avenue, East 33rd Street
#
#
# name Located on the corner of Fillmore Avenue and East 32nd Street in Marine Park.
#
#
# name N/S East 42 Street & Tudor Place
#
#
# name S/S East 42 Street, 1 to 2 Avenues
#
#
# name Avenue V between East 13th Street and East 14th Street
#
#
# name Avenue V between East 13th Street and East 14th Street
#
#
# name East 40th Street, Foster Avenue, Albany Avenue, and Farragut Road, Brooklyn
#
#
# name Avenue N between East 49th Street and Utica Avenue
#
#
# name Tilden Avenue, East 48 to East 49 Streets
#
#
# name Tilden Avenue, East 48 to East 49 Streets
#
#
# name Emmons Avenue between East 21st Street and East 26th Street
#
#
# name Emmons Avenue between East 21st Street and East 26th Street
#
#
# name East 35th Street, Queens-Midtown Tunnel Entrance, East 36th Street
#
#
# name East 35th Street, Queens-Midtown Tunnel Entrance, East 36th Street
#
#
# name Rutherford Place, Nathan D. Perlman Place, East 15th Street, East 17th Street
#
#
# name Rutherford Place, Nathan D. Perlman Place, East 15th Street, East 17th Street
#
#
# name Kings Highway, Avenue H, East 49th Street
#
#
# name Tilden Avenue between East 48th and East 49th Streets
#
#
# name Tilden Avenue between East 48th and East 49th Streets
#
#
# name East 7th Street, Avenue A, East 10th Street, Avenue B
#
#
# name First Avenue between East 41st Street and East 42nd Street
#
#
# name First Avenue between East 41st Street and East 42nd Street
#
#
# name FDR Drive, East 60th Street, East 61st Street, York Avenue
#
#
# name FDR Drive, East 60th Street, East 61st Street, York Avenue
#
#
# name East 29th Street and 2nd Avenue

# %% [markdown]
# ## Anchors
#
# Are atoms used to define the location of a regex within a line :
#
# - the '^' anchor specifies the beginning of the line
# - the '$' anchor specifies the end of a line
# - the '\b' anchor specifies a word boundry

# %%
grep('^Summary This project will reconstruct', './ParkProjects.txt')
# Out:
# Summary This project will reconstruct A. Philip Randolph Square.
#
#
# Summary This project will reconstruct mechanical & electrical controls, fire alarm systems, boilers & dehumidifiers damaged by Hurricane Sandy.
#
#
# Summary This project will reconstruct deteriorated structural systems at park and pool facilities citywide.
#
#
# Summary This project will reconstruct Abraham Lincoln Playground.
#
#
# Summary This project will reconstruct the comfort station in Abraham Lincoln Playground.
#
#
# Summary This project will reconstruct Agnes Haywood Playground.
#
#
# Summary This project will reconstruct Al Stabile Playground.
#
#
# Summary This project will reconstruct the synthetic turf field, basketball court, and drainage systems in Albemarle Playground.
#
#
# Summary This project will reconstruct roofs at various facilities in Manhattan.
#
#
# Summary This project will reconstruct deteriorated electrical systems at parks and recreation pool facilities citywide.
#
#
# Summary This project will reconstruct Alfred E. Smith Recreation Center.
#
#
# Summary This project will reconstruct clapboard siding and structural portions of the McFarlane-Bredt House located in Alice Austen Park.
#
#
# Summary This project will reconstruct  timber barrier rail and paths damaged from Hurricane Sandy and install new curbs at Buono Beach in Alice Austen Park.
#
#
# Summary This project will reconstruct the landscape elements at Alice Austen Park including picket fences and paths due to damage sustained during Hurricane Sandy. The project will also include the installation of security lighting.
#
#
# Summary This project will reconstruct the electrical and mechanical components of the fountain at Buono Beach in Alice Austen Park.
#
#
# Summary This project will reconstruct play equipment, safety surfacing, pavements and general site work at various locations in the Bronx.
#
#
# Summary This project will reconstruct parks, playgrounds and site work at various sites in the Bronx.
#
#
# Summary This project will reconstruct pavements, fencing, tennis courts, handball courts and plantings at various parks in Queens.
#
#
# Summary This project will reconstruct play equipment, pavements, fencing, and plantings in Queens.
#
#
# Summary This project will reconstruct the paths and address drainage issues at Oakland Lake in Alley Pond Park.
#
#
# Summary This project will reconstruct electrical systems in various parks citywide.
#
#
# Summary This project will reconstruct the plumbing systems in comfort stations at various park facilities citywide.
#
#
# Summary This project will reconstruct pavements, fencing, plantings, and benches in at various parks in Queens.
#
#
# Summary This project will reconstruct Vanderbilt Motor Parkway from Winchester Boulevard to Springfield Boulevard.
#
#
# Summary This project will reconstruct guide rails and fences at various parks citywide.
#
#
# Summary This project will reconstruct pathways at Oakland Lake in Alley Pond Park
#
#
# Summary This project will reconstruct and stabilize retaining walls and seawalls in parks citywide.
#
#
# Summary This project will reconstruct Almeda Playground.
#
#
# Summary This project will reconstruct pavements, fencing, tennis courts, handball courts, and plantings in Queens.
#
#
# Summary This project will reconstruct Greenstreet fencing at Amsterdam Avenue and West 127th Street.
#
#
# Summary This project will reconstruct the roofing systems at various facilities in Manhattan.
#
#
# Summary This project will reconstruct the plaza, paths, and landscape in Aqueduct Walk.
#
#
# Summary This project will reconstruct Morton Playground, including the basketball courts, play equipment, safety surface, water and drainage systems, park lighting, and landscaping.
#
#
# Summary This project will reconstruct roofs at various park facilities in the Bronx and Queens.
#
#
# Summary This project will reconstruct the pavement at Arrochar Playground.
#
#
# Summary This project will reconstruct the comfort stations at Arrochar Playground and Grandview Playground.
#
#
# Summary This project will reconstruct the playground and multi-use area at Arrochar Playground adjacent to PS 39.
#
#
# Summary This project will reconstruct the safety surfacing at Dekovats Playground.
#
#
# Summary This project will reconstruct the playground and adjacent paths in Asser Levy Park.
#
#
# Summary This project will reconstruct the boiler and pool dehumidification system at Asser Levy Recreation Center.
#
#
# Summary This project will reconstruct the HVAC system at Asser Levy Recreation Center.
#
#
# Summary This project will reconstruct Astoria Health Playground.
#
#
# Summary This project will reconstruct the comfort stations at Astoria Heights Playground and Bowne Playground.
#
#
# Summary This project will reconstruct Astoria Heights Playground.
#
#
# Summary This project will reconstruct Astoria Park.
#
#
# Summary This project will reconstruct the filtration system at Astoria Pool.
#
#
# Summary This project will reconstruct the diving pool at the Astoria Park Bathhouse for use as an outdoor plaza.
#
#
# Summary This project will reconstruct Charybdis Playground and construct a spray shower in Astoria Park.
#
#
# Summary This project will reconstruct the comfort station at Charybdis Playground in Astoria Park.
#
#
# Summary This project will reconstruct the track and field in Astoria Park.
#
#
# Summary This project will reconstruct the playground at Arrow Recreation Center.
#
#
# Summary This project will reconstruct the plaza and adjacent seating area in Athens Square Playground.  The cheek walls on either side of the two ramps will be reconstructed and a new ramp will be constructed between the seating area and the plaza.  New handrails will be installed, 2 1/2 foot fencing will be placed around plant beds, plant material will be replaced as needed, and a trench drain will be installed near the spray shower to keep water from flowing onto the safety surface.
#
#
# Summary This project will reconstruct the comfort station at Audubon Playground and make it ADA accessible.
#
#
# Summary This project will reconstruct Audubon Playground.
#
#
# Summary This project will reconstruct three comfort stations at various locations in Staten Island.
#
#
# Summary This project will reconstruct the playground and multi-use area at McDonald Playground.
#
#
# Summary This project will reconstruct the playground and seating area at Babi Yar Triangle.
#
#
# Summary This project will reconstruct tennis, basketball and handball courts in Baisley Pond Park; basketball courts and an entry ramp at Police Officer Nicholas Demutiis Playground; and basketball and handball courts at Harvard Playground in Queens.
#
#
# Summary This project will reconstruct paths in Baisley Pond Park.
#
#
# Summary This project will reconstruct the track, convert the natural turf field to synthetic turf, and construct an adult fitness area at Baisley Pond Park.
#
#
# Summary This project will reconstruct the roof at the comfort station in Banneker Playground.
#
#
# Summary This project will reconstruct the comfort stations at Banneker Playground and Tilden Playground.
#
#
# Summary This project will reconstruct Bartlett Playground.
#
#
# Summary This project will reconstruct the comfort station at Baruch Playground.
#
#
# Summary This project will reconstruct synthetic turf fields at various locations in Manhattan.
#
#
# Summary This project will reconstruct portions of Bath Beach Park, including new play equipment, pavements, safety surfacing, site furnishings, drainage, water supply and other site amenities.
#
#
# Summary This project will reconstruct the lower entrance, handball court, basketball court, and multipurpose play area at Bay Terrace Playground.
#
#
# Summary This project will reconstruct the comfort station in Bayside Playground.
#
#
# Summary This project will reconstruct the playground, sports courts and fields and construct a new comfort station at Bayswater Park.
#
#
# Summary This project will reconstruct plumbing and HVAC systems at comfort stations and facilities at various parks and recreation locations citywide.
#
#
# Summary This project will reconstruct electrical systems at comfort stations and other park facilities citywide.
#
#
# Summary This project will reconstruct comfort stations and facilities at various parks and recreation locations citywide.
#
#
# Summary This project will reconstruct Beach 59th Street Playground with new play equipment, safety surface, pavements, fencing, spray shower, benches and game tables.
#
#
# Summary This project will reconstruct the basketball courts at Beach 9th Street Playground.
#
#
# Summary This project will reconstruct Beach Channel (P.S. 183) playground located south of Beach Channel Drive between Beach 79th & Beach 80th Street.
#
#
# Summary This project will reconstruct the landscape and complete miscellaneous site work in Bellevue South Park.
#
#
# Summary This project will reconstruct the bicycle path and seawall along Shore Parkway.
#
#
# Summary This project will reconstruct the handball court and asphalt field at Benson Playground.
#
#
# Summary This project will reconstruct tennis courts and basketball courts at various parks in Brooklyn.
#
#
# Summary This project will reconstruct the boilers and heating systems at Bensonhurst Senior Recreation Center in Brooklyn and at the comfort station in Mosholu Parkway in the Bronx.
#
#
# Summary This project will reconstruct the playground, adjacent path system and sitting areas at the north end of Bensonhurst Park.
#
#
# Summary This project will reconstruct Bergen Beach Playground.
#
#
# Summary This project will reconstruct deteriorated plumbing systems at pools citywide.
#
#
# Summary This project will reconstruct deteriorated electrical systems at various pools citywide.
#
#
# Summary This project will reconstruct the roofing systems at various facilities in Brooklyn and Staten Island.
#
#
# Summary This project will reconstruct the pool piping hangers and supports at various locations citywide.
#
#
# Summary This project will reconstruct the comfort station and utility building in Betsy Head Park.
#
#
# Summary This project will reconstruct the concrete sidewalks and complete other related site work at various locations in the Bronx.
#
#
# Summary This project will reconstruct the playground, spray shower, handball courts, sitting area, fencing and pavements in Big Bush Park.
#
#
# Summary This project will reconstruct Bill 'Bojangles' Robinson Playground.
#
#
# Summary This project will reconstruct the comfort station in Bill Brown Playground.
#
#
# Summary This project will reconstruct Black Rock Playground.
#
#
# Summary This project will reconstruct Bland Playground.
#
#
# Summary This project will reconstruct Bleecker Playground, including the comfort station.
#
#
# Summary This project will reconstruct the synthetic turf field, rain garden and will install new field lighting at Greenbelt Recreation Center.
#
#
# Summary This project will reconstruct recreational lighting and overhead electrical lines due to Hurricane Sandy at various parks locations citywide.
#
#
# Summary This project will reconstruct the HVAC systems at the Greenbelt Recreation Center located in Staten Island and the Queens Museum located in Queens.
#
#
# Summary This project will reconstruct play equipment, pavements, fencing, water supply, drainage, site features, and plantings at various parks in Staten Island.
#
#
# Summary This project will reconstruct the comfort station in Bloomingdale Playground, bringing it into compliance with ADA accessibility standards.
#
#
# Summary This project will reconstruct basketball courts, paths, benches, spray shower, planting, play equipment and adult fitness equipment at Bloomingdale Playground.
#
#
# Summary This project will reconstruct the synthetic turf field, basketball backstops, and chain link fencing at Booker T. Washington Playground.
#
#
# Summary This project will reconstruct the playground and basketball court in Bowne Park.
#
#
# Summary This project will reconstruct comfort stations and facilities at various parks and recreation locations in Queens.
#
#
# Summary This project will reconstruct the pond in Bowne Park.
#
#
# Summary This project will reconstruct the plaza adjacent to bocce area with a new passive sitting area, decorative elements and plantings at Bowne Park.
#
#
# Summary This project will reconstruct the playground, asphalt field, seating area and swings at Bowne Playground.
#
#
# Summary This project will reconstruct the playgrounds at Briarwood Playground and Phil 'Scooter' Rizzuto Park.
#
#
# Summary This project will reconstruct the play equipment, swings, and spray shower and construct a new adult fitness area, a multi-purpose synthetic turf field with a performance stage, benches, fences, drainage, water supply and planting at Bridge Park 2.
#
#
# Summary This project will reconstruct Bridge Playground.
#
#
# Summary This project will reconstruct play equipment, safety surfacing, athletic fields, pavements, fencing, and masonry at various parks in Brooklyn that were damaged by Hurricane Sandy.
#
#
# Summary This project will reconstruct a stairway at Cunningham Park, the passive area of Brinkerhoff Mall, and fencing around the dog run in Forest Park, and construct a roller hockey rink at Broad Channel Park.
#
#
# Summary This project will reconstruct Brizzi Playground and the paths adjacent to Ben Vitale Fields in Dyker Beach Park.
#
#
# Summary This project will reconstruct the asphalt ballfield in Broad Channel American Park.
#
#
# Summary This project will reconstruct the entry plaza, including new benches, pavement and fencing, at Broad Channel Park.
#
#
# Summary This project will reconstruct landscapes, pavements, fences and benches at several malls along Broadway from West 102nd to 104th Streets and from West 137th to 139th Streets.
#
#
# Summary This project will reconstruct the roof at Ranaqua in Bronx Park.
#
#
# Summary This project will reconstruct the loading ramp at Ranaqua in Bronx Park.
#
#
# Summary This project will reconstruct roofing systems at various sites in the Bronx and Queens.
#
#
# Summary This project will reconstruct the basketball courts and the playground at Waring Playground in Bronx Park.
#
#
# Summary This project will reconstruct an existing portion and construct a new portion of the Bronx River Greenway.
#
#
# Summary This project will reconstruct paths and drainage systems, construct new entrances, and bioswales and rain gardens, and formalize the Bronx River Greenway in Shoelace Park.
#
#
# Summary This project will reconstruct the paths, landscape and staircase at East 233rd Street in Bronx River Park.
#
#
# Summary This project will reconstruct the softball field with a natural grass outfield and a running track with artificial turf multiuse infield at Parque de los Ninos.
#
#
# Summary This project will reconstruct the playground and seating area at Parque de los Ninos.
#
#
# Summary This project will reconstruct an entrance to Brookville Park.
#
#
# Summary This project will reconstruct Brookville Park.
#
#
# Summary This project will reconstruct water service, lighting, and pavements at various locations in Queens.
#
#
# Summary This project will reconstruct the natural turf baseball fields at Brookville Park.
#
#
# Summary This project will reconstruct the synthetic turf field at Brookville Park.
#
#
# Summary This project will reconstruct the picnic area and construct a tennis court and lighting at Brookville Park.
#
#
# Summary This project will reconstruct the basketball courts at Brower Park.
#
#
# Summary This project will reconstruct the pool HVAC system at Brownsville Recreation Center.
#
#
# Summary This project will reconstruct the interior and infrastructure of Brownsville Recreation Center.
#
#
# Summary This project will reconstruct HVAC systems at Lost Battalion Hall Recreation Center and Brownsville Recreation Center.
#
#
# Summary This project will reconstruct the roofing systems at various parks facilities in Brooklyn and Staten Island.
#
#
# Summary This project will reconstruct the roof at Brownsville Recreation Center.
#
#
# Summary This project will reconstruct the concrete pool deck at Bushwick Playground.
#
#
# Summary This project will reconstruct deteriorated structural systems at various pool facilities citywide.
#
#
# Summary This project will reconstruct deteriorated electrical systems at various pool facilities citywide.
#
#
# Summary This project will reconstruct deteriorated plumbing systems at various pool facilities citywide.
#
#
# Summary This project will reconstruct buildings and comfort stations in various parks citywide.
#
#
# Summary This project will reconstruct Butterfly Gardens including new pavements, fencing, benches, and trash receptacles and expanded planted areas.
#
#
# Summary This project will reconstruct the oval at Cadman Plaza Park.
#
#
# Summary This project will reconstruct the comfort stations at Marlboro Playground and Cadman Plaza East Comfort Station, in the borough of Brooklyn
#
#
# Summary This project will reconstruct Brooklyn War Memorial Restroom and Eleanor Roosevelt Playground Comfort Station.
#
#
# Summary This project will reconstruct the playground, spray shower, perimeter sidewalks and walls, basketball courts, adult fitness equipment and sitting areas in Callahan-Kelly Playground. In addition, this project will construct a new skate park and park entrances.
#
#
# Summary This project will reconstruct basketball and handball courts at Nautilus Playground and Cambria Playground, and the basketball courts at Walter Ward Playground.
#
#
# Summary This project will reconstruct the plaza area in Captain Tilly Park.
#
#
# Summary This project will reconstruct the comfort station in Captain Tilly Park.
#
#
# Summary This project will reconstruct the landscaped areas and drainage structures at Captain Tilly Park.
#
#
# Summary This project will reconstruct the children's playground in Carl Schurz Park.
#
#
# Summary This project will reconstruct the play areas, paths, fencing, landscape and park amenities at Carlton Park and Ida Court Playground.
#
#
# Summary This project will reconstruct comfort stations in various locations in the Bronx and Manhattan.
#
#
# Summary This project will reconstruct Carmansville Playground.
#
#
# Summary This project will reconstruct Carroll Park.
#
#
# Summary This project will reconstruct the multipurpose play area at Castlewood Playground.
#
#
# Summary This project will reconstruct the playground, basketball courts and adjacent landscape in Cedar Playground.
#
#
# Summary This project will reconstruct the comfort station in Cedar Playground.
#
#
# Summary This project will reconstruct the elevator at the Arsenal in Central Park.
#
#
# Summary This project will reconstruct the facade and roof at the Arsenal building in Central Park.
#
#
# Summary This project will reconstruct the play equipment, fencing, and spray shower area at Challenge Playground.
#
#
# Summary This project will reconstruct Chappetto Square.
#
#
# Summary This project will reconstruct the basketball and handball courts, provide fencing, water supply and construct a new entrance along Ellery Street at Charlie's Place.
#
#
# Summary This project will reconstruct the basketball court and adjacent paths and landscape at Chelsea Park.
#
#
# Summary This project will reconstruct the entrance lobby area at the Chelsea Recreation Center.
#
#
# Summary This project will reconstruct the men's and women's locker rooms at the Chelsea Recreation Center.
#
#
# Summary This project will reconstruct the HVAC systems at Al Oerter Recreation Center, Recreation Center 54, and Chelsea Recreation Center.
#
#
# Summary This project will reconstruct Chester Playground.
#
#
# Summary This project will reconstruct the playground and basketball court at Christopher J. Igneri Playground.
#
#
# Summary This project will reconstruct pathways and pavement at Claremont Park.
#
#
# Summary This project will reconstruct Claremont Park.
#
#
# Summary This project will reconstruct the area of Clawson Playground behind PS 50 with new play equipment, safety surfacing, benches and plantings.
#
#
# Summary This project will reconstruct Clement Clarke Moore Park.
#
#
# Summary This project will reconstruct concrete curbs and drainage systems and construct an accessible ramp at the parking lot and comfort station in Clove Lakes Park.
#
#
# Summary This project will reconstruct the adult fitness equipment in Clove Lakes Park.
#
#
# Summary This project will reconstruct the boiler and heating systems at Stonehenge in Clove Lakes Park.
#
#
# Summary This project will reconstruct pavements, fencing and landscaping elements at various parks in Staten Island.
#
#
# Summary This project will reconstruct the rink condensers at the WWII Veterans War Memorial Ice Rink in Clove Lakes Park.
#
#
# Summary This project will reconstruct the entrance area, fencing, bleachers, and pavements at Co-Op City Field.
#
#
# Summary This project will reconstruct the paths in Coffey Park and formalize the central plaza area. The project will also provide larger planted areas for existing trees and a formal, ADA-accessible BBQ area.
#
#
# Summary This project will reconstruct roller hockey rinks at Juniper Valley Park, Harvey Park, Mafera Park and College Point Park.
#
#
# Summary This project will reconstruct the east and west Ocean Parkway Malls from Avenue O to Kings Highway with new asphalt pavement, pipe handrails, trees, benches, signage, greenway markings and curbs; expanded tree pits and restored granite block pavers and a mile marker. This project will also reconstruct the handball and basketball courts, paving, fencing, gates and landscaping and construct a new ADA-accessible drinking fountain in Colonel David Marcus Playground.
#
#
# Summary This project will reconstruct the playground, sitting area and multi-purpose play area at Jackie Robinson Playground and the playground at Colonel David Marcus Playground.
#
#
# Summary This project will reconstruct the comfort station in Colonel David Marcus Playground.
#
#
# Summary This project will reconstruct the comfort station in Columbus Park.
#
#
# Summary This project will reconstruct the pavement at Columbus Park.
#
#
# Summary This project will reconstruct the Mulberry Street entrance at Columbus Park.
#
#
# Summary This project will reconstruct the concrete pool deck at Commodore John Barry Park.
#
#
# Summary This project will reconstruct the comfort station in Commodore Barry Park.
#
#
# Summary This project will reconstruct the playground at Commodore Barry Park.
#
#
# Summary This project will reconstruct the natural turf ballfields and construct new sports lighting and a track around the ballfields in Commodore Barry Park.
#
#
# Summary This project will reconstruct Conch (PS.105) Playground.
#
#
# Summary This project will reconstruct the Coney Island Boardwalk between Brighton 15th Street and Coney Island Avenue and the entrance at Brighton 15th Street.
#
#
# Summary This project will reconstruct timber barrier rail damaged from Hurricane Sandy at Conference House Park.
#
#
# Summary This project will reconstruct Lenape Playground.
#
#
# Summary This project will reconstruct temporary berms installed after Hurricane Sandy at Conference House Beach in Staten Island.
#
#
# Summary This project will reconstruct the Visitor Center at Conference House Park to provide ADA-accessible restrooms.
#
#
# Summary This project will reconstruct the Conference House Pavilion in Conference House Park.
#
#
# Summary This project will reconstruct Hurricane Sandy-damaged paths, the overlook and the parking lot in Conference House Park.
#
#
# Summary This project will reconstruct the basketball, handball and beach volleyball courts, and construct a dog run in Cooper Park.
#
#
# Summary This project will reconstruct the comfort station in Cooper Park.
#
#
# Summary This project will reconstruct the comfort station at Corlears Hook Park.
#
#
# Summary This project will reconstruct the dog run at Corlears Hook Park, adding stable ground surface, water features and dog waste containers, and replacing fencing.
#
#
# Summary This project will reconstruct pavements at Corona Golf Playground.
#
#
# Summary This project will reconstruct the sidewalks at Corona Golf Playground.
#
#
# Summary This project will reconstruct the comfort station at Seravalli Playground.
#
#
# Summary This project will reconstruct Court Square Park.
#
#
# Summary This project will reconstruct the pavement, backstop, drainage system, and benches at the handball court in Courtney Callender Playground.
#
#
# Summary This project will reconstruct filter plants at various intermediate-sized pools citywide.
#
#
# Summary This project will reconstruct the basketball courts, pavements, fencing, safety surfacing, timber barrier rails and landscaping elements at various sites in Staten Island.
#
#
# Summary This project will reconstruct temporary berms installed after Hurricane Sandy at Crescent Beach Park in Staten Island.
#
#
# Summary This project will reconstruct the handball and basketball courts in Crispus Attucks Playground.
#
#
# Summary This project will reconstruct the ballfields at Crocheron Park.
#
#
# Summary This project will reconstruct the waterfront Parks infrastructure damaged by Hurricane Sandy at Joe Michael's Mile.
#
#
# Summary This project will reconstruct the fixed pier, floating docks, and other Sandy-damaged elements at Bayside Marina.
#
#
# Summary This project will reconstruct the southern portion of Joe Michael's Mile.
#
#
# Summary This project will reconstruct the nature center in Crotona Park.
#
#
# Summary This project will reconstruct ballfield 5 at Crotona Park with synthetic turf.
#
#
# Summary This project will reconstruct play equipment, safety surfacing, pavements, and handball courts at various parks in the Bronx.
#
#
# Summary This project will reconstruct the comfort station at Playground of the Stars in Crotona Park.
#
#
# Summary This project will reconstruct the entrance towers, mezzanine roof and bridge at the entrance to the Crotona Park Bathhouse.
#
#
# Summary This project will reconstruct Crowley Playground.
#
#
# Summary This project will reconstruct Frank O'Connor Playground, Crowley Playground, and Real Good Playground.
#
#
# Summary This project will reconstruct the Lower Playground (Redwood Playground) in Cunningham Park.
#
#
# Summary This project will reconstruct the pathways at Redwood Playground in Cunningham Park.
#
#
# Summary This project will reconstruct 210th Street Playground at Cunningham Park.
#
#
# Summary This project will reconstruct the picnic area and the adjacent pathways, and construct a performance area in Cunningham Park.
#
#
# Summary This project will reconstruct Vanderbilt Motor Parkway from Springfield Boulevard to 199th Street north of 67th Avenue.
#
#
# Summary This project will reconstruct the garage in Cunningham Park.
#
#
# Summary This project will reconstruct ballfields 2, 3 and 4 in Cunningham Park.
#
#
# Summary This project will reconstruct Dag Hammarskjold Plaza including the pavilions, trellises, fences, benches, light poles, pavements, trees, and planting beds.
#
#
# Summary This project will reconstruct the playground at Daniel O'Connell Playground.
#
#
# Summary This project will reconstruct the recreation building in Daniel M. O'Connell Playground.
#
#
# Summary This project will reconstruct roofing systems at various parks and recreation facilities in Brooklyn and Staten Island.
#
#
# Summary This project will reconstruct DeMatti Park, with a new playground, spray shower, adult fitness area, lawn, bocce courts, and performance space.
#
#
# Summary This project will reconstruct the staircases in DeWitt Clinton Park.
#
#
# Summary This project will reconstruct pavements, fences, plantings, plumbing and general site work in Manhattan.
#
#
# Summary This project will reconstruct roofing systems in Manhattan.
#
#
# Summary This project will reconstruct DeLury Square.
#
#
# Summary This project will reconstruct DeSalvio Playground.
#
#
# Summary This project will reconstruct the pool deck at Liberty Pool.
#
#
# Summary This project will reconstruct pavements, handball courts, fencing, and plantings in Queens.
#
#
# Summary This project will reconstruct comfort stations and facilities at various parks and recreation locations in Queens.
#
#
# Summary This project will reconstruct the basketball courts at Detective Keith L. Williams Park (Liberty Park).
#
#
# Summary This project will reconstruct the maintenance shed roof at Devoe Park.
#
#
# Summary This project will reconstruct Di Gilio Playground.
#
#
# Summary This project will reconstruct the play equipment, safety surface, spray shower, benches, and security lighting at Ditmars Playground.
#
#
# Summary This project will reconstruct the basketball & handball courts located in Dome Playground.
#
#
# Summary This project will reconstruct the play area and lawn at Dome Playground.
#
#
# Summary This project will reconstruct the play area and sidewalks at Dongan Playground.
#
#
# Summary This project will reconstruct the seating area surrounding the monument at Doughboy Plaza, including the drinking fountain and pathways.
#
#
# Summary This project will reconstruct the pool deck at Dry Dock Pool.
#
#
# Summary This project will reconstruct the play equipment and security lighting at Dry Dock Playground.
#
#
# Summary This project will reconstruct the ballfields in Dugan Playground and Schmul Park.
#
#
# Summary This project will reconstruct the play equipment, swings, spray shower, and seating area at Dugan Playground.
#
#
# Summary This project will reconstruct Dunningham Triangle and the basketball court and spray shower at Playground Ninety.
#
#
# Summary This project will reconstruct the playground and court area in Dutch Kills Playground.
#
#
# Summary This project will reconstruct the comfort station at Dutch Kills Playground.
#
#
# Summary This project will reconstruct the multipurpose play areas at Dyker Playground in Dyker Beach Park, Patrick O'Rourke Playground and Wilson Playground.
#
#
# Summary This project will reconstruct the existing synthetic turf soccer field, bleachers, and drinking fountain at Dyker Beach Park.
#
#
# Summary This project will reconstruct Prescott Playground, including fencing, retaining walls, play equipment, and pavements.
#
#
# Summary This project will reconstruct comfort stations and facilities at various parks and recreation locations in Queens.
#
#
# Summary This project will reconstruct the playground and handball courts at PS 127 (East Elmhurst) Playground.
#
#
# Summary This project will reconstruct the electrical systems at Glick Park due to damage from Hurricane Sandy.
#
#
# Summary This project will reconstruct the waterfront Parks infrastructure at Glick Park.
#
#
# Summary This project will reconstruct the East River Esplanade from East 68th Street to East 70th Street.
#
#
# Summary This project will reconstruct the East River Esplanade at East 74th Street.
#
#
# Summary This project will reconstruct the basketball courts, demolish the existing above-ground mini-pool and construct a new in-ground mini-pool at Edenwald Playground.
#
#
# Summary This project will reconstruct the comfort station at Ehrenreich-Austin Playground.
#
#
# Summary This project will reconstruct the comfort station plumbing system at Ehrenreich-Austin Playground.
#
#
# Summary This project will reconstruct the comfort station electrical system at Ehrenreich-Austin Playground.
#
#
# Summary This project will reconstruct the play areas at Ehrenreich-Austin Playground, Utopia Playground, and Giovannelli Playground.
#
#
# Summary This project will reconstruct Ennis Playground.
#
#
# Summary This project will reconstruct the playground, spray shower, seating, handball and basketball courts, perimeter fence, and security lighting at Epiphany Playground.
#
#
# Summary This project will reconstruct the playground at Equity Park.
#
#
# Summary This project will reconstruct the basketball courts in Evergreen Park.
#
#
# Summary This project will reconstruct a basketball court and construct a tot lot and miscellaneous site work in Ewen Park.
#
#
# Summary This project will reconstruct deteriorated plumbing systems at parks and recreation pool facilities citywide.
#
#
# Summary This project will reconstruct the boilers and heating systems at Faber Pool and Lyons Pool.
#
#
# Summary This project will reconstruct the waterfront Parks infrastructure at Faber Park.
#
#
# Summary This project will reconstruct a portion of Ferry Point Park damaged by Hurricane Sandy.
#
#
# Summary This project will reconstruct paths and pavement at Wyckoff House.
#
#
# Summary This project will reconstruct the roof at the Wyckoff House in M. Fidler/Wyckoff House Park.
#
#
# Summary This project will reconstruct the ballfield closest to 25th Avenue in Memorial Field of Flushing.
#
#
# Summary This project will reconstruct the men's locker room in the FMCP pool facility into a family changing room.
#
#
# Summary This project will reconstruct the Henry Hudson entrance at Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the Olmsted Center in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the roof at the Flushing Meadows Corona Park Pool.
#
#
# Summary This project will reconstruct the roof at the Flushing Meadows Corona Park Aquatic Center.
#
#
# Summary This project will reconstruct synthetic turf soccer field 1 in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the roadway and paths along Meadow Lake Promenade in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the Parks Maintenance and Operations garage in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct and provide for the adaptive re-use of the Reflecting Pool in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct synthetic turf fields 8 & 9 in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the deteriorated fixed piers, floating docks, bulkhead, and related components, including Sandy-damaged elements.
#
#
# Summary This project will reconstruct the asphalt field at World's Fair Playground in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the electrical vault in Flushing Meadows Corona Park that was damaged by Hurricane Sandy.
#
#
# Summary This project will reconstruct pavements and fences at the tennis courts and near the LIRR tracks in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the Candela Structures at Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct synthetic turf fields 2, 3, and 5 in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the pedestrian and vehicle pathways in Flushing Meadow Park.
#
#
# Summary This project will reconstruct Mauro Playground in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct portions of the New York State Pavilion Observation Towers in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the Roosevelt Avenue entrance to Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the comfort station at Lawrence Playground in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct Lawrence Playground in Flushing Meadows Corona Park.
#
#
# Summary This project will reconstruct the sidewalks, guardrails, curbs and crosswalks at Oakridge Turn in Forest Park.
#
#
# Summary This project will reconstruct the comfort station at Sobelsohn Playground in Forest Park.
#
#
# Summary This project will reconstruct the comfort station plumbing system at Sobelsohn Playground in Forest Park.
#
#
# Summary This project will reconstruct the comfort station electrical system at Sobelsohn Playground in Forest Park.
#
#
# Summary This project will reconstruct Mary Whalen Playground.
#
#
# Summary This project will reconstruct roofs at Forest Park Garage and Oak Ridge in Forest Park.
#
#
# Summary This project will reconstruct pavements, fencing and drainage systems at various parks in Queens.
#
#
# Summary This project will reconstruct Lt. Clinton L. Whiting Square, the sidewalk and guide rail along the west side of Harvey Park, and the pathway between Park Lane South at 86th Street and the bandshell in Forest Park.
#
#
# Summary This project will reconstruct the fencing at Underbridge Dog Run and Forest Park Overlook Dog Run.
#
#
# Summary This project will reconstruct the paths, drainage and the T-ball field in Forest Park.
#
#
# Summary This project will reconstruct Joe Devoy Playground in Forest Park.
#
#
# Summary This project will reconstruct the Palm House at the Forest Park Greenhouse.
#
#
# Summary This project will reconstruct the oval plaza, lower plaza and sidewalk along Myrtle Avenue and staircases at St. Edwards Street and Willoughby Street and at DeKalb Avenue and Washington Park. The work will include pavement, drainage and handrail reconstruction, and new plantings, water features, lighting, seating, barbecues, and adult fitness equipment.
#
#
# Summary This project will reconstruct the park paths, staircases, entrances, drainage, and grading at Fort Greene Park.
#
#
# Summary This project will reconstruct the Willoughby Avenue entrance, park paths, perimeter sidewalks and landscape elements in Fort Greene Park.
#
#
# Summary This project will reconstruct basketball and tennis courts in Fort Hamilton Park.
#
#
# Summary This project will reconstruct the roof at Building 429 in Fort Totten Park.
#
#
# Summary This project will reconstruct the telecommunication lines at Fort Totten Park.
#
#
# Summary This project will reconstruct the front portico at the Bayside Historical Society Officers Club in Fort Totten Park.
#
#
# Summary This project will reconstruct the steeple spire and bell tower at the Chapel and reconstruct the roof and exterior woodwork at the Commander's House at Fort Totten.
#
#
# Summary This project will reconstruct the seawall in Fort Totten Park.
#
#
# Summary This project will reconstruct the path and stairs in Fort Tryon Park that lead to the Cloisters.  The fencing and lighting along the pathway will also be reconstructed and upgraded.
#
#
# Summary This project will reconstruct the spray shower plaza, children's climber play equipment, and safety surfacing at Anne Loftus Playground in Fort Tryon Park.
#
#
# Summary This project will reconstruct the staircase and perform site work at the Fort Tryon Park fieldhouse.
#
#
# Summary This project will reconstruct the playground, basketball court, drainage and water supply systems and surrounding landscape, and construct new adult fitness equipment at Jacob Javits Playground in Fort Tryon Park.
#
#
# Summary This project will reconstruct the ballfields in Fort Washington Park.
#
#
# Summary This project will reconstruct paths, pavements, and general site work in Riverside Park South, Riverside Park and Fort Washington Park in Manhattan, which were damaged by Hurricane Sandy.
#
#
# Summary This project will reconstruct portions of the greenways at Riverside Park and Fort Washington Park.
#
#
# Summary This project will reconstruct the plaza around the flagpole in Francis Lewis Park.
#
#
# Summary This project will reconstruct the natural turf field at Frank Golden Park.
#
#
# Summary This project will reconstruct Hurricane Sandy-damaged curbs, fences and safety surface at South Beach Playland Playground.
#
#
# Summary This project will reconstruct temporary berms installed after Hurricane Sandy at Freedom Circle in Staten Island.
#
#
# Summary This project will reconstruct Hurricane Sandy-damaged drain inlets, catch basins and lines, timber barrier rail fencing, vehicular barrier gates (and concrete island) and electrical utility boxes at Midland Beach.
#
#
# Summary This project will reconstruct the electrical and mechanical components of fountains damaged during Hurricane Sandy at Tappen Park and South Beach.
#
#
# Summary This project will reconstruct two natural turf ballfields and construct sports lighting and a score board in Franz Sigel Park.
#
#
# Summary This project will reconstruct the basketball courts at Frederick B. Judge Playground.
#
#
# Summary This project will reconstruct the playground at Frederick B. Judge Playground.
#
#
# Summary This project will reconstruct the tennis courts in Frederick Johnson Park.
#
#
# Summary This project will reconstruct Harlem Lane Playground, and it will demolish the existing comfort station and construct a new basketball court and synthetic turf field at Frederick Johnson Playground.
#
#
# Summary This project will reconstruct the play area at Frederick Johnson Playground.
#
#
# Summary This project will reconstruct the ballfields and add soil cover at Owl Hollow Fields.
#
#
# Summary This project will reconstruct the roof at Zink House in Freshkills Park.
#
#
# Summary This project will reconstruct portions of the existing playground at Friends Field, including the removal of the existing safety surface, and the expansion of the existing playground area.
#
#
# Summary This project will reconstruct Brook Park.
#
#
# Summary This project will reconstruct the comfort station at Fulton Park.
#
#
# Summary This project will reconstruct the seating area and playground at Garrison Playground.
#
#
# Summary This project will reconstruct the existing ballfields, basketball courts, and sports lighting, and improve the edges and entrances at MacArthur Park.
#
#
# Summary This project will reconstruct Hart Playground.
#
#
# Summary This project will reconstruct the playground and replace the basketball court with an adult fitness equipment area at Glen Oaks Oval.
#
#
# Summary This project will reconstruct Goble Playground, including the basketball courts, swings, and handball courts.
#
#
# Summary This project will reconstruct Gorman Playground.
#
#
# Summary This project will reconstruct the playground area in Grace Playground, including the play equipment, safety surfacing, spray shower, fencing, and utilities.
#
#
# Summary This project will reconstruct of the playground and basketball court at Grant Park.
#
#
# Summary This project will reconstruct the play equipment, swings, landscaping, and sitting areas in Grassmere Playground.
#
#
# Summary This project will reconstruct and maintain temporary berms installed after Hurricane Sandy at New Dorp Beach in Staten Island.
#
#
# Summary This project will reconstruct the first floor of the New Dorp Center in Staten Island due to damage from Hurricane Sandy.
#
#
# Summary This project will reconstruct the roads and paths at Cedar Grove Beach in Great Kills Park.
#
#
# Summary This project will reconstruct Hurricane Sandy-damaged site amenities, a spray shower and paths at New Dorp Beach in Great Kills Park.
#
#
# Summary This project will reconstruct the freshwater wetlands, plantings and site work at Cedar Grove Beach in Great Kills Park.
#
#
# Summary This project will reconstruct the heating system at the Greenbelt Native Plant Center.
#
#
# Summary This project will reconstruct the comfort station in Grove Hill Playground.
#
#
# Summary This project will reconstruct the synthetic turf fields at Grover Cleveland Playground and Pals Oval.
#
#
# Summary This project will reconstruct the handball courts at Hallets Cove Playground.
#
#
# Summary This project will reconstruct damaged portions of the seawall and railing at Hallets Cove.
#
#
# Summary This project will reconstruct Hallets Cove Playground.
#
#
# Summary This project will reconstruct the multi-purpose play area at Hallets Cove Playground.
#
#
# Summary This project will reconstruct the basketball courts and adult fitness equipment at Hamilton Fish Park.
#
#
# Summary This project will reconstruct Hamilton Fish Recreation Center.
#
#
# Summary This project will reconstruct the existing synthetic turf field at Hamilton-Metz Field.
#
#
# Summary This project will reconstruct the gymnasium floor and natatorium windows at the Hansborough Recreation Center.
#
#
# Summary This project will reconstruct the pool, entrance and interior spaces of the Hansborough Recreation Center.
#
#
# Summary This project will reconstruct Harmony Park.
#
#
# Summary This project will reconstruct Harold Schneiderman Playground.
#
#
# Summary This project will reconstruct the park's perimeter lawn area, construct four (4) sets of steel signage, and construct a storm sewer connection.
#
#
# Summary This project will reconstruct the multi-purpose ballfields at Hickman Playground and Harry Maze Playground.
#
#
# Summary This project will reconstruct the comfort station in Havemeyer Playground.
#
#
# Summary This project will reconstruct the outdoor gym at Wingate Park, the play area at Heckscher Playground, and the handball, basketball, sitting area and multi-purpose play area at Nautilus Playground.
#
#
# Summary This project will reconstruct play equipment, safety surfacing, pavements, fencing, tennis courts, handball courts and plantings at various parks in Queens.
#
#
# Summary This project will reconstruct the basketball and handball courts at Henry Hudson Park.
#
#
# Summary This project will reconstruct the basketball and handball courts, planting, fencing and asphalt and concrete pavement at Henry M. Jackson Playground.
#
#
# Summary This project will reconstruct the multipurpose room and fire alarm system at Von King Cultural Arts Center in Herbert Von King Park.
#
#
# Summary This project will reconstruct two park entrances at MacNeil Park.
#
#
# Summary This project will reconstruct the esplanade in MacNeil Park.
#
#
# Summary This project will reconstruct boilers and related plumbing and provide a new heating, ventilating, and air conditioning system for Highbridge Bathhouse.
#
#
# Summary This project will reconstruct Adventure Playground and Sunken Playground, install park pathway lighting to the historic High Bridge, and construct a new synthetic turf practice field at Highbridge Park.
#
#
# Summary This project will reconstruct the filter plant at Highbridge Pool.
#
#
# Summary This project will reconstruct the comfort station in Quisqueya Playground in Highbridge Park.
#
#
# Summary This project will reconstruct the water tower in Highbridge Park.
#
#
# Summary This project will reconstruct the staircase and pathways, including pavement, drainage, lighting and planting, in Highbridge Park.
#
#
# Summary This project will reconstruct the sidewalk and improve pedestrian access along a portion of Highland Boulevard.
#
#
# Summary This project will reconstruct the overlook area around the stone bridge with new pathways, reconstructing steps and stone walls in Highland Park.
#
#
# Summary This project will reconstruct the perimeter pathways, fencing, and security lighting around Ridgewood Reservoir in Highland Park
#
#
# Summary This project will reconstruct Gatehouse 27 next to Ridgewood Reservoir in Highland Park.
#
#
# Summary This project will reconstruct four basketball courts in Highland Park.
#
#
# Summary This project will reconstruct Lower Western Playground in Highland Park.
#
#
# Summary This project will reconstruct natural turf ballfields 1 and 2 in Highland Park.
#
#
# Summary This project will reconstruct the eastern half of the lower playground area, and performance area at Highland Park.
#
#
# Summary This project will reconstruct the comfort station at the lower east playground in Highland Park.
#
#
# Summary This project will reconstruct the northern and southern portions of Hinton Park.
#
#
# Summary This project will reconstruct the children's play area in Homecrest Playground, including the spray shower, play equipment, paving, site furniture, landscaping and utilities.
#
#
# Summary This project will reconstruct Honey Locust Park.
#
#
# Summary This project will reconstruct Hoover Playground, Borough of Queens.
#
#
# Summary This project will reconstruct the baseball field, outdoor gym, playground, sitting area and perimeter sidewalks at Hope Ballfield.
#
#
# Summary This project will reconstruct the asphalt ballfield and construct an adult fitness and skate area in Von Dohlen Playground.
#
#
# Summary This project will reconstruct Triborough Playground A; the sidewalks at Triborough Playgrounds A, B, C, and D; and the basketball courts and multipurpose play area at Hoyt Playground.
#
#
# Summary This project will reconstruct Virginia Park and Hugh Grant Circle, including general site work, pavements, fencing, curbs, lighting and landscaping.
#
#
# Summary This project will reconstruct the play equipment, safety surfacing, spray shower, fencing, benches and landscaping in Hunts Point Playground.
#
#
# Summary This project will reconstruct the dock in Hunts Point Riverside Park.
#
#
# Summary This project will reconstruct the soccer fields at Idlewild Park.
#
#
# Summary This project will reconstruct the fencing, sidewalks and parking lot at Idlewild Park.
#
#
# Summary This project will reconstruct ballfield #1 at Inwood Hill Park.
#
#
# Summary This project will reconstruct the Inwood Hill Nature Center at Inwood Hill Park due to damage caused by Hurricane Sandy.
#
#
# Summary This project will reconstruct the little league baseball field in Inwood Hill Park.
#
#
# Summary This project will reconstruct the water service to Isham Park.
#
#
# ...
#
#
# Summary This project will reconstruct the play units and water service at Seeley Park.
#
#
# Summary This project will reconstruct the sidewalk and fencing in Seton Falls Park.
#
#
# Summary This project will reconstruct the ballfields with synthetic turf at Seton Park.
#
#
# Summary This project will reconstruct the basketball courts in Seton Park.
#
#
# Summary This project will reconstruct the dog run, including fences, curbs, benches, stone screenings, plantings, sidewalks, and water service, in Seton Park.
#
#
# Summary This project will reconstruct the courtyard, gardens, paths, and fencing at Seward Park.
#
#
# Summary This project will reconstruct the electrical and structural components at Sheepshead Bay Piers.
#
#
# Summary This project will reconstruct the comfort station in Sheltering Arms Playground.
#
#
# Summary This project will reconstruct Vinland Playground at Shore Road Park.
#
#
# Summary This project will reconstruct the field house at Shore Road Park.
#
#
# Summary This project will reconstruct steel fencing, clear vegetation, and control erosion at Shore Road Park.
#
#
# Summary This project will reconstruct the paths at Silver Lake Park.
#
#
# Summary This project will reconstruct paths and pavement in the southern half of Silver Lake Park.
#
#
# Summary This project will reconstruct the sitting area, lawns and sidewalks at Sixteen Oaks Grove.
#
#
# Summary This project will reconstruct the tennis courts at Skyline Playground.
#
#
# Summary This project will reconstruct Sohncke Square.
#
#
# Summary This project will reconstruct the entire playground including play equipment, spray shower, basketball court, multi-purpose play area, benches, fences, drainage, water supply, security lighting, sports lighting and landscaping.
#
#
# Summary This project will reconstruct portions of Sorrentino Recreation Center.
#
#
# Summary This project will reconstruct boilers and provide a new heating, ventilation, and air conditioning system for the gymnasium at Sorrentino Recreation Center.
#
#
# Summary This project will reconstruct the playground, spray shower, lawn, and basketball and handball courts at Soundview Park with new play equipment, planting, and lighting.
#
#
# Summary This project will reconstruct the running track and athletic field in Soundview Park.
#
#
# Summary This project will reconstruct the basketball and handball courts at Sperandeo Playground.
#
#
# Summary This project will reconstruct Spring Street Park (Soho Square).
#
#
# Summary This project will reconstruct the basketball courts, and install new picnic tables, grills, charcoal bins, trees, and an accessible path to the BBQ area in Springfield Park.
#
#
# Summary This project will reconstruct the spray shower at Spuyten Duyvil Playground.
#
#
# Summary This project will reconstruct St. Gregory's Playground.
#
#
# Summary This project will reconstruct St. James Recreation Center.
#
#
# Summary This project will reconstruct the boiler, heating and air conditioning systems at St. James Recreation Center.
#
#
# Summary This project will reconstruct the boilers and HVAC systems at St. John's Recreation Center.
#
#
# Summary This project will reconstruct the outdoor sitting area adjacent to the recreation center in St. John’s Park, including new benches, fencing, picnic tables, game tables and chairs, a drinking fountain, flowering trees and ornamental plantings.
#
#
# Summary This project will reconstruct the existing multipurpose play area at St. Mary's Playground to include a skate park, basketball courts, multi-use synthetic turf field, adult fitness equipment and color seal coat walking track.
#
#
# Summary This project will reconstruct the comfort station at St. Mary's Park Playground West.
#
#
# Summary This project will reconstruct the amphitheater, plaza, pathways and lighting at St. Mary's Park.
#
#
# Summary This project will reconstruct St. Mary's Park Recreation Center.
#
#
# Summary This project will reconstruct the basketball and tennis courts, and install play equipment, seating areas, planting beds and trees at St. Mary's Park Playground West.
#
#
# Summary This project will reconstruct the ballfields and dog run, including natural turf, irrigation, sports lighting, fencing and landscaping at St. Mary's Park.
#
#
# Summary This project will reconstruct the synthetic turf field at St. Michael's Playground.
#
#
# Summary This project will reconstruct the comfort station at St. Nicholas Playground North.
#
#
# Summary This project will reconstruct the playground, multi-use fields, basketball and handball courts, and water features at Stapleton Playground.
#
#
# Summary This project will reconstruct the multi-purpose play area and handball courts in Starr Playground.
#
#
# Summary This project will reconstruct the playground and spray shower at Starr Playground.
#
#
# Summary This project will reconstruct the electrical systems at comfort stations in various parks citywide.
#
#
# Summary This project will reconstruct the synthetic turf field and construct new sports lighting at the basketball courts at Sternberg Park.
#
#
# Summary This project will reconstruct Stockton Playground with new play equipment, a spray shower, a synthetic turf field and painted track, lighting, fencing, pavement, plantings, and site furnishings.
#
#
# Summary This project will reconstruct Stroud Playground, including the multi-use area, landscaping, play equipment, safety surface, spray shower, seating areas, basketball court and handball court.
#
#
# Summary This project will reconstruct the fence and sidewalks in the eastern half of Stuyvesant Square.
#
#
# Summary This project will reconstruct the comfort station in Sumner Playground.
#
#
# Summary This project will reconstruct Sumner Playground.
#
#
# Summary This project will reconstruct Sunners Playground.
#
#
# Summary This project will reconstruct the subterranean controller vaults for the spray shower at Sunset Park.
#
#
# Summary This project will reconstruct the handball court in Sunset Park.
#
#
# Summary This project will reconstruct paths, benches and fencing at Sunset Park.
#
#
# Summary This project will reconstruct the playground in Sunset Park.
#
#
# Summary This project will reconstruct part of the Sunset Park Recreation Center.
#
#
# Summary This project will reconstruct stairs, handrails and landings in Sunset Park.
#
#
# Summary This project will reconstruct the asphalt multi-purpose play area and sport courts at Surf Playground with new basketball courts, seating area, synthetic turf and plantings.
#
#
# Summary This project will reconstruct a portion of Sutton Place Park.
#
#
# Summary This project will reconstruct the roof at the Village Hall located in Tappen Park.
#
#
# Summary This project will reconstruct Ten Eyck Playground with new play equipment, a spray shower, a synthetic turf field and painted track, a basketball court, lighting, fencing, pavement, plantings, and site furnishings.
#
#
# Summary This project will reconstruct the plaza area at Ten Eyck Plaza.
#
#
# Summary This project will reconstruct the comfort station near the playground in the Battery.
#
#
# Summary This project will reconstruct the comfort station in Battery Park.
#
#
# Summary This project will reconstruct and expand the playground at The Battery.
#
#
# Summary This project will reconstruct the playground, courts, and multi-use fields in Grandview Playground.
#
#
# Summary This project will reconstruct Bull Moose Dog Run in Theodore Roosevelt Park.
#
#
# Summary This project will reconstruct the play areas, adult fitness equipment, seating area, basketball courts, and baseball field at Thomas Boyland Park.
#
#
# Summary This project will reconstruct the concrete pool deck at Thomas Greene Playground.
#
#
# Summary This project will reconstruct Thomas Jefferson Playground.
#
#
# Summary This project will reconstruct the fishing pier that was damaged by Hurricane Sandy.
#
#
# Summary This project will reconstruct two playgrounds in Tompkins Square Park with new play equipment, safety surfacing, spray showers, seating, and fencing.
#
#
# Summary This project will reconstruct pavements at Tompkins Square Park, including paths and the multipurpose play area.
#
#
# Summary This project will reconstruct the field house in Tompkins Square Park.
#
#
# Summary This project will reconstruct Tony Dapolito Recreation Center.
#
#
# Summary This project will reconstruct Tribute Park due to damage from Hurricane Sandy.
#
#
# Summary This project will reconstruct the sitting area at Trygve Lie Plaza.
#
#
# Summary This project will reconstruct the comfort station at Twenty-Four Sycamores Park.
#
#
# Summary This project will reconstruct Umma Park.
#
#
# Summary This project will reconstruct stairways and landings in University Park.
#
#
# Summary This project will reconstruct Van Alst Playground.
#
#
# Summary This project will reconstruct the greenhouse and head house at the Van Cortlandt Park Nursery.
#
#
# Summary This project will reconstruct the entrance to Van Cortlandt Park at Broadway and West 242nd Street.
#
#
# Summary This project will reconstruct the existing natural grass ballfields (Indian Fields) in Van Cortlandt Park.
#
#
# Summary This project will reconstruct the birding bridge over Tibbetts Brook on the John Kieran Nature Trail in Van Cortlandt Park.
#
#
# Summary This project will reconstruct the spray shower at Woodlawn Playground in Van Cortlandt Park.
#
#
# Summary This project will reconstruct the comfort station in Woodlawn Playground in Van Cortlandt Park.
#
#
# Summary This project will reconstruct the playground, including new steel play equipment, swings, safety surfacing, fencing, landscaping, benches, and park security lighting, at Woodlawn Playground in Van Cortlandt Park
#
#
# Summary This project will reconstruct the playground at Van Nest Park, including new play equipment, a spray shower, sitting area and planting borders.
#
#
# Summary This project will reconstruct Veterans Grove.
#
#
# Summary This project will reconstruct lighting and electrical components damaged by Hurricane Sandy at Vietnam Veterans Plaza.
#
#
# Summary This project will reconstruct the play equipment, safety surfacing, handball courts, and asphalt multi-purpose play area and construct a new spray shower at Albano Playground.
#
#
# Summary This project will reconstruct the combination soccer and baseball synthetic turf field and adjacent fencing, drinking fountains, and seating areas at Wagner Playground.
#
#
# Summary This project will reconstruct Wakefield Playground.
#
#
# Summary This project will reconstruct the playground at Walton Park.
#
#
# Summary This project will reconstruct the basketball courts at Washington Hall Playground.
#
#
# Summary This project will reconstruct the dog run in Washington Park.
#
#
# Summary This project will reconstruct the perimeter sidewalks at Washington Square Park.
#
#
# Summary This project will reconstruct Strong Street Playground in Washington's Walk.
#
#
# Summary This project will reconstruct Weeksville Playground with new play equipment, seating and planting beds.
#
#
# Summary This project will reconstruct West 186th Street Basketball Court.
#
#
# Summary This project will reconstruct the air conditioning system for the gymnasium at West Bronx Recreation Center.
#
#
# Summary This project will reconstruct Whalen Park in the Bronx.
#
#
# Summary This project will reconstruct the playground in White Park.
#
#
# Summary This project will reconstruct White Playground.
#
#
# Summary This project will reconstruct the waterfront Parks infrastructure at Whitey Ford Field.
#
#
# Summary This project will reconstruct the natural turf field at Whitey Ford Field
#
#
# Summary This project will reconstruct the sitting area in William F. Moore Park.
#
#
# Summary This project will reconstruct pavements at William F. Passannante Ballfield.
#
#
# Summary This project will reconstruct William Sheridan Playground.
#
#
# Summary This project will reconstruct the HVAC systems for recreation centers and nature centers at parks locations in the Bronx and Manhattan.
#
#
# Summary This project will reconstruct the recreation building at Williamsbridge Oval Park.
#
#
# Summary This project will reconstruct the roof at the comfort station in Willis Playground.
#
#
# Summary This project will reconstruct the play area at Willis Playground.
#
#
# Summary This project will reconstruct the basketball courts at Wingate Park.
#
#
# Summary This project will reconstruct the shoreline at Transmitter Park.
#
#
# Summary This project will reconstruct the Sandy-damaged playground and adjacent pathways at Wolfe's Pond Park, including new asphalt pavement, safety surfacing, fencing, benches, and curbs.
#
#
# Summary This project will reconstruct the berm and restore the landscape in Wolfe's Pond Park.
#
#
# Summary This project will reconstruct the fencing on the 68th Avenue side of Yellowstone Park.
#
#
# Summary This project will reconstruct the fencing on the 68th Road side of Yellowstone Park.
#
#
# Summary This project will reconstruct the roof at the comfort station in Zimmerman Playground.
#
#
# Summary This project will reconstruct the handball courts, play equipment, swing set, and seating area at the southern portion of Zimmerman Playground.
#
#
# Summary This project will reconstruct Belden Point on City Island Avenue.
#
#
# Summary This project will reconstruct Frederick Douglass Boulevard Community Garden with new pavements and plantings.
#
#
# Summary This project will reconstruct the hazardous and deteriorated section of the existing asphalt bicycle path between (approximately) Bay 8th and Bay 14th Street.
#
#
# Summary This project will reconstruct the playground at PS 38 in Queens.
#
#
# Summary This project will reconstruct the playground at P.S. 321.
#
#
# Summary This project will reconstruct the multi-purpose play and passive recreation areas in Success Garden.
#
#
# Summary This project will reconstruct the perimeter concrete retaining walls, steel fencing and gate, and install a new water supply system at CS 134 Community Garden.
#
#
# Summary This project will reconstruct Amendola Plaza.
#
#
# Summary This project will reconstruct the 44th Drive Pier and DEP sewer outfall.
#
#
# Summary This project will reconstruct the perimeter fence at LaGuardia Corner Garden.
#
#
# Summary This project will reconstruct the sidewalks at Bedford Green.
#
#
# Summary This project will reconstruct the electrical systems at various recreation centers and nature centers citywide.
#
#
# Summary This project will reconstruct the mechanical systems at various Olympic pools citywide.
#
#
# Summary This project will reconstruct sidewalks damaged by adjacent city-owned trees in Brooklyn Community Boards 1-6, 8, 9, 14, 16, and 17.
#
#
# Summary This project will reconstruct recreation centers in Brooklyn and Staten Island to provide new emergency exits and other life safety features.
#
#
# Summary This project will reconstruct recreation centers in Manhattan to provide new emergency exits and other life safety features.
#
#
# Summary This project will reconstruct sidewalks damaged by adjacent city-owned trees in Queens Community Boards 1-7, 9, and 10.
#
#
# Summary This project will reconstruct sidewalks damaged by adjacent city-owned trees in Queens Community Boards 8 and 11-14.
#
#
# Summary This project will reconstruct sidewalks damaged by adjacent city-owned trees in Staten Island.
#
#
# Summary This project will reconstruct little league fields at various parks in the Bronx.
#
#
# Summary This project will reconstruct sidewalks damaged by adjacent city-owned trees in the Bronx and Manhattan.
#
#
# Summary This project will reconstruct recreation centers in the Bronx and Queens to provide new emergency exits and other life safety features.
#
#
# Summary This project will reconstruct park trails, install trail features, remove invasive species, plant new and replacement trees in the Bronx, Queens and Staten Island.
#
#
# Summary This project will reconstruct damaged sidewalks in Brooklyn and Staten Island.
#
#
# Summary This project will reconstruct sidewalks damaged by adjacent city-owned trees in Brooklyn Community Boards 7, 10-13, 15, and 18.
#
#
# Summary This project will reconstruct Harriet Tubman Memorial Square.
#
#
# Summary This project will reconstruct the garden at the step street at West 181st Street and Pinehurst Avenue.

# %%
grep('^Summary This project will construct', './ParkProjects.txt')
# Out:
# Summary This project will construct a mezzanine floor at the Citywide Services Shops Facility (Aramark Building).
#
#
# Summary This project will construct a park at Melrose Commons Site 62.
#
#
# Summary This project will construct new fitness equipment at Alley Pond Park and Alley Athletic Playground, reconstruct the seating area at One Room Schoolhouse Park, and construct a new meditation garden at Kissena Corridor Park.
#
#
# Summary This project will construct a new environmental center in Alley Pond Park.
#
#
# Summary This project will construct a living shoreline with oyster habitats along the western shore of Alley Creek at Alley Pond Park.
#
#
# Summary This project will construct a rooftop sitting area and searail in East River Esplanade.
#
#
# Summary This project will construct signage at several locations along the Old Croton Aqueduct.
#
#
# Summary This project will construct a comfort station in Aqueduct Walk.
#
#
# Summary This project will construct an off-street parking lot and trail head and improve trails in Arden Heights Woods.
#
#
# Summary This project will construct adult fitness equipment in Asser Levy Park.
#
#
# Summary This project will construct a new flagpole and install a bluestone path in Asser Levy Park.
#
#
# Summary This project will construct portions of the Queens East River and North Shore Greenway in Queensbridge Park, Rainey Park, Hallets Cove Playground, Astoria Park and Ralph Demarco Park.
#
#
# Summary This project will construct a picnic grove in O'Donohue Park.
#
#
# Summary This project will construct greenstreets and green infrastructure elements at citywide locations.
#
#
# Summary This project will construct a reading garden at Bellerose Playground.
#
#
# Summary This project will construct an ADA-accessible dog run and reconstruct the basketball court, playground, and sitting areas at Bellevue South Park.
#
#
# Summary This project will construct emergency public safely measures, including but limited to, fencing, paving, walls, demolitions, structural supports and site access.
#
#
# Summary This project will construct a synthetic turf field in Bennett Park.
#
#
# Summary This project will construct a playground and comfort station at Gateway Estates.
#
#
# Summary This project will construct electrical service to a playground and comfort station at Gateway Estates.
#
#
# Summary This project will construct the HVAC systems at the comfort station at Gateway Estates.
#
#
# Summary This project will construct plumbing systems for a playground and comfort station at Gateway Estates.
#
#
# Summary This project will construct a new skate park, basketball courts, fitness area and multi-purpose space in the northern parcel of Betsy Head Park.
#
#
# Summary This project will construct a comfort station at Imagination Playground in Betsy Head Park.
#
#
# Summary This project will construct a synthetic turf field, rubberized track, sport courts and adult fitness equipment area at Betsy Head Park.
#
#
# Summary This project will construct a new synthetic turf field and reconstruct the basketball courts at Bildersee Playground.
#
#
# Summary This project will construct a new play area, basketball courts and seating areas at Bildersee Playground.
#
#
# Summary This project will construct sports lighting and a scoreboard at softball field 3 in Bill Rainey Park.
#
#
# Summary This project will construct a new synthetic turf multi-use field and reconstruct the existing synthetic turf soccer field at Bloomingdale Park.
#
#
# Summary This project will construct adult fitness equipment and reconstruct the basketball court and handball court wall at Booker T. Washington Playground, reconstruct the playground at Chelsea Park, and construct adult fitness equipment and reconstruct the basketball half-court at Columbus Park.
#
#
# Summary This project will construct a bocce court in Bowne Park.
#
#
# Summary This project will construct a multi-modal pathway with lighting, a passive recreation area, green infrastructure, and shoreline restoration at Bridge Park.
#
#
# Summary This project will construct a dog run in Bronx Park, west of the intersection of Bronx Park East and Boston Road.
#
#
# Summary This project will construct an adult fitness area in Bronx Park.
#
#
# Summary This project will construct adult fitness equipment and miscellaneous site work and convert a tennis court to a basketball court in Bronx Park.
#
#
# Summary This project will construct a fish passage over the Twin Dams at the Bronx Zoo.
#
#
# Summary This project will construct drinking fountains in Bronx Park.
#
#
# Summary This project will construct green infrastructure to capture storm water and stabilize hillsides and slopes at Shoelace Park.
#
#
# Summary This project will construct new skate park elements in Brower Park.
#
#
# Summary This project will construct a portion of Bushwick Inlet Park at 50 Kent Avenue.
#
#
# Summary This project will construct two soccer fields in Calvert Vaux Park.
#
#
# Summary This project will construct a comfort station and maintenance facility in Calvert Vaux Park.
#
#
# Summary This project will construct a 3.5-acre natural habitat for waterfowl by excavating existing fill material, re-grading steep slopes and creating inter-tidal zones. It will also include a new boat launch ramp, fencing, and plantings.
#
#
# Summary This project will construct a multi-use greenway path connecting the on-street path along Paerdegat Avenue North to the Shore Parkway Greenway along the southwestern edge of Canarsie Park.
#
#
# Summary This project will construct a playground in Canarsie Park.
#
#
# Summary This project will construct a comfort station in Canarsie Park.
#
#
# Summary This project will construct a commemorative site of Mother Language Day at Captain Tilly Park.
#
#
# Summary This project will construct security measures at entrances to Carl Schurz Park.
#
#
# Summary This project will construct energy efficient ballfield lighting retrofits.
#
#
# Summary This project will construct paths and landscaping in Castle Hill Park.
#
#
# Summary This project will construct a new park, including play equipment, seating, lighting, plantings, and other site furnishings at Chelsea Green.
#
#
# Summary This project will construct green infrastructure to capture storm water at Classon Playground, Colonel David Marcus Playground, Oracle Playground, and Willoughby Playground.
#
#
# Summary This project will construct a 5K running trail, including re-grading of an existing trail, new edging, new surfacing and associated landscape improvements in Clove Lakes Park.
#
#
# Summary This project will construct a comfort station at Co-op City Waterfront Park.
#
#
# Summary This project will construct sports and security lighting at College Point Fields.
#
#
# Summary This project will construct a football field at College Point Fields.
#
#
# Summary This project will construct new fencing, gates, planting beds, benches and pavements, and a water supply system in Colucci Park.
#
#
# Summary This project will construct an adult fitness area in Colucci Playground.
#
#
# Summary This project will construct security measures at entrances to Coney Island Boardwalk.
#
#
# Summary This project will construct emergency protective measures at Conference House and Crescent Park beaches.
#
#
# Summary This project will construct shoreline protection measures in Conference House Park.
#
#
# Summary This project will construct a 20' field perimeter fence and reconstruct pavements, electrical service, bleachers, and other fences at Cooney Grauer Field.
#
#
# Summary This project will construct Corporal Irwin Fischer Park.
#
#
# Summary This project will construct new paths, seating and a tot lot and reconstruct the landscape at Crescent Beach Park.
#
#
# Summary This project will construct a living shoreline along the western shore of Alley Creek at Alley Pond Park.
#
#
# Summary This project will construct sports lighting at ballfield 1 in Crotona Park.
#
#
# Summary This project will construct green infrastructure to capture stormwater at Crotona Parkway Malls, Whalen Grove, Parkside Playground, Loreto Playground, and Haviland Playground.
#
#
# Summary This project will construct a new synthetic turf multi-purpose athletic field to replace an existing natural turf field at Cypress Hills Playground. The work will include a new perimeter recreation path, reconstructed dugouts, drinking fountains and misting stations.
#
#
# Summary This project will construct a dog run at Devoe Park.
#
#
# Summary This project will construct separate dog runs for both small and large dogs in DiMattina Park, Dyker Beach Park and Owl's Head Park with new drainage, lighting, plantings, benches, paving, fencing, drinking fountains, and improved odor and dust control.
#
#
# Summary This project will construct new park security lighting in Drew Playground.
#
#
# Summary This project will construct green infrastructure to capture storm water at East Elmhurst Playground, Electric Playground, Horace Harding Playground, London Planetree Playground, and Joseph P. Addabbo Memorial Park.
#
#
# Summary This project will construct a masonry ramp to provide ADA access to John Finley Walk at East 82nd Street.
#
#
# Summary This project will construct a memorial to Vietnam War veterans from Queens in Elmhurst Park.
#
#
# Summary This project will construct additional fencing, paths, seating and miscellaneous site amenities at Rocks & Roots Park (Estella Diggs).
#
#
# Summary This project will construct an adult fitness area in Ewen Park.
#
#
# Summary This project will construct new active recreation areas, paths, seating, lighting and an expanded public gathering area at Faber Park.
#
#
# Summary This project will construct a plaza-type skate park at Faber Park, including new drainage structures and trees.
#
#
# Summary This project will construct a multi-purpose field, baseball field, tennis courts, pickleball courts, adult fitness equipment, picnic area, parking area, bio-retention areas, paths, and landscape elements at Fairview Park.
#
#
# Summary This project will construct a new comfort station at Fairview Park.
#
#
# Summary This project will construct a comfort station in the eastern section of Ferry Point Park.
#
#
# Summary This project will construct adult fitness equipment in Ferry Point Park.
#
#
# Summary This project will construct a golf course at Ferry Point Park.
#
#
# Summary This project will construct the HVAC system in connection with the construction of a comfort station in the western section of Ferry Point Park.
#
#
# Summary This project will construct the electrical system in connection with the construction of a comfort station in the western section of Ferry Point Park.
#
#
# Summary This project will construct the plumbing system in connection with the construction of a comfort station in the western section of Ferry Point Park.
#
#
# Summary This project will construct a comfort station in the western section of Ferry Point Park.
#
#
# Summary This project will construct a waterfront path and salt water marsh in Ferry Point Park.
#
#
# Summary This project will construct a visitor center in Wyckoff House Park.
#
#
# Summary This project will construct an outdoor classroom and boardwalk at Willow Lake.
#
#
# Summary This project will construct a new multi-use bicycle and pedestrian pathway into Forest Park from Myrtle Avenue, including streetscape and park pathway improvements.
#
#
# Summary This project will construct an elevator at the Center for the Women of New York at Fort Totten Park.
#
#
# Summary This project will construct a new waterfront mixed-use path in Fort Washington Park.
#
#
# Summary This project will construct a new playground between West 162nd & 164th Streets and reconstruct the fields, courts, and greenway between West 155th & West 168th Streets.
#
#
# Summary This project will construct an accessible ramp from the Hudson River Greenway to Dyckman Street in Fort Washington Park. It will also reconstruct the entrance to Inwood Hill Park at Dyckman Street near the Hudson River and create a multi-use path between that entrance and the pedestrian bridge over the Amtrak rail line.
#
#
# Summary This project will construct a comfort station in Fox Playground.
#
#
# Summary This project will construct a synthetic turf soccer field and reconstruct two ballfields with synthetic turf in Frank Principe Park.
#
#
# Summary This project will construct a temporary emergency protective berm at Midland Beach from New Dorp Lane to Ocean Breeze Park.
#
#
# Summary This project will construct a recreation building at Midland Beach.
#
#
# Summary This project will construct landscaping and planting at the Ocean Breeze Athletic Complex parking lot at Franklin D. Roosevelt Boardwalk and Beach.
#
#
# Summary This project will construct emergency protective measures at FDR Beach and Boardwalk.
#
#
# Summary This project will construct a new comfort station at Frederick Johnson Playground.
#
#
# Summary This project will construct synthetic turf athletic fields, roadways, a parking lot with associated landscaping and stormwater management, multi-use and pedestrian paths, benches, signage, fencing, and lighting, and restore woodlands and wetlands at Freshkills South Park.
#
#
# Summary This project will construct a comfort station at Freshkills South Park.
#
#
# Summary This project will construct four soccer fields and a parking lot at Owl Hollow Fields.
#
#
# Summary This project will construct a field house at Owl Hollow Fields in Freshkills Park.
#
#
# Summary This project will construct a new multi-use pathway, overlook structures, and comfort station with composting toilets in the northern section of Freshkills Park.
#
#
# Summary This project will construct a 3.2 mile multi-use path running along the edges of Freshkills Park, William T. Davis Wildlife Refuge and La Tourette Park.
#
#
# Summary This project will construct a multi-use synthetic turf field, adult fitness area, and sitting area, and reconstruct the handball courts and basketball courts at Glenwood Playground.
#
#
# Summary This project will construct Grand Playground, including a new play area, sitting area, spray shower, and basketball court.
#
#
# Summary This project will construct Grant Park, including converting the roadbed to recreational space.
#
#
# Summary This project will construct a new comfort station at Gravesend Park.
#
#
# Summary This project will construct a new comfort station and an accessible ramp in Green Central Knoll.
#
#
# Summary This project will construct green infrastructure to capture storm water at Greenwood Playground.
#
#
# Summary This project will construct adult fitness equipment and reconstruct the playground at Haffen Park.
#
#
# Summary This project will construct a comfort station in Harlem River Park.
#
#
# Summary This project will construct a BMX bike, skate park and multipurpose play area at Harold Ickes Playground.
#
#
# Summary This project will construct a new synthetic turf field, a walking track, basketball courts, handball courts, spectator bleachers, benches, landscaping, and lighting at Heckscher Playground.
#
#
# Summary This project will construct a vegetable garden, orchard, hedgerow, windbreak, ornamental plantings, a portion of the farm drive, custom seating, a drinking fountain, an outhouse and a wellhouse at the Lott House.
#
#
# Summary This project will construct the steps along the waterfront at MacNeil Park.
#
#
# Summary This project will construct a comfort station in Highbridge Park.
#
#
# Summary This project will construct new play equipment, a spray shower, a synthetic turf field, a painted track, adult fitness equipment, basketball court, lighting, fencing, pavement, planting and site furnishings at Hilltop Playground.
#
#
# Summary This project will construct a portion of the Hutchinson River Greenway from Pelham Parkway to Shore Road.
#
#
# Summary This project will construct pathway lighting at Kissena Corridor Park between 56th Avenue and Colden Street and at Hutchinson River Parkway along Bartow Avenue.
#
#
# Summary This project will construct a nature center in Idlewild Park.
#
#
# Summary This project will construct adult fitness equipment in Inwood Hill Park.
#
#
# Summary This project will construct adult fitness equipment at J. Hood Wright Park.
#
#
# Summary This project will construct a synthetic turf lawn panel within the J.J. Byrne Playground in Washington Park.
#
#
# Summary This project will construct a new fence at Jane Street Garden and reconstruct Jackson Square Park.
#
#
# Summary This project will construct a 5-foot wide jogging trail around the perimeter of the Jerome Park Reservoir, with new seating, plantings and adult fitness equipment. The project will also reconstruct the jogging trail, dog run, and basketball courts at Fort Independence Park, and construct new adult fitness equipment.
#
#
# Summary This project will construct a steel perimeter fence in Joyce Kilmer Park.
#
#
# Summary This project will construct sports lighting and a scoreboard at Julio Carballo Fields.
#
#
# Summary This project will construct a new asphalt path, reconstruct a lawn and remove a chain link fence in Kissena Corridor Park.
#
#
# Summary This project will construct green infrastructure to capture storm water at Kissena Park and Kissena Corridor Park.
#
#
# Summary This project will construct a comfort station in Leif Ericson Park.
#
#
# Summary This project will construct and adult fitness area and install fitness equipment at Linden Park.
#
#
# Summary This project will construct a comfort station and reconstruct the parking lot at Little Bay Park.
#
#
# Summary This project will construct a synthetic turf field at Little Flower Playground.
#
#
# Summary This project will construct a modular comfort station at Lopez Playground.
#
#
# Summary This project will construct an expanded asphalt multi-purpose play area in Loreto Playground.
#
#
# Summary This project will construct new play equipment for 2-5 years old, benches, fencing, drainage and water supply systems and plantings in Lt. Federico Narvaez Tot Lot.
#
#
# Summary This project will construct comfort stations at various locations in Brooklyn, the Bronx, and Manhattan.
#
#
# Summary This project will construct green infrastructure to capture storm water at Magenta Playground, Watson Gleason Playground, and Space Time Playground.
#
#
# Summary This project will construct a new comfort station and Little League building in Marcus Garvey Park.
#
#
# Summary This project will construct a new synthetic turf field and adult fitness at Maria Hernandez Park.
#
#
# Summary This project will construct new asphalt paths along Gerritsen Avenue and provide improved accessibility to the existing baseball fields in Marine Park.
#
#
# Summary This project will construct a new asphalt path, benches and accessible entrances adjacent to the Gerritsen Avenue ballfields in Marine Park.
#
#
# Summary This project will construct a new playground to include play equipment, swings, spray shower area, hillside slide and a picnic area near Brigham Street in Marine Park.
#
#
# Summary This project will construct a comfort station in Monsignor Kett Playground.
#
#
# Summary This project will construct a lighting system for Mosholu Parkway WWI Monument.
#
#
# Summary This project will construct screen fencing around the garbage management system at Ocean Breeze Park to reduce the visual impact to the public.
#
#
# Summary This project will construct a new synthetic turf field at Osborn Playground.
#
#
# Summary This project will construct a dog run in Pelham Bay Park, West end of the City Island Bridge.
#
#
# Summary This project will construct a barrier-free participatory garden that engages all the senses in enjoying the outdoors in Pelham Bay Park.
#
#
# Summary This project will construct an adult fitness area and nature walk in Pelham Bay Park.
#
#
# Summary This project will construct a skate park and reconstruct the amphitheater and basketball courts in Kelly Playground (PS 52).
#
#
# Summary This project will construct a synthetic turf field at Playground 125.
#
#
# Summary This project will construct an accessible entrance to Poe Cottage and reconstruct surrounding landscape including planting, pavements and fencing.
#
#
# Summary This project will construct a comfort station in Police Officer Edward Byrne Park.
#
#
# Summary This project will construct a basketball court in Pugsley Creek Park.
#
#
# Summary This project will construct a synthetic turf soccer field and sitting area at Quarry Ballfields.
#
#
# Summary This project will construct a field house in Queensbridge Park.
#
#
# Summary This project will construct a seating area, overlook, paths, barrier rail, lighting and landscaping at the Richmond Terrace Wetlands.
#
#
# Summary This project will construct a portion of Riverside Park South between West 65th Street and West 68th Street, including new plazas, play areas, lawns, volleyball courts, and a dog run, and it will reconstruct the bikeway between West 62nd Street and West 70th Street.
#
#
# Summary This project will construct immediate public safety measures, including but not limited to fencing, walls, demolition/structural supports and site access, at Rockaway Beach.
#
#
# Summary This project will construct a ramp to the Rockaway Beach Boardwalk at Beach 24th-25th Streets.
#
#
# Summary This project will construct a labyrinth at Shore Front Parkway.
#
#
# Summary This project will construct a dog run along Shore Front Parkway.
#
#
# Summary This project will construct a gateway structure at Shore Front Parkway.
#
#
# Summary This project will construct an adventure course at Shore Front Parkway.
#
#
# Summary This project will construct park amenities, including sidewalks, seating, bike racks, fencing, game tables, drinking fountains, and landscaping along Shore Front Parkway.
#
#
# Summary This project will construct a multi-purpose sports field at Shore Front Parkway.
#
#
# Summary This project will construct a playground at Shore Front Parkway.
#
#
# Summary This project will construct an irrigation system at Ruppert Park.
#
#
# Summary This project will construct a new comfort station in Scarangella Park.
#
#
# Summary This project will construct a new basketball half-court, fencing, and lighting at Seabury Playground.
#
#
# Summary This project will construct a comfort station in Seaside Wildlife Nature Park
#
#
# Summary This project will construct an entrance, path and fencing at Sherman Creek.
#
#
# Summary This project will construct a new path along the western edge of Shore Road Park.
#
#
# Summary This project will construct a dog run in Shore Road Park.
#
#
# Summary This project will construct new pavements, drainage, benches, game tables, fencing, fitness equipment and planting at Louis Simeone Park.
#
#
# Summary This project will construct a portion of the Bronx River Greenway between Soundview Park at Lafayette Ave & Bruckner Blvd.
#
#
# Summary This project will construct a dog run in Soundview Park in the Bronx.
#
#
# Summary This project will construct a comfort station at Soundview Park.
#
#
# Summary This project will construct a new entrance at Rosedale Avenue and a new open lawn area, asphalt paths, benches, park security lighting, and planting in Soundview Park.
#
#
# Summary This project will construct green infrastructure to capture storm water at Greenstreets near Spring Creek in Queens.
#
#
# Summary This project will construct a dog run in St. James Park.
#
#
# Summary This project will construct an outdoor adult fitness area at St. John's Recreation Center.
#
#
# Summary This project will construct a comfort station adjacent to the St. John's Recreation Center.
#
#
# Summary This project will construct new play equipment, benches, and pavements at St. Mary's Playground.
#
#
# Summary This project will construct rain gardens and other green infrastructure to capture storm water at St. Mary's Park in the Bronx.
#
#
# Summary This project will construct a wooden boardwalk, outdoor classroom, and pathways in Sunset Cove Park.
#
#
# Summary This project will construct a salt marsh and upland coastal forest area in Sunset Cove Park.
#
#
# Summary This project will construct a stage at Sunset Park.
#
#
# Summary This project will construct an adult fitness area in Sunset Park.
#
#
# Summary This project will construct lawns and bikeway at the Battery.
#
#
# Summary This project will construct a monument at Olde Towne of Flushing Burial Ground.
#
#
# Summary This project will construct a skate park in the northeast corner of the existing playground in Thomas Jefferson Park.
#
#
# Summary This project will construct a new community center in Tilden Playground.
#
#
# Summary This project will construct a dog run and reconstruct a basketball court at Triborough Bridge Playground C.
#
#
# Summary This project will construct a playground in Van Cortlandt Park.
#
#
# Summary This project will construct a skate park in Van Cortlandt Park.
#
#
# Summary This project will construct a portion of the Putnam Greenway in Van Cortlandt Park.
#
#
# Summary This project will construct a dog run in Van Cortlandt Park.
#
#
# Summary This project will construct a flagpole and reconstruct a portion of the plaza in Van Nest Park.
#
#
# Summary This project will construct the Hell Gate pathway.
#
#
# Summary This project will construct a multi use pedestrian pathway under the Amtrak Viaduct at Wards Island Park.
#
#
# Summary This project will construct a comfort station in Fort Four Playground at Washington's Walk.
#
#
# Summary This project will construct West Farms Park.
#
#
# Summary This project will construct a comfort station in West Playground.
#
#
# Summary This project will construct a rain garden and erosion control in Westerleigh Park.
#
#
# Summary This project will construct a new skate park at Williamsbridge Oval.
#
#
# Summary This project will construct Yolanda Garcia Park.
#
#
# Summary This project will construct a playground at Sunnyside Gardens Park.
#
#
# Summary This project will construct new steel fencing and gates and reconstruct the curbs at La Plaza Cultural Community Garden.
#
#
# Summary This project will construct new steel fences with concrete curbs and install water service at Hooper Grove Community Garden.
#
#
# Summary This project will construct Davidson Park.
#
#
# Summary This project will construct a new playground at Brooklyn PS 192 and open the playground for the surrounding community to use outside of school hours.
#
#
# Summary This project will construct a playground and multi-use recreation area at Intermediate School 228.
#
#
# Summary This project will construct a new open space within the NYCHA Pomonok Houses.
#
#
# Summary This project will construct a playground at Grove Street Community Garden
#
#
# Summary This project will construct a new park and comfort station on the corner of Augustina Avenue and Nameoke Avenue.
#
#
# Summary This project will construct Thursby Basin Park.
#
#
# Summary This project will construct Bay Breeze Park.
#
#
# Summary This project will construct green infrastructure to capture storm water at Greenstreets at various locations near Coney Island Beach and Boardwalk.
#
#
# Summary This project will construct a new seating area within the NYCHA Woodside Houses.
#
#
# Summary This project will construct a new elevated structure and park over the Brooklyn Queens Expressway.
#
#
# Summary This project will construct Beaver Noll Park, which will include a tot lot and sitting area.
#
#
# Summary This project will construct a comfort station at Nameoke Park.
#
#
# Summary This project will construct a stormwater greenstreet on Crotona Parkway between East 178th Street and East Tremont Avenue.
#
#
# Summary This project will construct a new park at Hudson Street and West Houston Street.
#
#
# Summary This project will construct a common green plaza in Goodwill Park (Two Coves Community Garden).
#
#
# Summary This project will construct Nameoke Park.
#
#
# Summary This project will construct perimeter retaining walls, curbs, steel picket fencing, and a water supply system. Existing side walks and street curbs will be reconstructed.
#
#
# Summary This project will construct Elizabeth H. Berger Plaza, closing the slip road between two smaller parks to create one larger plaza with plantings, a lawn mound, and seating.
#
#
# Summary This project will construct a new park, including a comfort station, playground and multi-purpose synthetic turf field at Gateway Estates.
#
#
# Summary This project will construct a new open space at West 48th Street and 10th Avenue.

# %% [markdown]
# ---

# %% [markdown]
# ## Some more basic patterns and metacharacters'
#
# - . (dot) matches any character except \n (newline)
# - \t matches a tab
# - \n matches a newline
# - \r matches return
# - ^ matches the start of a string
# - $ matches the end of a string

# %% [markdown]
# ## Metacharacters
#
# Include "  \ ^ $ . | ? * + ( ) [ ] and \
#
# These metacharacters help us match various, non-literal components of a sentence. In order to 'escape' them (aka, to search for that symbol itself) you need to proceed it with a backslash (\)

# %% [markdown]
# ---

# %% [markdown]
# To gain insight into what your regular expression is doing at any time, I highly recommend using regexper.com (https://regexper.com/) which will allow you to see exactly what a given search is doing.
#
# For instance, check out https://regexper.com/#%5EMy%0A to see what we just did with '^My'
#
# Here is a good cheat sheet for all the special characters, too, From Emma Wedekind: https://dev.to/emmawedekind/regex-cheat-sheet-2j2a
#
# Finally, I'd also recommend RegEx101, a handy debugger for regular expressions: https://regex101.com/

# %% [markdown]
# ---

# %% [markdown]
# ## Shortcuts:
#
# - \d: matches digits 0-9
# - \D matches anything but \d
# - \w matches any alphanumeric character plus underscore
# - \W matches anything but \w
# - \s matches any "whitespace character (space, tab, newline)
# - \S matches anything but \s

# %% [markdown]
# ---

# %% [markdown]
# ## Operators:

# %% [markdown]
# ## `'alternation' operator`
#
# Defines one or more alternatives that need to be true to return a match:

# %%
grep('^Summary This project will (partially|expand)', './ParkProjects.txt')
# Out:
# Summary This project will expand Asser Levy Playground into the roadbed of Asser Levy Place and construct a new artificial turf field and exercise track, new adult fitness equipment, benches, tables, drinking fountains, park lighting and trees.
#
#
# Summary This project will partially reconstruct the Greenbelt Recreation Center.
#
#
# Summary This project will expand the parking area at Greenbelt Recreation Center.
#
#
# Summary This project will expand Collect Pond Park into the adjacent parking lot and provide new plantings and a pond.
#
#
# Summary This project will partially reconstruct Lyons Pool Recreation Center in Staten Island.
#
#
# Summary This project will expand Seba Playground in Marine Park.

# %% [markdown]
# ## `Repetition operator `
#
# Specifies that the symbol to be matched may be repeated:

# %% [markdown]
# Repetition Shortcuts:
#
# - * = {0,} The * character means match the previous atom zero or more times
# - + = {1,} The + character means match the previous atom one or more times
# - ? = {0,1} The ? character means match the previous atom zero or one times

# %%
grep('Summary .{400,}$', './ParkProjects.txt')
# Out:
# Summary This project will reconstruct the plaza and adjacent seating area in Athens Square Playground.  The cheek walls on either side of the two ramps will be reconstructed and a new ramp will be constructed between the seating area and the plaza.  New handrails will be installed, 2 1/2 foot fencing will be placed around plant beds, plant material will be replaced as needed, and a trench drain will be installed near the spray shower to keep water from flowing onto the safety surface.
#
#
# Summary This project will reconstruct the east and west Ocean Parkway Malls from Avenue O to Kings Highway with new asphalt pavement, pipe handrails, trees, benches, signage, greenway markings and curbs; expanded tree pits and restored granite block pavers and a mile marker. This project will also reconstruct the handball and basketball courts, paving, fencing, gates and landscaping and construct a new ADA-accessible drinking fountain in Colonel David Marcus Playground.
#
#
# Summary This project will include paving and landscape improvements in Riverside Park. At Riverside Drive between West 122nd and West 125th Streets, the project will reconstruct the existing perimeter sidewalk, including asphalt pavement and new bluestone curb, benches and fencing. At Crabapple Grove between West 91st and West 95th Streets, the project will reconstruct park paths and install new benches. Along the Hudson River Greenway between West 72nd and West 83rd Streets, the project will install additional greenway signage, improve park lighting and reconstruct pavements.
#
#
# Summary This project will provide an opportunity to strengthen the historic character and elegance of the existing landscape.  The project will create a new entrance to the park and house that will comply with current ADA accessibility standards, improving access to the park.  The perimeter sidewalk adjacent to the sections of wall being restored will be reconstructed to eliminate trip hazards as will portions of the brick pathways in the park that lead to the mansion to provide a safer path for all visitors.

# %% [markdown]
# ## `Group Operator`
#
# In the group operator, when a group of characters is inclused in parantehses, the next operator applies to the whole group, not only the previous characters

# %%
grep('name.* (\d){3,} .*', './ParkProjects.txt')
# Out:
# name 850 East 138th Street
#
#
# name E 156 St bet Tinton Av & Union Av
#
#
# name Grand Central Parkway., Whitestone Expressway between 111 Street and College Point Boulevard, Park Drive E
#
#
# name W 166 St bet Woodycrest Av & Nelson Av
#
#
# name Rev James Polite Av to Interval Av bet E 167 St & Home St
#
#
# name East 135 Street between Madison & 5 Avenue
#
#
# name W. 134 St., Lenox Terrace Pl.
#
#
# name Madison Ave, E. 120 St. to E. 124 St.
#
#
# name St. Mary's Street, St. Ann's Avenue, East 149 Street, Jackson Avenue
#
#
# name E. 124 St. Bet 1 Ave. and 2 Ave.
#
#
# name Hamilton Place, West 140 to West 141 Streets
#
#
# name FDR Drive, East 106 to East 107 Streets
#
#
# name West 134 Street, Lenox Terrace Place
#
#
# name West 135 Street between Lenox Terrace Place and 5 Avenues
#
#
# name West 117 Street & Morningside Avenue
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name West 156 Street & St. Nicholas Avenue
#
#
# name 128 Pitt Street
#
#
# name West 134 Street, Lenox Terrace Place
#
#
# name Jerome Avenue, McClellan Street, River Avenue, East 164 Street
#
#
# name Jerome Ave., E. 193 St., Creston Ave., E
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name Clay Ave., Anthony Ave. bet Mount Eden Pkwy. and E. 170 St
#
#
# name E 161 St, Trinity Av, E 163 St, Cauldwel
#
#
# name Jackson Av bet E 147 St & E 145 St
#
#
# name Jerome Ave., E. 193 St., Creston Ave., E
#
#
# name Rev James Polite Av bet E 163 St & E 164 St
#
#
# name E 135 St bet Alex&er Av and Willis Av
#
#
# name E 141 St to E 140 St bet Willis Av & Alexander Av
#
#
# name E. 138 St., Grand Concourse, Railroad tracks
#
#
# name LIE., 73 Ave., Union Turnpike, GCP bet. 193 St., Francis Lewis Blvd., Hollis Hills Ter., and 210 St.
#
#
# name Baisley & Merrick Boulevards, 115 Avenue
#
#
# name 149 Avenue, 235 Street, Brookville Boulevard, South Conduit Avenue
#
#
# name Jamaica Ave., 89 Ave. bet. 150 St. and 153 St.
#
#
# name 37 Avenue between 112 & 113 Streets
#
#
# name Vleigh Place & 141 Street
#
#
# name Burke Ave., E. 180 St. bet. Dr. Kazamiroff Blvd., Southern Blvd. and Bronx Park E., Unionport Rd.
#
#
# name Seaview Ave. bet. Paerdegat Basin and E. 93 St., E. 102 St. and Fresh Creek Basin
#
#
# name Grand Central Pkwy., Whitestone Exwy. bet. 111 St. and College Point Blvd., Park Drive E.
#
#
# name 1st Avenue to FDR Drive, East 111 to East 114 Streets
#
#
# name FDR Drive, East 90 to East 125 Streets
#
#
# name Riverside Drive to Broadway, West 192 to Dyckman Streets
#
#
# name FDR Drive, East 90 to East 125 Streets
#
#
# name Grand Central Parkway., Whitestone Expressway between 111 Street and College Point Boulevard, Park Drive E
#
#
# name Convent and Amsterdam Av, W 135 St
#
#
# name Dr. MLK Jr. Blvd. at W. 170 St.
#
#
# name Goulden Av bet W 205 St and Sedgwick Av
#
#
# name University Av bet W 174 St & W Tremont Av
#
#
# name East 163 Street & Teller Avenue
#
#
# name Southern Boulevard, Webster, Burke Avenues, Bronx Pak East, 180 Street
#
#
# name Hutchinson River Pkwy. E. bet. Wilkinson Ave. and E. 197 St.
#
#
# name Bayside Avenue, 25th Avenue, 149 to 150 Streets
#
#
# name Grand Central Parkway., Whitestone Expressway between 111 Street and College Point Boulevard, Park Drive E
#
#
# name E 158 st bet Eagle Av & Caildwell Av
#
#
# name East 163 Street, Cauldwell Avenue & East 161 Street
#
#
# name Vleigh Place & 141 Street
#
#
# name East 166 Street & Morris Avenue
#
#
# name Guy Brewer Boulevard, 134 Avenue
#
#
# name Jerome Avenue, East 193 Street, Creston Avenue, East 191 Street
#
#
# name St. Mary's Street, St. Ann's Avenue, East 149 Street, Jackson Avenue
#
#
# name Goulden Avenue, West 205 Street, Paul Avenue, Bedford Park Boulevard
#
#
# name St. Mary's Street, St. Ann's Avenue, East 149 Street, Jackson Avenue
#
#
# name 450 Flatbush Avenue
#
#
# name West 172 Street between Nelson Avenue, Jesup Street
#
#
# name 111 Avenue, 134 & 135 Streets, Lincoln Street
#
#
# name S/s Jamaica Av Bet 202 and 204 Sts
#
#
# name 179 Pl. bet. 90 Ave. and Jamaica Ave.
#
#
# name Brookville Blvd. bet. 136 Ave. 137 Ave.
#
#
# name E. 141 St. bet. Brook Ave. and St Ann's Ave.
#
#
# name E. 141 St. bet. Brook Ave. and St Ann's Ave.
#
#
# name E. 141 St. bet. Brook Ave. and St Ann's Ave.
#
#
# name Seaview Avenue between Paerdegat Basin and East 93 Street, East 102 Street and Fresh Creek Basin
#
#
# name Bradhurst & Edgecombe Avenues, West 145 Street to West 155 Street
#
#
# name E. 180 St. bet. Daly Ave. and Vyse Ave.
#
#
# name W. 254 St. bet Riverdale Ave. and Mosholu Ave.
#
#
# name West 144 Street & Lenox Avenue
#
#
# name W. 107 St. to W. 108 St., Columbus Ave. and Amsterdam Ave.
#
#
# name 29 Ave., 32 Ave. bet. 155 St. and 159 St.
#
#
# name 149 Av, Springfield Bl, 145 Rd, 148 St
#
#
# name Springfield Bl, 145 Rd, Arthur St
#
#
# name 148 St and 85 Av
#
#
# name Brinkerhoff Avenue, Merrick Boulevard, 110 Road
#
#
# name Broadway, Columbus Circle to West 110 Street
#
#
# name Broadway, West 135 Street to West 156 Streets
#
#
# name Burke Ave., E. 180 St. bet. Dr. Kazamiroff Blvd., Southern Blvd. and Bronx Park E., Unionport Rd.
#
#
# name 109 Street between 46-47 Avenues
#
#
# name 20 Avenue between 123 Street and 124 Street
#
#
# name 149 Avenue, 235 Street, Brookville Boulevard, South Conduit Avenue
#
#
# name 149 Avenue, Springfield Boulevard, 145 Road, 184 Street
#
#
# name 1555 Linden Boulevard
#
#
# name 1555 Linden Boulevard
#
#
# name Schieffelin Ave. bet. E. 266 Dr. and E. 229 St.
#
#
# name 32 Ave. bet. 99 St. and 100 St.
#
#
# name E 180 St bet Prospect Av & Mapes Av
#
#
# name Madison Avenue, East 120 Street to East 124 Street
#
#
# name 46 Ave., 46 Rd. bet. Oceania St. and 211 St.
#
#
# name Jerome Av to River Av bet E 164 St & McClellan St at Cromwell Ave
#
#
# name E 180 St bet Prospect Av & Mapes Av
#
#
# name Jerome Av to River Av bet E 164 St & McClellan St at Cromwell Ave
#
#
# name Schieffelin Ave. bet. E. 266 Dr. and E. 229 St.
#
#
# name 32 Ave. bet. 99 St. and 100 St.
#
#
# name E 180 St bet Prospect Av & Mapes Av
#
#
# name Madison Ave, E. 120 St. to E. 124 St.
#
#
# name 46 Ave., 46 Rd. bet. Oceania St. and 211 St.
#
#
# name Jerome Av to River Av bet E 164 St & McClellan St at Cromwell Ave
#
#
# name Goulden Avenue, West 205 Street, Paul Avenue, Bedford Park Boulevard
#
#
# name 121 Avenue & 220 Street
#
#
# name Baisley & Merrick Boulevards, 115 Avenue
#
#
# name 89 St and 160 Av
#
#
# name 121 Avenue & 220 Street
#
#
# name 202 Street & Jamaica Avenue S/S
#
#
# name Springfield Boulevard & 139 Avenue
#
#
# name Amsterdam Av, W 151 St To W 152 St
#
#
# name Lenox Ave, W. 113 St. To W. 114 St.
#
#
# name W. 145 St. to W. 143 St., Lenox Ave., and Harlem River
#
#
# name 430 West 25th Street
#
#
# name 14 Ave. bet. 121 St. and College Point Blvd.
#
#
# name Northern Blvd., 43 Ave. bet. 169 St. and 170 St.
#
#
# name 109 St., 111 St. bet. 46 Ave. and 47 Ave.
#
#
# name 34 Avenue & 214 Place
#
#
# name W. 168 St. bet. Dr. MLK Jr. Blvd. and Merriam Ave.
#
#
# name E 168 St bet  Park Av & Washington Av
#
#
# name Between Southern Boulevard & Crotona Parkway from East 175 Street to Garden Street
#
#
# name Horace Harding Exwy. Sr. Rd. S., 62 Ave. bet. 99 St. and 102 St.
#
#
# name Underhill Avenue, Peck Avenue, 199 Street between Fresh Meadow Lane and Francis Lewis Bouelvard, Union Turnpike
#
#
# name Riverside Drive to Broadway, West 192 to Dyckman Streets
#
#
# name Lenox Ave, W. 113 St. To W. 114 St.
#
#
# name Poppenhusen Ave. bet. 115 St. and College Pl.
#
#
# name Lewis Ave. bet. 101 St. and 102 St.
#
#
# name 173 St., 172 St. bet. Liberty Ave., 106 Ave., Polhemas Ave. and 107 Ave.
#
#
# name 111 Av, 134 and 135 Sts, Lincoln St
#
#
# name Avenues J & K, East 100 to East 101 Streets
#
#
# name 25 Av Bet 98 and 100 Sts
#
#
# name W/S 164 Street, S/O 65 Avenue
#
#
# name North Conduit Avenue, between 80 and 88 Streets, 133 Avenue
#
#
# name 2175 Richmond Terrace, between Faber Street and Sharpe Avenue
#
#
# name 2301 Amsterdam Avenue
#
#
# name West 129 Street, Amsterdam Avenue
#
#
# name Grand Central Pkwy., Whitestone Exwy. bet. 111 St. and College Point Blvd., Park Drive E.
#
#
# name Grand Central Pkwy., Whitestone Exwy. bet. 111 St. and College Point Blvd., Park Drive E.
#
#
# name Baisley & Merrick Boulevards, 115 Avenue
#
#
# name Poppenhusen Ave. bet. 115 St. and College Pl.
#
#
# name West of Grand Central Parkway, 112 Street between 64 Avenue & 64 Road
#
#
# name 208 Totten Avenue
#
#
# name Chapel at 423 Abbot Road, Commander's House at 422A Weaver Avenue
#
#
# name Riverside Drive, Hudson River, West 155 - West 179 Streets, Henry Hudson Parkway
#
#
# name Riverside Drive, Hudson River, West 155 - West 179 Streets, Henry Hudson Parkway
#
#
# name Riverside Drive, Hudson River, West 155 - West 179 Streets, Henry Hudson Parkway
#
#
# name 128 Cedar Grove Avenue
#
#
# name 3808 Victory Boulevard
#
#
# name North Conduit Avenue, between 80 and 88 Streets, 133 Avenue
#
#
# name West 134 Street, Lenox Terrace Place
#
#
# name 104 Ave. bet. 225 St. and 227 St.
#
#
# name Poppenhusen Ave. bet. 115 St. and College Pl.
#
#
# name N Conduit Av bet 118 St & Lefferts Blvd
#
#
# name 173 St and 137 Av
#
#
# name 1940 East 36th Street, Brooklyn
#
#
# name 2301 Amsterdam Avenue
#
#
# name East 177 Street, Westchester Avenue, Virginia Avenue
#
#
# name Fort Hamilton Parkway between 94 Street and 101 Street
#
#
# name 765 Manida Street
#
#
# name E. 139 St. bet. Brook Ave. and Willis Ave.
#
#
# name Melrose Avenue between East 160 Street and East 159 Street
#
#
# name Harlem River, Jerome, River Avenues, Ruppert Place, East 157 Street
#
#
# name Jerome Avenue, East 193 Street, Creston Avenue, East 191 Street
#
#
# name Madison Ave, E. 120 St. to E. 124 St.
#
#
# name 2880 Flatbush Avenue
#
#
# name 2335 Bergen Avenue
#
#
# name 2551 Westchester Avenue
#
#
# name 2551 Westchester Avenue
#
#
# name Merrick Bl, 173 Pl, Sayers Av
#
#
# name East 102 Street & FDR Drive
#
#
# name Morningside Ave., W. 123 St. and W. 124 St.
#
#
# name 1 Ave., FDR Dr., bet. E. 111 St. and E. 114 St.
#
#
# name St Nicholas Av To St Nicholas Terr, W 128 St To W 141 St
#
#
# name Merrick Blvd. bet. 115 Ave., 116 Ave., and Baisley Blvd.
#
#
# name Independence Avenue and West 235 Street
#
#
# name Bounded by 101 Street, Lewis, Strong and Radcliff Avenues in the Borough of Queens.
#
#
# name Adjacent to P.S. 134 between Henry Street and East Broadway
#
#
# name 450 Saint Anns Avenue
#
#
# name 111 Canal Street
#
#
# name Sedgwick to Cedar Avenues, North of West 180 Street
#
#
# name 1527 Jesup Avenue
#
#
# name 103 East 122nd Street
#
#
# name Lexington Avenue between East 100th and East 101 Streets
#
#
# name Pleasant Avenue between East 118 & East 119 Streets
#
#
# name 1801 Davidson Avenue between West 176th Street and West 177th Street
#
#
# name 228 Avenue S, between West 4th Street and West 5th Street
#
#
# name 555 Glenmore Avenue

# %% [markdown]
# ---

# %% [markdown]
# # Exercise 1: What do these regex's match?

# %%
# your code here

# %% [markdown]
# # Solution

# %%
grep('^Summary .* Street.$', './ParkProjects.txt')
# Out:
# Summary This project will reconstruct Greenstreet fencing at Amsterdam Avenue and West 127th Street.
#
#
# Summary This project will reconstruct Beach Channel (P.S. 183) playground located south of Beach Channel Drive between Beach 79th & Beach 80th Street.
#
#
# Summary This project will reconstruct the Coney Island Boardwalk between Brighton 15th Street and Coney Island Avenue and the entrance at Brighton 15th Street.
#
#
# Summary This project will construct a masonry ramp to provide ADA access to John Finley Walk at East 82nd Street.
#
#
# Summary This project will reconstruct the East River Esplanade from East 68th Street to East 70th Street.
#
#
# Summary This project will reconstruct the East River Esplanade at East 74th Street.
#
#
# Summary This project will install a sewer line between Inwood Hill Nature Center and West 218th Street.
#
#
# Summary This project will construct a portion of Riverside Park South between West 65th Street and West 68th Street, including new plazas, play areas, lawns, volleyball courts, and a dog run, and it will reconstruct the bikeway between West 62nd Street and West 70th Street.
#
#
# Summary This project will reconstruct the entrance to Van Cortlandt Park at Broadway and West 242nd Street.
#
#
# Summary This project will acquire two lots for community gardens on West 143rd Street.
#
#
# Summary This project will reconstruct the hazardous and deteriorated section of the existing asphalt bicycle path between (approximately) Bay 8th and Bay 14th Street.
#
#
# Summary The project will construct a new open space at the DEP site on East 4th Street between Bowery and Lafayette Street.
#
#
# Summary The project will construct a new open space at the DEP site at Grand Street and Lafayette Street.
#
#
# Summary This project will construct a new park at Hudson Street and West Houston Street.

# %%
grep('East (\d){2,}st', './ParkProjects.txt')
# Out:
# name East 71st Street between Avenue N and Avenue T
#
#
# name Flatlands Avenue between East 81st Street and East 82nd Street
#
#
# name Flatlands Avenue between East 81st Street and East 82nd Street
#
#
# name Walton Avenue, Grand Concourse, East 158th Street, East 151st Street
#
#
# name Brook Avenue between East 140th Street and East 141st Street
#
#
# name Grand Concourse between East 161st and East 164th Streets
#
#
# name Mapes Avenue and Prospect Avenue between East 180th Street and East 181st Street
#
#
# name East 181st Street and Oak Tree Place between Quarry Road and Hughes Avenue
#
#
# name Emmons Avenue between East 21st Street and East 26th Street
#
#
# name First Avenue between East 41st Street and East 42nd Street
#
#
# name FDR Drive, East 60th Street, East 61st Street, York Avenue
#
#
# name Second Avenue between East 120th Street and East 121st Street
#
#
# name East 181st Street and Walton Avenue
#
#
# name East 141st Street between Alexander Avenue and Willis Avenue

# %%
grep('Lenox .* (Pl\.|Place)', './ParkProjects.txt')
# Out:
# name W. 134 St., Lenox Terrace Pl.
#
#
# name West 134 Street, Lenox Terrace Place
#
#
# name West 135 Street between Lenox Terrace Place and 5 Avenues
#
#
# name West 134 Street, Lenox Terrace Place
#
#
# name West 134 Street, Lenox Terrace Place

# %% [markdown]
# ---

# %% [markdown]
# # Exercise 2: Imagine you have a file with telephone numbers in different formats:
#
# - 679-397-5255
# - 2126660921
# - 212-998-0902
# - 888-888-2222
# - 800-555-1211
# - 800 555 1212
# - 800.555.1213
# - (800) 555-1214
# - 1-800-555-1215
# - 1(800)555-1216
# - 800-555-1212-1234
# - 800-555-1212x1234
# - 800-555-1212 ext. 1234
# - work 1-(800) 555.1212 #1234
#
# # Your goal is to standardize everything in the form (xxx)-xxx-xxx.
#
# To make the process interactive, go to http://regex101.com/?#python, copy and paste the numbers above in the text area called "Text String", and then try to write the regular expression above. (Remember to put the "g" character in the small text field next to the regex: this has the same meaning as in sed, and it means "find globally" the regex, not just the first occurence).

# %%
TextString = """

679-397-5255
2126660921
212-998-0902
888-888-2222
800-555-1211
800 555 1212
800.555.1213
(800) 555-1214
1-800-555-1215
1(800)555-1216
800-555-1212-1234
800-555-1212x1234
800-555-1212 ext. 1234
work 1-(800) 555.1212 #1234

"""

# your code here

# %% [markdown]
# # Solution

# %%
TextString = """

679-397-5255
2126660921
212-998-0902
888-888-2222
800-555-1211
800 555 1212
800.555.1213
(800) 555-1214
1-800-555-1215
1(800)555-1216
800-555-1212-1234
800-555-1212x1234
800-555-1212 ext. 1234
work 1-(800) 555.1212 #1234

"""

# Notice now that each part of the phone is included in parentheses allowing us to grab individual part of the 
# phone number

regex = re.compile(r'([2-9]\d{2})\D*(\d{3})\D*(\d{4})')
matches = regex.finditer(TextString)

phones = list()
for m in matches:
    area_code = m.group(1)
    first_three_digits = m.group(2)
    last_four_digits =  m.group(3)
    
    phone = "(" + area_code + ")" + first_three_digits + "-" + last_four_digits
            
    phones.append(phone)

# Notice that our list does not include numbers with invalid area codes (e.g., 124, 125)
phones
# Out:
# ['(679)397-5255',
#  '(212)666-0921',
#  '(212)998-0902',
#  '(888)888-2222',
#  '(800)555-1211',
#  '(800)555-1212',
#  '(800)555-1213',
#  '(800)555-1214',
#  '(800)555-1215',
#  '(800)555-1216',
#  '(800)555-1212',
#  '(800)555-1212',
#  '(800)555-1212',
#  '(800)555-1212']

# %% [markdown]
# ---

# %% [markdown]
# # [Python's re Regular Expression Library](https://docs.python.org/3/library/re.html)
#
# We are going to move away from using Panos's Grep function now and focus on Python's Regular Expression Library (re). To be clear, the regular expressions remain the same, but ow we call for them and summon them is different.
#
# A quick note on match groups, too. [_Documentation_](https://docs.python.org/2/library/re.html)
#
# `group([group1, ...]) returns one or more subgroups of the match. If there is a single argument, the result is a single string; if there are multiple arguments, the result is a tuple with one item per argument. Without arguments, group1 defaults to zero (the whole match is returned). If a groupN argument is zero, the corresponding return value is the entire matching string; if it is in the inclusive range [1..99], it is the string matching the corresponding parenthesized group. If a group number is negative or larger than the number of groups defined in the pattern, an IndexError exception is raised. If a group is contained in a part of the pattern that did not match, the corresponding result is None. If a group is contained in a part of the pattern that matched multiple times, the last match is returned.`
#
# For example:
# ```python
# >>> m = re.match(r"(\w+) (\w+)", "Isaac Newton, physicist")
# >>> m.group(0)       # The entire match
# 'Isaac Newton'
# >>> m.group(1)       # The first parenthesized subgroup.
# 'Isaac'
# >>> m.group(2)       # The second parenthesized subgroup.
# 'Newton'
# >>> m.group(1, 2)    # Multiple arguments give us a tuple.
# ('Isaac', 'Newton')
# ```

# %%
text = "Hello, my name is Alex Siegman. Please call me back at 212 555-9583 or email me at as13815@nyu.edu at your \
earliest convenience. Thank you."

# %%
import re
from re import search

# %%
regex = re.compile(r'[Aa]lex')
matches = regex.finditer(text)

for match in matches: 
    print(match.group())
# Out:
# Alex

# %% [markdown]
# Let's try and match for an email address:

# %%
regex = re.compile(r'\w+@\w+\..{3}')

matches = regex.finditer(text)

for match in matches: 
    print(match.group())
# Out:
# as13815@nyu.edu

# %% [markdown]
# How about for a phone number?

# %%
regex = re.compile(r'\d{3} \d{3}-\d{4}')

matches = regex.finditer(text)

for match in matches: 
    print(match.group())
# Out:
# 212 555-9583

# %% [markdown]
# And what if you have multiple matches in the same string?

# %%
text = "Hello, my name is Alex Siegman. Please call me back at 212 555-9583 or 314 935-9981 or email me at as13815@nyu.edu at your \
earliest convenience. Thank you."

# %%
# we can use 'finditer' that returns a collection of MatchObject items

regex = re.compile(r'\d{3} \d{3}-\d{4}')

matches = regex.finditer(text)
for i, match in enumerate(matches):
    print(i+1, "==>", match.group())
    
# FYI the 'search' term only returns the first MatchObject item
# Out:
# 1 ==> 212 555-9583
# 2 ==> 314 935-9981

# %% [markdown]
# ---

# %% [markdown]
# ## Data Extraction
#
# It's awesome that we can return our matches here in our notebook, but what we really want to do is select the strings that match our regex and return them to a program to be processed. For example:

# %%
regex = re.compile(r"""(\d{3}) # the area code
                       \D* # zero or more non-digits
                       (\d{3}) # three digits
                       \D* # zero or more non-digits
                       (\d{4}) # four digits
                    """, re.VERBOSE)

matches = regex.finditer(text)
for match in matches:
    print(match.group())
    print("Formatted:", match.group(1),"-", match.group(2), "-", match.group(3))
    print("===========")
# Out:
# 212 555-9583
# Formatted: 212 - 555 - 9583
# ===========
# 314 935-9981
# Formatted: 314 - 935 - 9981
# ===========

# %% [markdown]
# What about our large 'file' of ill-formatted phone numbers from earlier?

# %%
TextString = """

679-397-5255
2126660921
212-998-0902
888-888-2222
800-555-1211
800 555 1212
800.555.1213
(800) 555-1214
1-800-555-1215
1(800)555-1216
800-555-1212-1234
800-555-1212x1234
800-555-1212 ext. 1234
work 1-(800) 555.1212 #1234

"""

# %%
regex = re.compile(r'(\d{3})\D*(\d{3})\D*(\d{4})')
matches = regex.finditer(TextString)

phones = list()

for m in matches:
    area_code = m.group(1)
    first_three_digits = m.group(2)
    last_four_digits =  m.group(3)
    
    phone = "(" + area_code + ")" + first_three_digits + "-" + last_four_digits
            
    phones.append(phone)

phones
# Out:
# ['(679)397-5255',
#  '(212)666-0921',
#  '(212)998-0902',
#  '(888)888-2222',
#  '(800)555-1211',
#  '(800)555-1212',
#  '(800)555-1213',
#  '(800)555-1214',
#  '(800)555-1215',
#  '(800)555-1216',
#  '(800)555-1212',
#  '(800)555-1212',
#  '(800)555-1212',
#  '(800)555-1212']

# %% [markdown]
# ## String Replacement
#
# String Replacement (.sub()) allows us to return a version of our text where all instances that matched have been substituted with a replacement. For instance, if we want to mask phone numbers in a document:

# %%
regex = re.compile('(\d{3})\D*(\d{3})\D*(\d{4})')

newstring = re.sub(regex, "XXX-XXX-XXXX", TextString)

print(newstring)
# Out:
# XXX-XXX-XXXX
# XXX-XXX-XXXX
# XXX-XXX-XXXX
# XXX-XXX-XXXX
# XXX-XXX-XXXX
# XXX-XXX-XXXX
# XXX-XXX-XXXX
# (XXX-XXX-XXXX
# 1-XXX-XXX-XXXX
# 1(XXX-XXX-XXXX
# XXX-XXX-XXXX-1234
# XXX-XXX-XXXXx1234
# XXX-XXX-XXXX ext. 1234
# work 1-(XXX-XXX-XXXX #1234

# %% [markdown]
# ---
